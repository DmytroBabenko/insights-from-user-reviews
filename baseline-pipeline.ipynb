# %%
import pandas as pd
import numpy as np
from typing import List
import warnings
import random
import json

# %%
warnings.filterwarnings('ignore')

# %%
def save_data_to_json(data, file):
    with open(file, 'w') as f:
        json.dump(data, f)

# %%
def load_json(file):
    with open(file) as json_file:
        data = json.load(json_file)
        return data

# %%
def get_mixed_review_texts(df):
    review_texts = []
    for index, row in df.iterrows():
        review_text = ""
        
        if len(row['title']) > 0 and row['title'] != 'Nan':
            review_text += row['title']
            
        if len(row['pos_text']) > 0 and row['pos_text'] != 'Nan':
            review_text += f" {row['pos_text']}"

        if len(row['neg_text']) > 0 and row['neg_text'] != 'Nan':
            review_text += f" {row['neg_text']}"
            
            
        review_texts.append(review_text)
            
    
    return review_texts

# %% [markdown]
# ## Dataset

# %% [markdown]
# See https://github.com/DmytroBabenko/insights-from-user-reviews/blob/master/dataset/data-analysis.ipynb to get more details about dataset

# %% [markdown]
# For baseline, we are going to use Ukrainian-language user reviews parsed from *booking.com.*

# %%
booking_test_df = pd.read_csv("dataset/booking/booking-test.csv")

# %%
hotel_topic_marks_test = pd.read_csv("dataset/booking/hotel-topic-marks-test.csv")

# %%
test_hotels = np.unique(hotel_topic_marks_test['hotel'].values)

# %%
test_hotels[50:70]
# Out:
# array(['felisa.uk.html', 'fire-inn.uk.html', 'flora-apartments.uk.html',
#        'flying-dutchman.uk.html', 'fontush-boutique.uk.html',
#        'franz.uk.html', 'frapolli.uk.html', 'freedom-kiev.uk.html',
#        'fregat.uk.html', 'gagarinn.uk.html', 'garmonia.uk.html',
#        'gaudi-stylish.uk.html', 'genuez.uk.html', 'gintama.uk.html',
#        'good-night.uk.html', 'gostinitsa-semeinogo-tipa.uk.html',
#        'gostinitsa-vg.uk.html', 'gostiniy-dvor-odessa.uk.html',
#        'gotiel-quot-art-gotiel-quot.uk.html', 'gotiel-znannia.uk.html'],
#       dtype=object)

# %%
len(test_hotels)
# Out:
# 188

# %% [markdown]
# ## Collocations

# %% [markdown]
# The extracting collocation algorith for baseline is implemented in *collocations.collocation_extractor.py*. Here, we use this implementation.

# %%
from topics import TopicType
from collocations.collocation_extractor import StanfordNLPCollocationExtractor

# %%
[e.value for e in TopicType]
# Out:
# [('clean',),
#  ('comfort',),
#  ('location',),
#  ('services',),
#  ('staff',),
#  ('value',),
#  ('wi-fi',),
#  'others']

# %%
collocation_extractor = StanfordNLPCollocationExtractor()
# Out:
# Use device: gpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/dbabenko/stanfordnlp_resources/uk_iu_models/uk_iu_tokenizer.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/dbabenko/stanfordnlp_resources/uk_iu_models/uk_iu_tagger.pt', 'pretrain_path': '/home/dbabenko/stanfordnlp_resources/uk_iu_models/uk_iu.pretrain.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/dbabenko/stanfordnlp_resources/uk_iu_models/uk_iu_lemmatizer.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/dbabenko/stanfordnlp_resources/uk_iu_models/uk_iu_parser.pt', 'pretrain_path': '/home/dbabenko/stanfordnlp_resources/uk_iu_models/uk_iu.pretrain.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# Done loading processors!
# ---

# %% [markdown]
# Example of extraction collocation for one hotel

# %%
example_hotel = test_hotels[57]
example_hotel_df = booking_test_df.loc[booking_test_df['hotel'] == example_hotel]
example_hotel_df.head()
# Out:
#                                                   title  \
# 1367  Чистота в номері, гаряча вона постійно, бо є е...
# 1368  Брудне, некомфортно місце, лише у разі якщо не...
# 1369  В моєму номері був бойлер, що дало доступ до г...
# 1370  Душ у номері, є холодильник, є зайчик і вентил...
# 1371  Ванна кімната чиста, є шампунь, гель, упакован...
#
#                                                pos_text  \
# 1367  Чистота в номері, гаряча вона постійно, бо є е...
# 1368  Заселили після 12 години ночі, хоча вказано, з...
# 1369  В моєму номері був бойлер, що дало доступ до г...
# 1370  Душ у номері, є холодильник, є зайчик і вентил...
# 1371  Ванна кімната чиста, є шампунь, гель, упакован...
#
#                                                neg_text  ratingValue  \
# 1367  Я отримав номер на 8 поверсі з гарним краєвидо...          8.3
# 1368  Брудно . В коридорі дірки у стінах, аж лячно б...          3.3
# 1369             Дуже холодно, не захоплюємо приміщення          4.2
# 1370  Знаходиться в такому місці, що добратись можна...          5.0
# 1371  Якщо врахувати ціну за номер, то немає претенз...          8.3
#
#       bestRating                 hotel  rating
# 1367        10.0  freedom-kiev.uk.html       4
# 1368        10.0  freedom-kiev.uk.html       2
# 1369        10.0  freedom-kiev.uk.html       2
# 1370        10.0  freedom-kiev.uk.html       2
# 1371        10.0  freedom-kiev.uk.html       4

# %%
example_hotel_revies = get_mixed_review_texts(example_hotel_df)
example_hotel_revies[:5]
# Out:
# ['Чистота в номері, гаряча вона постійно, бо є електричний... Чистота в номері, гаряча вона постійно, бо є електричний бойлер, а також радіатор та тепла ковдра, що об 11 ночі знайшов мені адміністратор, бо було трохи нижче нуля градусів. Взагалі, коли треба на день два приїхати в Київ у справах, то в цілому можна перетерпіти. Я отримав номер на 8 поверсі з гарним краєвидом, але біля ліфту, та через стіни було добре чути сусідів, щоразу інших, які сварили ся до першої години ночі, а стосовно ліфту, всі ходили повз мене весь вечер, всю ніч і ранок і кожен крок було дуже добре чути, так було всі три дні і голосно розмовляли по телефону і сварилися і таке інше.',
#  'Брудне, некомфортно місце, лише у разі якщо нема інших варіантів Заселили після 12 години ночі, хоча вказано, зо заселення до опівночі. Та дозволили поставити безкоштовно автомобіль на території. Брудно . В коридорі дірки у стінах, аж лячно було ходити . В номері лише туалет, душ на поверсі . матрац на ліжку дуже поганий, пружини боляче давлять в боки, та дуже брудний . матрацників немає . постільна білизна з якоїсь синтетики . Хоча вікна металопластикові, але дуже було чутно зранку звуки з вулиці, що заважало відпочивати . Якби ціна цього номера була у 2 рази менша, можна було би пробачити, але він коштує як пристойні апартаменти . Тому і порівнюю його з цією ціновою групою.',
#  'В моєму номері був бойлер, що дало доступ до гарячої води. В моєму номері був бойлер, що дало доступ до гарячої води. Виделку та ложка були брудні, персонал не потурбувався про те, щоб їх помити після колишніх гостів Дуже холодно, не захоплюємо приміщення',
#  'Душ у номері, є холодильник, є зайчик і вентилятор, ... Душ у номері, є холодильник, є зайчик і вентилятор, балкон . Тепло, нормальне ліжко, велике . Відсутній неприємний запах. Знаходиться в такому місці, що добратись можна тільки за таксі, за таксі платити від 60 до 100 . Немає кухні, але є чайник в номері, в нашому чайнику зацвіла вода, і він став чайником з пліснявою.',
#  'Ванна кімната чиста, є шампунь, гель, упаковані тапочки,... Ванна кімната чиста, є шампунь, гель, упаковані тапочки, гаряча вода, рушники . В номері є вентилятор (було дуже жарко, він нас врятував) ), маленький холодильник, чайник, тарілки, стакани, шафа з вішалка . В нашому номері не було телевізора, але зате був балкон) )). Якщо врахувати ціну за номер, то немає претензій . Трохи двери в душовій не щільно закриваються, але це не критично.']

# %%
example_collocations = collocation_extractor.extract_from_list_of_text(example_hotel_revies)

# %%
example_collocations
# Out:
# [({'word': 'чистота', 'upos': 'NOUN', 'lemma': 'чистота'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'гаряча', 'upos': 'ADJ', 'lemma': 'гарячий'},
#   {'word': 'вона', 'upos': 'PRON', 'lemma': 'вона'},
#   {'word': 'постійно', 'upos': 'ADV', 'lemma': 'постійно'}),
#  ({'word': 'чистота', 'upos': 'NOUN', 'lemma': 'чистота'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'гаряча', 'upos': 'ADJ', 'lemma': 'гарячий'},
#   {'word': 'вона', 'upos': 'PRON', 'lemma': 'вона'},
#   {'word': 'постійно', 'upos': 'ADV', 'lemma': 'постійно'}),
#  ({'word': 'електричний', 'upos': 'ADJ', 'lemma': 'електричний'},
#   {'word': 'бойлер', 'upos': 'NOUN', 'lemma': 'бойлер'}),
#  ({'word': 'тепла', 'upos': 'ADJ', 'lemma': 'теплий'},
#   {'word': 'ковдра', 'upos': 'NOUN', 'lemma': 'ковдр'}),
#  ({'word': 'радіатор', 'upos': 'NOUN', 'lemma': 'радіатор'},
#   {'word': 'та', 'upos': 'CCONJ', 'lemma': 'та'},
#   {'word': 'тепла', 'upos': 'ADJ', 'lemma': 'теплий'},
#   {'word': 'ковдра', 'upos': 'NOUN', 'lemma': 'ковдр'}),
#  ({'word': 'ночі', 'upos': 'NOUN', 'lemma': 'ніч'},
#   {'word': 'знайшов', 'upos': 'VERB', 'lemma': 'знайти'}),
#  ({'word': 'знайшов', 'upos': 'VERB', 'lemma': 'знайти'},
#   {'word': 'мені', 'upos': 'PRON', 'lemma': 'я'},
#   {'word': 'адміністратор', 'upos': 'NOUN', 'lemma': 'адміністратор'}),
#  ({'word': 'трохи', 'upos': 'ADV', 'lemma': 'трохи'},
#   {'word': 'нижче', 'upos': 'ADV', 'lemma': 'нижче'}),
#  ({'word': 'нижче', 'upos': 'ADV', 'lemma': 'нижче'},
#   {'word': 'нуля', 'upos': 'NOUN', 'lemma': 'нуля'}),
#  ({'word': 'нуля', 'upos': 'NOUN', 'lemma': 'нуля'},
#   {'word': 'градусів', 'upos': 'NOUN', 'lemma': 'градус'}),
#  ({'word': 'коли', 'upos': 'ADV', 'lemma': 'коли'},
#   {'word': 'треба', 'upos': 'ADV', 'lemma': 'треба'}),
#  ({'word': 'день', 'upos': 'NOUN', 'lemma': 'день'},
#   {'word': 'два', 'upos': 'NUM', 'lemma': 'два'},
#   {'word': 'приїхати', 'upos': 'VERB', 'lemma': 'приїхати'}),
#  ({'word': 'приїхати', 'upos': 'VERB', 'lemma': 'приїхати'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'київ', 'upos': 'PROPN', 'lemma': 'Київ'}),
#  ({'word': 'цілому', 'upos': 'NOUN', 'lemma': 'ціле'},
#   {'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'},
#   {'word': 'перетерпіти', 'upos': 'VERB', 'lemma': 'перетерпіти'}),
#  ({'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'},
#   {'word': 'перетерпіти', 'upos': 'VERB', 'lemma': 'перетерпіти'}),
#  ({'word': 'отримав', 'upos': 'VERB', 'lemma': 'отримати'},
#   {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': '8', 'upos': 'ADJ', 'lemma': '8'},
#   {'word': 'поверсі', 'upos': 'NOUN', 'lemma': 'поверх'}),
#  ({'word': 'гарним', 'upos': 'ADJ', 'lemma': 'гарний'},
#   {'word': 'краєвидом', 'upos': 'NOUN', 'lemma': 'краєвид'}),
#  ({'word': 'поверсі', 'upos': 'NOUN', 'lemma': 'поверх'},
#   {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#   {'word': 'гарним', 'upos': 'ADJ', 'lemma': 'гарний'},
#   {'word': 'краєвидом', 'upos': 'NOUN', 'lemma': 'краєвид'}),
#  ({'word': 'стіни', 'upos': 'NOUN', 'lemma': 'стіна'},
#   {'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#   {'word': 'добре', 'upos': 'ADV', 'lemma': 'добре'},
#   {'word': 'чути', 'upos': 'VERB', 'lemma': 'чути'}),
#  ({'word': 'добре', 'upos': 'ADV', 'lemma': 'добре'},
#   {'word': 'чути', 'upos': 'VERB', 'lemma': 'чути'}),
#  ({'word': 'чути', 'upos': 'VERB', 'lemma': 'чути'},
#   {'word': 'сусідів', 'upos': 'NOUN', 'lemma': 'сусід'}),
#  ({'word': 'сварили', 'upos': 'VERB', 'lemma': 'сварити'},
#   {'word': 'ся', 'upos': 'NOUN', 'lemma': 'сей'}),
#  ({'word': 'першої', 'upos': 'ADJ', 'lemma': 'перший'},
#   {'word': 'години', 'upos': 'NOUN', 'lemma': 'година'}),
#  ({'word': 'години', 'upos': 'NOUN', 'lemma': 'година'},
#   {'word': 'ночі', 'upos': 'NOUN', 'lemma': 'ніч'}),
#  ({'word': 'вечер', 'upos': 'NOUN', 'lemma': 'вечер'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'всю', 'upos': 'DET', 'lemma': 'весь'},
#   {'word': 'ніч', 'upos': 'NOUN', 'lemma': 'ніч'}),
#  ({'word': 'ніч', 'upos': 'NOUN', 'lemma': 'ніч'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'ранок', 'upos': 'NOUN', 'lemma': 'ранок'}),
#  ({'word': 'добре', 'upos': 'ADV', 'lemma': 'добре'},
#   {'word': 'чути', 'upos': 'VERB', 'lemma': 'чути'}),
#  ({'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#   {'word': 'добре', 'upos': 'ADV', 'lemma': 'добре'},
#   {'word': 'чути', 'upos': 'VERB', 'lemma': 'чути'}),
#  ({'word': 'голосно', 'upos': 'ADV', 'lemma': 'голосно'},
#   {'word': 'розмовляли', 'upos': 'VERB', 'lemma': 'розмовляти'}),
#  ({'word': 'розмовляли', 'upos': 'VERB', 'lemma': 'розмовляти'},
#   {'word': 'по', 'upos': 'ADP', 'lemma': 'по'},
#   {'word': 'телефону', 'upos': 'NOUN', 'lemma': 'телефон'}),
#  ({'word': 'брудне', 'upos': 'ADJ', 'lemma': 'брудний'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'некомфортно', 'upos': 'ADV', 'lemma': 'некомфортно'},
#   {'word': 'місце', 'upos': 'NOUN', 'lemma': 'місце'}),
#  ({'word': 'некомфортно', 'upos': 'ADV', 'lemma': 'некомфортно'},
#   {'word': 'місце', 'upos': 'NOUN', 'lemma': 'місце'}),
#  ({'word': 'разі', 'upos': 'NOUN', 'lemma': 'раз'},
#   {'word': 'якщо', 'upos': 'SCONJ', 'lemma': 'якщо'},
#   {'word': 'нема', 'upos': 'VERB', 'lemma': 'немати'}),
#  ({'word': 'нема', 'upos': 'VERB', 'lemma': 'немати'},
#   {'word': 'інших', 'upos': 'DET', 'lemma': 'інший'},
#   {'word': 'варіантів', 'upos': 'NOUN', 'lemma': 'варіант'}),
#  ({'word': 'нема', 'upos': 'VERB', 'lemma': 'немати'},
#   {'word': 'інших', 'upos': 'DET', 'lemma': 'інший'},
#   {'word': 'варіантів', 'upos': 'NOUN', 'lemma': 'варіант'},
#   {'word': 'заселили', 'upos': 'VERB', 'lemma': 'заселити'}),
#  ({'word': 'заселили', 'upos': 'VERB', 'lemma': 'заселити'},
#   {'word': 'після', 'upos': 'ADP', 'lemma': 'після'},
#   {'word': '12', 'upos': 'NUM', 'lemma': '12'},
#   {'word': 'години', 'upos': 'NOUN', 'lemma': 'година'}),
#  ({'word': 'години', 'upos': 'NOUN', 'lemma': 'година'},
#   {'word': 'ночі', 'upos': 'NOUN', 'lemma': 'ніч'}),
#  ({'word': 'вказано', 'upos': 'VERB', 'lemma': 'вказати'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'зо', 'upos': 'ADP', 'lemma': 'зо'},
#   {'word': 'заселення', 'upos': 'NOUN', 'lemma': 'заселення'}),
#  ({'word': 'заселення', 'upos': 'NOUN', 'lemma': 'заселення'},
#   {'word': 'до', 'upos': 'ADP', 'lemma': 'до'},
#   {'word': 'опівночі', 'upos': 'NOUN', 'lemma': 'опівніч'}),
#  ({'word': 'дозволили', 'upos': 'VERB', 'lemma': 'дозволити'},
#   {'word': 'поставити', 'upos': 'VERB', 'lemma': 'поставити'}),
#  ({'word': 'поставити', 'upos': 'VERB', 'lemma': 'поставити'},
#   {'word': 'безкоштовно', 'upos': 'ADV', 'lemma': 'безкоштовно'}),
#  ({'word': 'поставити', 'upos': 'VERB', 'lemma': 'поставити'},
#   {'word': 'безкоштовно', 'upos': 'ADV', 'lemma': 'безкоштовно'},
#   {'word': 'автомобіль', 'upos': 'NOUN', 'lemma': 'автомобіль'}),
#  ({'word': 'автомобіль', 'upos': 'NOUN', 'lemma': 'автомобіль'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': 'території', 'upos': 'NOUN', 'lemma': 'територія'}),
#  ({'word': 'коридорі', 'upos': 'NOUN', 'lemma': 'коридор'},
#   {'word': 'дірки', 'upos': 'NOUN', 'lemma': 'дірка'}),
#  ({'word': 'дірки', 'upos': 'NOUN', 'lemma': 'дірка'},
#   {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#   {'word': 'стінах', 'upos': 'NOUN', 'lemma': 'стіна'}),
#  ({'word': 'лячно', 'upos': 'ADV', 'lemma': 'лячно'},
#   {'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#   {'word': 'ходити', 'upos': 'VERB', 'lemma': 'ходити'}),
#  ({'word': 'туалет', 'upos': 'NOUN', 'lemma': 'туалет'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'душ', 'upos': 'NOUN', 'lemma': 'душ'}),
#  ({'word': 'душ', 'upos': 'NOUN', 'lemma': 'душ'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': 'поверсі', 'upos': 'NOUN', 'lemma': 'поверх'}),
#  ({'word': 'матрац', 'upos': 'NOUN', 'lemma': 'матрац'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': 'ліжку', 'upos': 'NOUN', 'lemma': 'ліжко'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'поганий', 'upos': 'ADJ', 'lemma': 'поганий'}),
#  ({'word': 'пружини', 'upos': 'NOUN', 'lemma': 'пружина'},
#   {'word': 'боляче', 'upos': 'ADV', 'lemma': 'боляче'},
#   {'word': 'давлять', 'upos': 'VERB', 'lemma': 'давити'}),
#  ({'word': 'боляче', 'upos': 'ADV', 'lemma': 'боляче'},
#   {'word': 'давлять', 'upos': 'VERB', 'lemma': 'давити'}),
#  ({'word': 'давлять', 'upos': 'VERB', 'lemma': 'давити'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'боки', 'upos': 'NOUN', 'lemma': 'бік'}),
#  ({'word': 'брудний', 'upos': 'ADJ', 'lemma': 'брудний'},
#   {'word': '.', 'upos': 'PUNCT', 'lemma': '.'},
#   {'word': 'матрацників', 'upos': 'NOUN', 'lemma': 'матрацник'}),
#  ({'word': 'матрацників', 'upos': 'NOUN', 'lemma': 'матрацник'},
#   {'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'}),
#  ({'word': 'постільна', 'upos': 'ADJ', 'lemma': 'постільний'},
#   {'word': 'білизна', 'upos': 'ADJ', 'lemma': 'білизний'}),
#  ({'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'},
#   {'word': '.', 'upos': 'PUNCT', 'lemma': '.'},
#   {'word': 'постільна', 'upos': 'ADJ', 'lemma': 'постільний'},
#   {'word': 'білизна', 'upos': 'ADJ', 'lemma': 'білизний'}),
#  ({'word': 'білизна', 'upos': 'ADJ', 'lemma': 'білизний'},
#   {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#   {'word': 'якоїсь', 'upos': 'DET', 'lemma': 'якийсь'},
#   {'word': 'синтетики', 'upos': 'NOUN', 'lemma': 'синтетика'}),
#  ({'word': 'вікна', 'upos': 'NOUN', 'lemma': 'вікно'},
#   {'word': 'металопластикові', 'upos': 'ADJ', 'lemma': 'металопластиковий'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#   {'word': 'чутно', 'upos': 'ADV', 'lemma': 'чутно'}),
#  ({'word': 'чутно', 'upos': 'ADV', 'lemma': 'чутно'},
#   {'word': 'зранку', 'upos': 'ADV', 'lemma': 'зранку'}),
#  ({'word': 'чутно', 'upos': 'ADV', 'lemma': 'чутно'},
#   {'word': 'зранку', 'upos': 'ADV', 'lemma': 'зранку'},
#   {'word': 'звуки', 'upos': 'NOUN', 'lemma': 'звук'}),
#  ({'word': 'звуки', 'upos': 'NOUN', 'lemma': 'звук'},
#   {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#   {'word': 'вулиці', 'upos': 'NOUN', 'lemma': 'вулиця'}),
#  ({'word': 'вулиці', 'upos': 'NOUN', 'lemma': 'вулиця'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'що', 'upos': 'SCONJ', 'lemma': 'що'},
#   {'word': 'заважало', 'upos': 'VERB', 'lemma': 'заважати'}),
#  ({'word': 'заважало', 'upos': 'VERB', 'lemma': 'заважати'},
#   {'word': 'відпочивати', 'upos': 'VERB', 'lemma': 'відпочивати'}),
#  ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': 'цього', 'upos': 'DET', 'lemma': 'цей'},
#   {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#  ({'word': 'рази', 'upos': 'NOUN', 'lemma': 'раз'},
#   {'word': 'менша', 'upos': 'ADJ', 'lemma': 'менший'}),
#  ({'word': 'менша', 'upos': 'ADJ', 'lemma': 'менший'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'}),
#  ({'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'},
#   {'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#   {'word': 'би', 'upos': 'AUX', 'lemma': 'би'},
#   {'word': 'пробачити', 'upos': 'VERB', 'lemma': 'пробачити'}),
#  ({'word': 'пристойні', 'upos': 'ADJ', 'lemma': 'пристойний'},
#   {'word': 'апартаменти', 'upos': 'NOUN', 'lemma': 'апартамент'}),
#  ({'word': 'коштує', 'upos': 'VERB', 'lemma': 'коштувати'},
#   {'word': 'як', 'upos': 'SCONJ', 'lemma': 'як'},
#   {'word': 'пристойні', 'upos': 'ADJ', 'lemma': 'пристойний'},
#   {'word': 'апартаменти', 'upos': 'NOUN', 'lemma': 'апартамент'}),
#  ({'word': 'тому', 'upos': 'ADV', 'lemma': 'тому'},
#   {'word': 'і', 'upos': 'PART', 'lemma': 'і'},
#   {'word': 'порівнюю', 'upos': 'VERB', 'lemma': 'порівнювати'}),
#  ({'word': 'ціновою', 'upos': 'ADJ', 'lemma': 'ціновий'},
#   {'word': 'групою', 'upos': 'NOUN', 'lemma': 'група'}),
#  ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'був', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'бойлер', 'upos': 'NOUN', 'lemma': 'бойлер'}),
#  ({'word': 'бойлер', 'upos': 'NOUN', 'lemma': 'бойлер'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'що', 'upos': 'SCONJ', 'lemma': 'що'},
#   {'word': 'дало', 'upos': 'VERB', 'lemma': 'дати'}),
#  ({'word': 'дало', 'upos': 'VERB', 'lemma': 'дати'},
#   {'word': 'доступ', 'upos': 'NOUN', 'lemma': 'доступ'}),
#  ({'word': 'гарячої', 'upos': 'ADJ', 'lemma': 'гарячий'},
#   {'word': 'води', 'upos': 'NOUN', 'lemma': 'вода'}),
#  ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'був', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'бойлер', 'upos': 'NOUN', 'lemma': 'бойлер'}),
#  ({'word': 'бойлер', 'upos': 'NOUN', 'lemma': 'бойлер'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'що', 'upos': 'SCONJ', 'lemma': 'що'},
#   {'word': 'дало', 'upos': 'VERB', 'lemma': 'дати'}),
#  ({'word': 'дало', 'upos': 'VERB', 'lemma': 'дати'},
#   {'word': 'доступ', 'upos': 'NOUN', 'lemma': 'доступ'}),
#  ({'word': 'гарячої', 'upos': 'ADJ', 'lemma': 'гарячий'},
#   {'word': 'води', 'upos': 'NOUN', 'lemma': 'вода'}),
#  ({'word': 'виделку', 'upos': 'NOUN', 'lemma': 'виделка'},
#   {'word': 'та', 'upos': 'CCONJ', 'lemma': 'та'},
#   {'word': 'ложка', 'upos': 'NOUN', 'lemma': 'ложка'}),
#  ({'word': 'персонал', 'upos': 'NOUN', 'lemma': 'персонал'},
#   {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#   {'word': 'потурбувався', 'upos': 'VERB', 'lemma': 'потурбуватися'}),
#  ({'word': 'колишніх', 'upos': 'ADJ', 'lemma': 'колишній'},
#   {'word': 'гостів', 'upos': 'NOUN', 'lemma': 'гіст'}),
#  ({'word': 'помити', 'upos': 'VERB', 'lemma': 'помити'},
#   {'word': 'після', 'upos': 'ADP', 'lemma': 'після'},
#   {'word': 'колишніх', 'upos': 'ADJ', 'lemma': 'колишній'},
#   {'word': 'гостів', 'upos': 'NOUN', 'lemma': 'гіст'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'холодно', 'upos': 'ADV', 'lemma': 'холодно'}),
#  ({'word': 'холодно', 'upos': 'ADV', 'lemma': 'холодно'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#   {'word': 'захоплюємо', 'upos': 'VERB', 'lemma': 'захоплювати'}),
#  ({'word': 'захоплюємо', 'upos': 'VERB', 'lemma': 'захоплювати'},
#   {'word': 'приміщення', 'upos': 'NOUN', 'lemma': 'приміщення'}),
#  ({'word': 'душ', 'upos': 'NOUN', 'lemma': 'Душ'},
#   {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'зайчик', 'upos': 'NOUN', 'lemma': 'зайчик'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'вентилятор', 'upos': 'NOUN', 'lemma': 'вентилятор'}),
#  ({'word': 'душ', 'upos': 'NOUN', 'lemma': 'Душ'},
#   {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'зайчик', 'upos': 'NOUN', 'lemma': 'зайчик'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'вентилятор', 'upos': 'NOUN', 'lemma': 'вентилятор'}),
#  ({'word': 'тепло', 'upos': 'ADJ', 'lemma': 'Тепло'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'нормальне', 'upos': 'ADJ', 'lemma': 'нормальний'},
#   {'word': 'ліжко', 'upos': 'NOUN', 'lemma': 'ліжко'}),
#  ({'word': 'тепло', 'upos': 'ADJ', 'lemma': 'Тепло'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'нормальне', 'upos': 'ADJ', 'lemma': 'нормальний'}),
#  ({'word': 'ліжко', 'upos': 'NOUN', 'lemma': 'ліжко'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'велике', 'upos': 'ADJ', 'lemma': 'великий'}),
#  ({'word': 'неприємний', 'upos': 'ADJ', 'lemma': 'неприємний'},
#   {'word': 'запах', 'upos': 'NOUN', 'lemma': 'запах'}),
#  ({'word': 'відсутній', 'upos': 'ADJ', 'lemma': 'відсутній'},
#   {'word': 'неприємний', 'upos': 'ADJ', 'lemma': 'неприємний'},
#   {'word': 'запах', 'upos': 'NOUN', 'lemma': 'запах'}),
#  ({'word': 'знаходиться', 'upos': 'VERB', 'lemma': 'знаходитися'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'такому', 'upos': 'DET', 'lemma': 'такий'},
#   {'word': 'місці', 'upos': 'NOUN', 'lemma': 'місце'}),
#  ({'word': 'добратись', 'upos': 'VERB', 'lemma': 'добратися'},
#   {'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'}),
#  ({'word': 'таксі', 'upos': 'NOUN', 'lemma': 'таксі'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'за', 'upos': 'ADP', 'lemma': 'за'},
#   {'word': 'таксі', 'upos': 'NOUN', 'lemma': 'таксі'}),
#  ({'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'},
#   {'word': 'кухні', 'upos': 'NOUN', 'lemma': 'кухня'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'чайник', 'upos': 'NOUN', 'lemma': 'чайник'}),
#  ({'word': 'чайник', 'upos': 'NOUN', 'lemma': 'чайник'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'чайнику', 'upos': 'NOUN', 'lemma': 'чайник'},
#   {'word': 'зацвіла', 'upos': 'VERB', 'lemma': 'зацвілий'}),
#  ({'word': 'зацвіла', 'upos': 'VERB', 'lemma': 'зацвілий'},
#   {'word': 'вода', 'upos': 'NOUN', 'lemma': 'вода'}),
#  ({'word': 'став', 'upos': 'VERB', 'lemma': 'стати'},
#   {'word': 'чайником', 'upos': 'NOUN', 'lemma': 'чайник'}),
#  ({'word': 'чайником', 'upos': 'NOUN', 'lemma': 'чайник'},
#   {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#   {'word': 'пліснявою', 'upos': 'ADJ', 'lemma': 'пліснява'}),
#  ({'word': 'ванна', 'upos': 'ADJ', 'lemma': 'ванна'},
#   {'word': 'кімната', 'upos': 'NOUN', 'lemma': 'кімната'}),
#  ({'word': 'кімната', 'upos': 'NOUN', 'lemma': 'кімната'},
#   {'word': 'чиста', 'upos': 'ADJ', 'lemma': 'чистий'}),
#  ({'word': 'чиста', 'upos': 'ADJ', 'lemma': 'чистий'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'шампунь', 'upos': 'NOUN', 'lemma': 'шампунь'}),
#  ({'word': 'шампунь', 'upos': 'NOUN', 'lemma': 'шампунь'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'гель', 'upos': 'NOUN', 'lemma': 'гель'}),
#  ({'word': 'упаковані', 'upos': 'ADJ', 'lemma': 'упакований'},
#   {'word': 'тапочки', 'upos': 'NOUN', 'lemma': 'тапічка'}),
#  ({'word': 'ванна', 'upos': 'ADJ', 'lemma': 'ванна'},
#   {'word': 'кімната', 'upos': 'NOUN', 'lemma': 'кімната'}),
#  ({'word': 'кімната', 'upos': 'NOUN', 'lemma': 'кімната'},
#   {'word': 'чиста', 'upos': 'ADJ', 'lemma': 'чистий'}),
#  ({'word': 'чиста', 'upos': 'ADJ', 'lemma': 'чистий'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'шампунь', 'upos': 'NOUN', 'lemma': 'шампунь'}),
#  ({'word': 'шампунь', 'upos': 'NOUN', 'lemma': 'шампунь'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'гель', 'upos': 'NOUN', 'lemma': 'гель'}),
#  ({'word': 'упаковані', 'upos': 'ADJ', 'lemma': 'упакований'},
#   {'word': 'тапочки', 'upos': 'NOUN', 'lemma': 'тапічка'}),
#  ({'word': 'гаряча', 'upos': 'ADJ', 'lemma': 'гарячий'},
#   {'word': 'вода', 'upos': 'NOUN', 'lemma': 'вода'}),
#  ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'вентилятор', 'upos': 'NOUN', 'lemma': 'вентилятор'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'жарко', 'upos': 'ADV', 'lemma': 'жарко'}),
#  ({'word': 'маленький', 'upos': 'ADJ', 'lemma': 'маленький'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'}),
#  ({'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'чайник', 'upos': 'NOUN', 'lemma': 'чайник'}),
#  ({'word': 'шафа', 'upos': 'NOUN', 'lemma': 'шафа'},
#   {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#   {'word': 'вішалка', 'upos': 'NOUN', 'lemma': 'вішалка'}),
#  ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#   {'word': 'було', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'було', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'телевізора', 'upos': 'NOUN', 'lemma': 'телевізор'}),
#  ({'word': 'був', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'балкон', 'upos': 'NOUN', 'lemma': 'балкон'}),
#  ({'word': 'врахувати', 'upos': 'VERB', 'lemma': 'врахувати'},
#   {'word': 'ціну', 'upos': 'NOUN', 'lemma': 'ціна'}),
#  ({'word': 'ціну', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': 'за', 'upos': 'ADP', 'lemma': 'за'},
#   {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'},
#   {'word': 'претензій', 'upos': 'NOUN', 'lemma': 'претензія'}),
#  ({'word': 'трохи', 'upos': 'ADV', 'lemma': 'трохи'},
#   {'word': 'двери', 'upos': 'PROPN', 'lemma': 'двер'}),
#  ({'word': 'двери', 'upos': 'PROPN', 'lemma': 'двер'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'душовій', 'upos': 'NOUN', 'lemma': 'душова'}),
#  ({'word': 'щільно', 'upos': 'ADV', 'lemma': 'щільно'},
#   {'word': 'закриваються', 'upos': 'VERB', 'lemma': 'закриватися'}),
#  ({'word': 'платна', 'upos': 'ADJ', 'lemma': 'платний'},
#   {'word': 'парковка', 'upos': 'NOUN', 'lemma': 'парковка'}),
#  ({'word': 'пропонувати', 'upos': 'VERB', 'lemma': 'пропонувати'},
#   {'word': 'нічого', 'upos': 'PRON', 'lemma': 'ніщо'},
#   {'word': 'платна', 'upos': 'ADJ', 'lemma': 'платний'},
#   {'word': 'парковка', 'upos': 'NOUN', 'lemma': 'парковка'}),
#  ({'word': 'парковка', 'upos': 'NOUN', 'lemma': 'парковка'},
#   {'word': 'душ', 'upos': 'NOUN', 'lemma': 'Душ'}),
#  ({'word': 'загальний', 'upos': 'ADJ', 'lemma': 'загальний'},
#   {'word': 'сам', 'upos': 'DET', 'lemma': 'сам'},
#   {'word': 'готель', 'upos': 'NOUN', 'lemma': 'готель'}),
#  ({'word': 'готель', 'upos': 'NOUN', 'lemma': 'готель'},
#   {'word': 'розташований', 'upos': 'ADJ', 'lemma': 'розташований'}),
#  ({'word': 'старому', 'upos': 'ADJ', 'lemma': 'старий'},
#   {'word': 'будинку', 'upos': 'NOUN', 'lemma': 'будинок'}),
#  ({'word': 'розташований', 'upos': 'ADJ', 'lemma': 'розташований'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'старому', 'upos': 'ADJ', 'lemma': 'старий'},
#   {'word': 'будинку', 'upos': 'NOUN', 'lemma': 'будинок'}),
#  ({'word': 'де', 'upos': 'ADV', 'lemma': 'де'},
#   {'word': 'ще', 'upos': 'ADV', 'lemma': 'ще'},
#   {'word': 'розміщені', 'upos': 'ADJ', 'lemma': 'розміщений'}),
#  ({'word': 'ще', 'upos': 'ADV', 'lemma': 'ще'},
#   {'word': 'розміщені', 'upos': 'ADJ', 'lemma': 'розміщений'}),
#  ({'word': 'будинку', 'upos': 'NOUN', 'lemma': 'будинок'},
#   {'word': 'де', 'upos': 'ADV', 'lemma': 'де'},
#   {'word': 'ще', 'upos': 'ADV', 'lemma': 'ще'},
#   {'word': 'розміщені', 'upos': 'ADJ', 'lemma': 'розміщений'}),
#  ({'word': 'дешеві', 'upos': 'ADJ', 'lemma': 'дешевий'},
#   {'word': 'хостели', 'upos': 'NOUN', 'lemma': 'хостель'}),
#  ({'word': 'розміщені', 'upos': 'ADJ', 'lemma': 'розміщений'},
#   {'word': 'дешеві', 'upos': 'ADJ', 'lemma': 'дешевий'},
#   {'word': 'хостели', 'upos': 'NOUN', 'lemma': 'хостель'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'приємна', 'upos': 'ADJ', 'lemma': 'приємний'}),
#  ({'word': 'приємна', 'upos': 'ADJ', 'lemma': 'приємний'},
#   {'word': 'обстановка', 'upos': 'NOUN', 'lemma': 'обстановка'}),
#  ({'word': 'обстановка', 'upos': 'NOUN', 'lemma': 'обстановка'},
#   {'word': '.', 'upos': 'PUNCT', 'lemma': '.'},
#   {'word': 'перестрілки', 'upos': 'NOUN', 'lemma': 'перестрілка'}),
#  ({'word': 'перестрілки', 'upos': 'NOUN', 'lemma': 'перестрілка'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'готелі', 'upos': 'NOUN', 'lemma': 'готель'}),
#  ({'word': 'занадто', 'upos': 'ADV', 'lemma': 'занадто'},
#   {'word': 'тонкі', 'upos': 'ADJ', 'lemma': 'тонкий'}),
#  ({'word': 'тонкі', 'upos': 'ADJ', 'lemma': 'тонкий'},
#   {'word': 'що', 'upos': 'SCONJ', 'lemma': 'що'},
#   {'word': 'все', 'upos': 'PRON', 'lemma': 'все'},
#   {'word': 'чути', 'upos': 'VERB', 'lemma': 'чути'}),
#  ({'word': 'чути', 'upos': 'VERB', 'lemma': 'чути'},
#   {'word': 'що', 'upos': 'SCONJ', 'lemma': 'що'},
#   {'word': 'роблять', 'upos': 'VERB', 'lemma': 'робити'}),
#  ({'word': 'роблять', 'upos': 'VERB', 'lemma': 'робити'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'говорять', 'upos': 'VERB', 'lemma': 'говорити'}),
#  ({'word': 'роблять', 'upos': 'VERB', 'lemma': 'робити'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'говорять', 'upos': 'VERB', 'lemma': 'говорити'},
#   {'word': 'сусіди', 'upos': 'NOUN', 'lemma': 'сусід'}),
#  ({'word': 'найдешевші', 'upos': 'ADJ', 'lemma': 'найдешевшя'},
#   {'word': 'ціні', 'upos': 'NOUN', 'lemma': 'ціна'}),
#  ({'word': 'ціні', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': 'по', 'upos': 'ADP', 'lemma': 'по'},
#   {'word': 'києву', 'upos': 'PROPN', 'lemma': 'Київ'}),
#  ({'word': 'хороший', 'upos': 'ADJ', 'lemma': 'хороший'},
#   {'word': 'варіант', 'upos': 'NOUN', 'lemma': 'варіант'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'хороший', 'upos': 'ADJ', 'lemma': 'хороший'}),
#  ({'word': 'хороший', 'upos': 'ADJ', 'lemma': 'хороший'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'приємний', 'upos': 'ADJ', 'lemma': 'приємний'},
#   {'word': 'адміністратор', 'upos': 'NOUN', 'lemma': 'адміністратор'}),
#  ({'word': 'хороший', 'upos': 'ADJ', 'lemma': 'хороший'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'приємний', 'upos': 'ADJ', 'lemma': 'приємний'}),
#  ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#   {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#  ({'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'душ', 'upos': 'NOUN', 'lemma': 'душ'}),
#  ({'word': 'гаряча', 'upos': 'ADJ', 'lemma': 'гарячий'},
#   {'word': 'вода', 'upos': 'NOUN', 'lemma': 'вода'}),
#  ({'word': 'система', 'upos': 'NOUN', 'lemma': 'система'},
#   {'word': 'блокова', 'upos': 'NOUN', 'lemma': 'блоковий'}),
#  ({'word': 'ванна', 'upos': 'ADJ', 'lemma': 'ванна'},
#   {'word': 'кімната', 'upos': 'NOUN', 'lemma': 'кімната'}),
#  ({'word': 'кімната', 'upos': 'NOUN', 'lemma': 'кімната'},
#   {'word': 'спільна', 'upos': 'ADJ', 'lemma': 'спільний'}),
#  ({'word': 'писали', 'upos': 'VERB', 'lemma': 'писати'},
#   {'word': 'раніше', 'upos': 'ADV', 'lemma': 'раніше'}),
#  ({'word': 'писали', 'upos': 'VERB', 'lemma': 'писати'},
#   {'word': 'раніше', 'upos': 'ADV', 'lemma': 'раніше'},
#   {'word': 'люди', 'upos': 'NOUN', 'lemma': 'людина'}),
#  ({'word': 'коридорі', 'upos': 'NOUN', 'lemma': 'коридор'},
#   {'word': 'ходять', 'upos': 'VERB', 'lemma': 'ходити'}),
#  ({'word': 'ходять', 'upos': 'VERB', 'lemma': 'ходити'},
#   {'word': 'іноземці', 'upos': 'NOUN', 'lemma': 'іноземець'}),
#  ({'word': 'іноземці', 'upos': 'NOUN', 'lemma': 'іноземець'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'схоже', 'upos': 'ADJ', 'lemma': 'схожий'}),
#  ({'word': 'старий', 'upos': 'ADJ', 'lemma': 'старий'},
#   {'word': 'гуртожиток', 'upos': 'NOUN', 'lemma': 'гуртожиток'}),
#  ({'word': 'схоже', 'upos': 'ADJ', 'lemma': 'схожий'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': 'старий', 'upos': 'ADJ', 'lemma': 'старий'},
#   {'word': 'гуртожиток', 'upos': 'NOUN', 'lemma': 'гуртожиток'}),
#  ({'word': 'переночувати', 'upos': 'VERB', 'lemma': 'переночувати'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': 'одну', 'upos': 'NUM', 'lemma': 'один'},
#   {'word': 'ніч', 'upos': 'NOUN', 'lemma': 'ніч'}),
#  ({'word': 'комфортніше', 'upos': 'ADV', 'lemma': 'комфортніше'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'якби', 'upos': 'SCONJ', 'lemma': 'якби'},
#   {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'був', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'сипучий', 'upos': 'ADJ', 'lemma': 'сипучий'}),
#  ({'word': 'сипучий', 'upos': 'ADJ', 'lemma': 'сипучий'},
#   {'word': 'матрац', 'upos': 'NOUN', 'lemma': 'матрац'}),
#  ({'word': 'попався', 'upos': 'VERB', 'lemma': 'попастися'},
#   {'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'сипучий', 'upos': 'ADJ', 'lemma': 'сипучий'},
#   {'word': 'матрац', 'upos': 'NOUN', 'lemma': 'матрац'}),
#  ({'word': 'одразу', 'upos': 'ADV', 'lemma': 'одразу'},
#   {'word': 'прокидаєшся', 'upos': 'VERB', 'lemma': 'прокидатися'}),
#  ({'word': 'перевертається', 'upos': 'VERB', 'lemma': 'перевертатися'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'одразу', 'upos': 'ADV', 'lemma': 'одразу'},
#   {'word': 'прокидаєшся', 'upos': 'VERB', 'lemma': 'прокидатися'}),
#  ({'word': 'неоднозначний', 'upos': 'ADJ', 'lemma': 'неоднозначний'},
#   {'word': 'досвід', 'upos': 'NOUN', 'lemma': 'досвід'}),
#  ({'word': 'досвід', 'upos': 'NOUN', 'lemma': 'досвід'},
#   {'word': 'достатньо', 'upos': 'ADV', 'lemma': 'достатньо'},
#   {'word': 'зручний', 'upos': 'ADJ', 'lemma': 'зручний'},
#   {'word': 'заїзд', 'upos': 'NOUN', 'lemma': 'заїзд'}),
#  ({'word': 'достатньо', 'upos': 'ADV', 'lemma': 'достатньо'},
#   {'word': 'зручний', 'upos': 'ADJ', 'lemma': 'зручний'}),
#  ({'word': 'зручний', 'upos': 'ADJ', 'lemma': 'зручний'},
#   {'word': 'заїзд', 'upos': 'NOUN', 'lemma': 'заїзд'}),
#  ({'word': 'меж', 'upos': 'NOUN', 'lemma': 'межа'},
#   {'word': 'києва', 'upos': 'PROPN', 'lemma': 'Київ'}),
#  ({'word': 'велика', 'upos': 'ADJ', 'lemma': 'великий'},
#   {'word': 'парковка', 'upos': 'NOUN', 'lemma': 'парковка'}),
#  ({'word': 'місяця', 'upos': 'NOUN', 'lemma': 'місяць'},
#   {'word': 'достатньо', 'upos': 'ADV', 'lemma': 'достатньо'}),
#  ({'word': 'достатньо', 'upos': 'ADV', 'lemma': 'достатньо'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'навіть', 'upos': 'PART', 'lemma': 'навіть'},
#   {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'безкоштовні', 'upos': 'ADJ', 'lemma': 'безкоштовний'},
#   {'word': 'місця', 'upos': 'NOUN', 'lemma': 'місце'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'безкоштовні', 'upos': 'ADJ', 'lemma': 'безкоштовний'},
#   {'word': 'місця', 'upos': 'NOUN', 'lemma': 'місце'}),
#  ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'достатньо', 'upos': 'ADV', 'lemma': 'достатньо'},
#   {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#  ({'word': 'достатньо', 'upos': 'ADV', 'lemma': 'достатньо'},
#   {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#  ({'word': 'випадково', 'upos': 'ADV', 'lemma': 'випадково'},
#   {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#   {'word': 'припиняти', 'upos': 'VERB', 'lemma': 'припиняти'}),
#  ({'word': 'припиняти', 'upos': 'VERB', 'lemma': 'припиняти'},
#   {'word': 'прости', 'upos': 'NOUN', 'lemma': 'прости'}),
#  ({'word': 'покращений', 'upos': 'ADJ', 'lemma': 'покращений'},
#   {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'делюкс', 'upos': 'NOUN', 'lemma': 'Делюкс'},
#   {'word': 'чи', 'upos': 'CCONJ', 'lemma': 'чи'},
#   {'word': 'покращений', 'upos': 'ADJ', 'lemma': 'покращений'},
#   {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': '-', 'upos': 'PUNCT', 'lemma': '-'},
#   {'word': 'без', 'upos': 'ADP', 'lemma': 'без'},
#   {'word': 'різниці', 'upos': 'NOUN', 'lemma': 'різник'}),
#  ({'word': 'рівно', 'upos': 'ADV', 'lemma': 'рівно'},
#   {'word': 'душ', 'upos': 'NOUN', 'lemma': 'душ'}),
#  ({'word': 'душ', 'upos': 'NOUN', 'lemma': 'душ'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'туалет', 'upos': 'NOUN', 'lemma': 'туалет'}),
#  ({'word': 'туалет', 'upos': 'NOUN', 'lemma': 'туалет'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'блоці', 'upos': 'NOUN', 'lemma': 'блок'}),
#  ({'word': 'спільний', 'upos': 'ADJ', 'lemma': 'спільний'},
#   {'word': 'для', 'upos': 'ADP', 'lemma': 'для'},
#   {'word': '2', 'upos': 'NUM', 'lemma': '2'},
#   {'word': 'номерів', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'випадково', 'upos': 'ADV', 'lemma': 'випадково'},
#   {'word': 'забрели', 'upos': 'VERB', 'lemma': 'забрети'}),
#  ({'word': 'пропадете', 'upos': 'VERB', 'lemma': 'пропадитий'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'гуртожиток', 'upos': 'NOUN', 'lemma': 'гуртожиток'}),
#  ({'word': 'іноземних', 'upos': 'ADJ', 'lemma': 'іноземний'},
#   {'word': 'громадян', 'upos': 'NOUN', 'lemma': 'громадянин'}),
#  ({'word': 'гуртожиток', 'upos': 'NOUN', 'lemma': 'гуртожиток'},
#   {'word': 'іноземних', 'upos': 'ADJ', 'lemma': 'іноземний'},
#   {'word': 'громадян', 'upos': 'NOUN', 'lemma': 'громадянин'}),
#  ({'word': 'громадян', 'upos': 'NOUN', 'lemma': 'громадянин'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'що', 'upos': 'SCONJ', 'lemma': 'що'},
#   {'word': 'виглядають', 'upos': 'VERB', 'lemma': 'виглядати'}),
#  ({'word': 'виглядають', 'upos': 'VERB', 'lemma': 'виглядати'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'наче', 'upos': 'SCONJ', 'lemma': 'наче'},
#   {'word': 'біженці', 'upos': 'NOUN', 'lemma': 'біженець'}),
#  ({'word': 'комфортні', 'upos': 'ADJ', 'lemma': 'комфортний'},
#   {'word': 'умови', 'upos': 'NOUN', 'lemma': 'умова'}),
#  ({'word': 'невисоку', 'upos': 'ADJ', 'lemma': 'невисокий'},
#   {'word': 'ціну', 'upos': 'NOUN', 'lemma': 'ціна'}),
#  ({'word': 'умови', 'upos': 'NOUN', 'lemma': 'умова'},
#   {'word': 'за', 'upos': 'ADP', 'lemma': 'за'},
#   {'word': 'невисоку', 'upos': 'ADJ', 'lemma': 'невисокий'},
#   {'word': 'ціну', 'upos': 'NOUN', 'lemma': 'ціна'}),
#  ({'word': 'готель', 'upos': 'NOUN', 'lemma': 'готель'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'старенький', 'upos': 'ADJ', 'lemma': 'старенький'}),
#  ({'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'зроблений', 'upos': 'ADJ', 'lemma': 'зроблений'}),
#  ({'word': 'зроблений', 'upos': 'ADJ', 'lemma': 'зроблений'},
#   {'word': 'ремонт', 'upos': 'NOUN', 'lemma': 'ремонт'}),
#  ({'word': 'нові', 'upos': 'ADJ', 'lemma': 'новий'},
#   {'word': 'меблі', 'upos': 'NOUN', 'lemma': 'меблий'}),
#  ({'word': 'ремонт', 'upos': 'NOUN', 'lemma': 'ремонт'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'нові', 'upos': 'ADJ', 'lemma': 'новий'},
#   {'word': 'меблі', 'upos': 'NOUN', 'lemma': 'меблий'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'приємний', 'upos': 'ADJ', 'lemma': 'приємний'}),
#  ({'word': 'приємний', 'upos': 'ADJ', 'lemma': 'приємний'},
#   {'word': 'та', 'upos': 'CCONJ', 'lemma': 'та'},
#   {'word': 'ввічливий', 'upos': 'ADJ', 'lemma': 'ввічливий'},
#   {'word': 'адміністратор', 'upos': 'NOUN', 'lemma': 'адміністратор'}),
#  ({'word': 'приємний', 'upos': 'ADJ', 'lemma': 'приємний'},
#   {'word': 'та', 'upos': 'CCONJ', 'lemma': 'та'},
#   {'word': 'ввічливий', 'upos': 'ADJ', 'lemma': 'ввічливий'}),
#  ({'word': 'адміністратор', 'upos': 'NOUN', 'lemma': 'адміністратор'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'який', 'upos': 'DET', 'lemma': 'який'},
#   {'word': 'пішов', 'upos': 'VERB', 'lemma': 'піти'}),
#  ({'word': 'пішов', 'upos': 'VERB', 'lemma': 'піти'},
#   {'word': 'назустріч', 'upos': 'ADP', 'lemma': 'назустріч'},
#   {'word': 'нашій', 'upos': 'DET', 'lemma': 'наш'},
#   {'word': 'групі', 'upos': 'NOUN', 'lemma': 'група'}),
#  ({'word': 'проблем', 'upos': 'NOUN', 'lemma': 'проблема'},
#   {'word': 'дозволив', 'upos': 'VERB', 'lemma': 'дозволити'},
#   {'word': 'залишити', 'upos': 'VERB', 'lemma': 'залишити'}),
#  ({'word': 'дозволив', 'upos': 'VERB', 'lemma': 'дозволити'},
#   {'word': 'залишити', 'upos': 'VERB', 'lemma': 'залишити'}),
#  ({'word': 'залишити', 'upos': 'VERB', 'lemma': 'залишити'},
#   {'word': 'речі', 'upos': 'NOUN', 'lemma': 'річ'}),
#  ({'word': 'цілий', 'upos': 'ADJ', 'lemma': 'цілий'},
#   {'word': 'день', 'upos': 'NOUN', 'lemma': 'день'}),
#  ({'word': 'день', 'upos': 'NOUN', 'lemma': 'день'},
#   {'word': 'зберігання', 'upos': 'NOUN', 'lemma': 'зберігання'}),
#  ({'word': 'обслуговування', 'upos': 'NOUN', 'lemma': 'обслуговування'},
#   {'word': 'та', 'upos': 'CCONJ', 'lemma': 'та'},
#   {'word': 'умови', 'upos': 'NOUN', 'lemma': 'умова'}),
#  ({'word': 'найкраще', 'upos': 'ADJ', 'lemma': 'найкраще'},
#   {'word': 'поєднання', 'upos': 'NOUN', 'lemma': 'поєднання'}),
#  ({'word': 'поєднання', 'upos': 'NOUN', 'lemma': 'поєднання'},
#   {'word': 'ціни', 'upos': 'NOUN', 'lemma': 'ціна'}),
#  ({'word': 'ціни', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': 'та', 'upos': 'CCONJ', 'lemma': 'та'},
#   {'word': 'якості', 'upos': 'NOUN', 'lemma': 'якість'}),
#  ({'word': 'дістатись', 'upos': 'VERB', 'lemma': 'дістатися'},
#   {'word': 'до', 'upos': 'ADP', 'lemma': 'до'},
#   {'word': 'готелю', 'upos': 'NOUN', 'lemma': 'готель'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'легко', 'upos': 'ADV', 'lemma': 'легко'}),
#  ({'word': 'легко', 'upos': 'ADV', 'lemma': 'легко'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'від', 'upos': 'ADP', 'lemma': 'від'},
#   {'word': 'метро', 'upos': 'NOUN', 'lemma': 'метро'}),
#  ({'word': 'метро', 'upos': 'NOUN', 'lemma': 'метро'},
#   {'word': "лук'янівська", 'upos': 'ADJ', 'lemma': 'лук’янівський'}),
#  ({'word': 'дістатись', 'upos': 'VERB', 'lemma': 'дістатися'},
#   {'word': 'до', 'upos': 'ADP', 'lemma': 'до'},
#   {'word': 'готелю', 'upos': 'NOUN', 'lemma': 'готель'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'легко', 'upos': 'ADV', 'lemma': 'легко'}),
#  ({'word': "лук'янівська", 'upos': 'ADJ', 'lemma': 'лук’янівський'},
#   {'word': '3', 'upos': 'NUM', 'lemma': '3'},
#   {'word': 'зупинки', 'upos': 'NOUN', 'lemma': 'зупинка'}),
#  ({'word': 'метро', 'upos': 'NOUN', 'lemma': 'метро'},
#   {'word': "лук'янівська", 'upos': 'ADJ', 'lemma': 'лук’янівський'},
#   {'word': '3', 'upos': 'NUM', 'lemma': '3'},
#   {'word': 'зупинки', 'upos': 'NOUN', 'lemma': 'зупинка'}),
#  ({'word': 'зупинки', 'upos': 'NOUN', 'lemma': 'зупинка'},
#   {'word': 'тролейбусом', 'upos': 'NOUN', 'lemma': 'тролейбус'}),
#  ({'word': 'тролейбусом', 'upos': 'NOUN', 'lemma': 'тролейбус'},
#   {'word': 'або', 'upos': 'CCONJ', 'lemma': 'або'},
#   {'word': 'маршруткою', 'upos': 'NOUN', 'lemma': 'маршрутка'}),
#  ({'word': 'хвилин', 'upos': 'NOUN', 'lemma': 'хвилина'},
#   {'word': 'пішки', 'upos': 'ADV', 'lemma': 'пішки'}),
#  ({'word': '8', 'upos': 'ADJ', 'lemma': '8'},
#   {'word': 'поверсі', 'upos': 'NOUN', 'lemma': 'поверх'}),
#  ({'word': 'двомісному', 'upos': 'ADJ', 'lemma': 'двомісний'},
#   {'word': 'покращеному', 'upos': 'ADJ', 'lemma': 'покращений'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'покращеному', 'upos': 'ADJ', 'lemma': 'покращений'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#   {'word': 'душем', 'upos': 'NOUN', 'lemma': 'душь'}),
#  ({'word': 'душем', 'upos': 'NOUN', 'lemma': 'душь'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'санвузлом', 'upos': 'NOUN', 'lemma': 'санвузл'}),
#  ({'word': 'зручне', 'upos': 'ADJ', 'lemma': 'зручний'},
#   {'word': 'ліжко', 'upos': 'NOUN', 'lemma': 'ліжко'}),
#  ({'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'},
#   {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'ліжко', 'upos': 'NOUN', 'lemma': 'ліжко'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'},
#   {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': "м'які", 'upos': 'ADJ', 'lemma': 'м’який'},
#   {'word': 'рушники', 'upos': 'NOUN', 'lemma': 'рушник'}),
#  ({'word': 'маленький', 'upos': 'ADJ', 'lemma': 'маленький'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'}),
#  ({'word': 'привабливий', 'upos': 'ADJ', 'lemma': 'привабливий'},
#   {'word': 'пейзаж', 'upos': 'NOUN', 'lemma': 'пейзазати'}),
#  ({'word': 'пейзаж', 'upos': 'NOUN', 'lemma': 'пейзазати'},
#   {'word': 'міста', 'upos': 'NOUN', 'lemma': 'місто'}),
#  ({'word': 'пейзаж', 'upos': 'NOUN', 'lemma': 'пейзазати'},
#   {'word': 'міста', 'upos': 'NOUN', 'lemma': 'місто'},
#   {'word': 'за', 'upos': 'ADP', 'lemma': 'за'},
#   {'word': 'вікном', 'upos': 'NOUN', 'lemma': 'вікно'}),
#  ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': 'проживання', 'upos': 'NOUN', 'lemma': 'проживання'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'демократична', 'upos': 'ADJ', 'lemma': 'демократичний'}),
#  ({'word': 'бюджетне', 'upos': 'ADJ', 'lemma': 'бюджетний'},
#   {'word': 'житло', 'upos': 'NOUN', 'lemma': 'житло'}),
#  ({'word': 'шукаєте', 'upos': 'VERB', 'lemma': 'шукати'},
#   {'word': 'бюджетне', 'upos': 'ADJ', 'lemma': 'бюджетний'},
#   {'word': 'житло', 'upos': 'NOUN', 'lemma': 'житло'}),
#  ({'word': 'спокійному', 'upos': 'ADJ', 'lemma': 'спокійний'},
#   {'word': 'місці', 'upos': 'NOUN', 'lemma': 'місце'}),
#  ({'word': 'житло', 'upos': 'NOUN', 'lemma': 'житло'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'спокійному', 'upos': 'ADJ', 'lemma': 'спокійний'},
#   {'word': 'місці', 'upos': 'NOUN', 'lemma': 'місце'}),
#  ({'word': 'зручним', 'upos': 'ADJ', 'lemma': 'зручний'},
#   {'word': 'розташуванням', 'upos': 'NOUN', 'lemma': 'розташування'}),
#  ({'word': 'місці', 'upos': 'NOUN', 'lemma': 'місце'},
#   {'word': 'зі', 'upos': 'ADP', 'lemma': 'зі'},
#   {'word': 'зручним', 'upos': 'ADJ', 'lemma': 'зручний'},
#   {'word': 'розташуванням', 'upos': 'NOUN', 'lemma': 'розташування'}),
#  ({'word': 'комфортним', 'upos': 'ADJ', 'lemma': 'комфортний'},
#   {'word': 'проживанням', 'upos': 'NOUN', 'lemma': 'проживання'}),
#  ({'word': 'проживанням', 'upos': 'NOUN', 'lemma': 'проживання'},
#   {'word': '-', 'upos': 'PUNCT', 'lemma': '-'},
#   {'word': 'вам', 'upos': 'PRON', 'lemma': 'ви'},
#   {'word': 'сюди', 'upos': 'ADV', 'lemma': 'сюди'}),
#  ({'word': 'дякую', 'upos': 'VERB', 'lemma': 'дякувати'},
#   {'word': 'керівництву', 'upos': 'NOUN', 'lemma': 'керівництво'}),
#  ({'word': 'керівництву', 'upos': 'NOUN', 'lemma': 'керівництво'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'персоналу', 'upos': 'NOUN', 'lemma': 'персонал'}),
#  ({'word': 'персоналу', 'upos': 'NOUN', 'lemma': 'персонал'},
#   {'word': 'готелю', 'upos': 'NOUN', 'lemma': 'готель'}),
#  ({'word': 'повагою', 'upos': 'NOUN', 'lemma': 'повага'},
#   {'word': 'юрій', 'upos': 'PROPN', 'lemma': 'Юрій'}),
#  ({'word': 'юрій', 'upos': 'PROPN', 'lemma': 'Юрій'},
#   {'word': 'та', 'upos': 'CCONJ', 'lemma': 'та'},
#   {'word': 'марина', 'upos': 'PROPN', 'lemma': 'Марина'}),
#  ({'word': 'покращених', 'upos': 'ADJ', 'lemma': 'покращений'},
#   {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'проживали', 'upos': 'VERB', 'lemma': 'проживати'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'покращених', 'upos': 'ADJ', 'lemma': 'покращений'},
#   {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'тому', 'upos': 'ADV', 'lemma': 'тому'},
#   {'word': 'як', 'upos': 'ADV', 'lemma': 'як'},
#   {'word': 'виглядають', 'upos': 'VERB', 'lemma': 'виглядати'}),
#  ({'word': 'як', 'upos': 'ADV', 'lemma': 'як'},
#   {'word': 'виглядають', 'upos': 'VERB', 'lemma': 'виглядати'}),
#  ({'word': 'покращених', 'upos': 'ADJ', 'lemma': 'покращений'},
#   {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'проживали', 'upos': 'VERB', 'lemma': 'проживати'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'покращених', 'upos': 'ADJ', 'lemma': 'покращений'},
#   {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'тому', 'upos': 'ADV', 'lemma': 'тому'},
#   {'word': 'як', 'upos': 'ADV', 'lemma': 'як'},
#   {'word': 'виглядають', 'upos': 'VERB', 'lemma': 'виглядати'}),
#  ({'word': 'тому', 'upos': 'ADV', 'lemma': 'тому'},
#   {'word': 'як', 'upos': 'ADV', 'lemma': 'як'}),
#  ({'word': 'дешевші', 'upos': 'ADJ', 'lemma': 'дешевшя'},
#   {'word': 'варіанти', 'upos': 'NOUN', 'lemma': 'варіант'}),
#  ({'word': 'виглядають', 'upos': 'VERB', 'lemma': 'виглядати'},
#   {'word': 'дешевші', 'upos': 'ADJ', 'lemma': 'дешевшя'},
#   {'word': 'варіанти', 'upos': 'NOUN', 'lemma': 'варіант'}),
#  ({'word': 'готель', 'upos': 'NOUN', 'lemma': 'Готель'},
#   {'word': 'відповідає', 'upos': 'VERB', 'lemma': 'відповідати'}),
#  ({'word': 'відповідає', 'upos': 'VERB', 'lemma': 'відповідати'},
#   {'word': 'своєму', 'upos': 'DET', 'lemma': 'свій'},
#   {'word': 'рівню', 'upos': 'NOUN', 'lemma': 'рівній'}),
#  ({'word': 'співвідношенні', 'upos': 'NOUN', 'lemma': 'співвідношення'},
#   {'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'}),
#  ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': '-', 'upos': 'PUNCT', 'lemma': '-'},
#   {'word': 'якість', 'upos': 'NOUN', 'lemma': 'якість'}),
#  ({'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'була', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'чиста', 'upos': 'ADJ', 'lemma': 'чистий'},
#   {'word': 'постіль', 'upos': 'NOUN', 'lemma': 'постіль'}),
#  ({'word': 'була', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'чиста', 'upos': 'ADJ', 'lemma': 'чистий'},
#   {'word': 'постіль', 'upos': 'NOUN', 'lemma': 'постіль'}),
#  ({'word': 'зручне', 'upos': 'ADJ', 'lemma': 'зручний'},
#   {'word': 'ліжко', 'upos': 'NOUN', 'lemma': 'ліжко'}),
#  ({'word': 'постіль', 'upos': 'NOUN', 'lemma': 'постіль'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'зручне', 'upos': 'ADJ', 'lemma': 'зручний'},
#   {'word': 'ліжко', 'upos': 'NOUN', 'lemma': 'ліжко'}),
#  ({'word': 'душі', 'upos': 'NOUN', 'lemma': 'душа'},
#   {'word': 'завжди', 'upos': 'ADV', 'lemma': 'завжди'},
#   {'word': 'гаряча', 'upos': 'ADJ', 'lemma': 'гарячий'}),
#  ({'word': 'завжди', 'upos': 'ADV', 'lemma': 'завжди'},
#   {'word': 'гаряча', 'upos': 'ADJ', 'lemma': 'гарячий'}),
#  ({'word': 'гаряча', 'upos': 'ADJ', 'lemma': 'гарячий'},
#   {'word': 'вода', 'upos': 'NOUN', 'lemma': 'вода'}),
#  ({'word': 'гаряча', 'upos': 'ADJ', 'lemma': 'гарячий'},
#   {'word': 'вода', 'upos': 'NOUN', 'lemma': 'вода'},
#   {'word': 'завдяки', 'upos': 'ADP', 'lemma': 'завдяки'},
#   {'word': 'бойлер', 'upos': 'NOUN', 'lemma': 'бойлер'}),
#  ({'word': 'великим', 'upos': 'ADJ', 'lemma': 'великий'},
#   {'word': 'плюсом', 'upos': 'NOUN', 'lemma': 'плюс'}),
#  ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#  ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': 'чайник', 'upos': 'NOUN', 'lemma': 'чайник'}),
#  ({'word': 'чайник', 'upos': 'NOUN', 'lemma': 'чайник'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'}),
#  ({'word': 'більше', 'upos': 'ADV', 'lemma': 'більше'},
#   {'word': 'тут', 'upos': 'ADV', 'lemma': 'тут'},
#   {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#   {'word': 'зупинятимуть', 'upos': 'VERB', 'lemma': 'зупиняти'}),
#  ({'word': 'тут', 'upos': 'ADV', 'lemma': 'тут'},
#   {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#   {'word': 'зупинятимуть', 'upos': 'VERB', 'lemma': 'зупиняти'}),
#  ({'word': 'мала', 'upos': 'VERB', 'lemma': 'малий'},
#   {'word': 'проблеми', 'upos': 'NOUN', 'lemma': 'проблема'}),
#  ({'word': 'проблеми', 'upos': 'NOUN', 'lemma': 'проблема'},
#   {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#   {'word': 'документами', 'upos': 'NOUN', 'lemma': 'документ'}),
#  ({'word': 'документами', 'upos': 'NOUN', 'lemma': 'документ'},
#   {'word': 'для', 'upos': 'ADP', 'lemma': 'для'},
#   {'word': 'проплати', 'upos': 'NOUN', 'lemma': 'проплати'}),
#  ({'word': 'проплати', 'upos': 'NOUN', 'lemma': 'проплати'},
#   {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#   {'word': 'бухгалтерії', 'upos': 'NOUN', 'lemma': 'бухгалтерія'}),
# ...
#   {'word': 'назвати', 'upos': 'VERB', 'lemma': 'назвати'}),
#  ({'word': 'спав', 'upos': 'VERB', 'lemma': 'спати'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': 'дивані', 'upos': 'NOUN', 'lemma': 'диван'}),
#  ({'word': 'дивані', 'upos': 'NOUN', 'lemma': 'диван'},
#   {'word': 'докладному', 'upos': 'ADJ', 'lemma': 'докладний'}),
#  ({'word': 'випирали', 'upos': 'VERB', 'lemma': 'випирати'},
#   {'word': 'пружини', 'upos': 'NOUN', 'lemma': 'пружина'}),
#  ({'word': 'постіль', 'upos': 'NOUN', 'lemma': 'постіль'},
#   {'word': 'сам', 'upos': 'DET', 'lemma': 'сам'},
#   {'word': 'собі', 'upos': 'PRON', 'lemma': 'себе'},
#   {'word': 'повинен', 'upos': 'ADJ', 'lemma': 'повинний'}),
#  ({'word': 'повинен', 'upos': 'ADJ', 'lemma': 'повинний'},
#   {'word': 'надівати', 'upos': 'VERB', 'lemma': 'надівати'}),
#  ({'word': 'надівати', 'upos': 'VERB', 'lemma': 'надівати'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'навіть', 'upos': 'PART', 'lemma': 'навіть'},
#   {'word': 'ліжка', 'upos': 'NOUN', 'lemma': 'ліжко'}),
#  ({'word': 'ліжка', 'upos': 'NOUN', 'lemma': 'ліжко'},
#   {'word': 'нормального', 'upos': 'ADJ', 'lemma': 'нормальний'}),
#  ({'word': 'коли', 'upos': 'ADV', 'lemma': 'коли'},
#   {'word': 'розклав', 'upos': 'VERB', 'lemma': 'розкласти'}),
#  ({'word': 'було', 'upos': 'VERB', 'lemma': 'бути'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'коли', 'upos': 'ADV', 'lemma': 'коли'},
#   {'word': 'розклав', 'upos': 'VERB', 'lemma': 'розкласти'}),
#  ({'word': 'розклав', 'upos': 'VERB', 'lemma': 'розкласти'},
#   {'word': 'диван', 'upos': 'NOUN', 'lemma': 'диван'}),
#  ({'word': 'вхідні', 'upos': 'ADJ', 'lemma': 'вхідний'},
#   {'word': 'двері', 'upos': 'NOUN', 'lemma': 'двері'}),
#  ({'word': 'розклав', 'upos': 'VERB', 'lemma': 'розкласти'},
#   {'word': 'диван', 'upos': 'NOUN', 'lemma': 'диван'},
#   {'word': 'вхідні', 'upos': 'ADJ', 'lemma': 'вхідний'},
#   {'word': 'двері', 'upos': 'NOUN', 'lemma': 'двері'}),
#  ({'word': 'відкривались', 'upos': 'VERB', 'lemma': 'відкриватися'},
#   {'word': 'цілком', 'upos': 'ADV', 'lemma': 'цілком'}),
#  ({'word': 'описі', 'upos': 'NOUN', 'lemma': 'опис'},
#   {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#   {'word': 'вказано', 'upos': 'VERB', 'lemma': 'вказати'}),
#  ({'word': 'душ', 'upos': 'NOUN', 'lemma': 'душ'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': '2', 'upos': 'NUM', 'lemma': '2'},
#   {'word': 'кімнати', 'upos': 'NOUN', 'lemma': 'кімната'}),
#  ({'word': 'мав', 'upos': 'VERB', 'lemma': 'мати'},
#   {'word': 'бути', 'upos': 'AUX', 'lemma': 'бути'},
#   {'word': 'вайда', 'upos': 'PROPN', 'lemma': 'Вайда'}),
#  ({'word': 'коридорах', 'upos': 'NOUN', 'lemma': 'коридор'},
#   {'word': 'накурено', 'upos': 'VERB', 'lemma': 'накурено'}),
#  ({'word': 'накурено', 'upos': 'VERB', 'lemma': 'накурено'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'таке', 'upos': 'DET', 'lemma': 'такий'},
#   {'word': 'відчуття', 'upos': 'NOUN', 'lemma': 'відчуття'}),
#  ({'word': 'там', 'upos': 'ADV', 'lemma': 'там'},
#   {'word': 'живуть', 'upos': 'VERB', 'lemma': 'жити'}),
#  ({'word': 'живуть', 'upos': 'VERB', 'lemma': 'жити'},
#   {'word': 'одні', 'upos': 'DET', 'lemma': 'один'},
#   {'word': '«', 'upos': 'PUNCT', 'lemma': '«'},
#   {'word': 'пияки', 'upos': 'NOUN', 'lemma': 'пияка'}),
#  ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': '300', 'upos': 'NUM', 'lemma': '300'},
#   {'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'}),
#  ({'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'},
#   {'word': 'але', 'upos': 'CCONJ', 'lemma': 'але'},
#   {'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'}),
#  ({'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'},
#   {'word': 'вказати', 'upos': 'VERB', 'lemma': 'вказати'}),
#  ({'word': 'вказати', 'upos': 'VERB', 'lemma': 'вказати'},
#   {'word': 'які', 'upos': 'DET', 'lemma': 'який'},
#   {'word': 'умови', 'upos': 'NOUN', 'lemma': 'умова'}),
#  ({'word': 'пізно', 'upos': 'ADV', 'lemma': 'пізно'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'змучений', 'upos': 'ADJ', 'lemma': 'змучений'}),
#  ({'word': 'хотілось', 'upos': 'VERB', 'lemma': 'хотітися'},
#   {'word': 'шукати', 'upos': 'VERB', 'lemma': 'шукати'}),
#  ({'word': 'шукати', 'upos': 'VERB', 'lemma': 'шукати'},
#   {'word': 'кращого', 'upos': 'ADJ', 'lemma': 'кращий'}),
#  ({'word': 'як', 'upos': 'ADV', 'lemma': 'як'},
#   {'word': 'маєте', 'upos': 'VERB', 'lemma': 'мати'}),
#  ({'word': 'маєте', 'upos': 'VERB', 'lemma': 'мати'},
#   {'word': 'час', 'upos': 'NOUN', 'lemma': 'час'}),
#  ({'word': 'маєте', 'upos': 'VERB', 'lemma': 'мати'},
#   {'word': 'час', 'upos': 'NOUN', 'lemma': 'час'},
#   {'word': 'раджу', 'upos': 'VERB', 'lemma': 'радити'}),
#  ({'word': 'маєте', 'upos': 'VERB', 'lemma': 'мати'},
#   {'word': 'час', 'upos': 'NOUN', 'lemma': 'час'},
#   {'word': 'раджу', 'upos': 'VERB', 'lemma': 'радити'},
#   {'word': 'пошукати', 'upos': 'VERB', 'lemma': 'пошукати'}),
#  ({'word': 'пошукати', 'upos': 'VERB', 'lemma': 'пошукати'},
#   {'word': 'щось', 'upos': 'PRON', 'lemma': 'щось'},
#   {'word': 'краще', 'upos': 'ADV', 'lemma': 'краще'}),
#  ({'word': 'однозначно', 'upos': 'ADV', 'lemma': 'однозначно'},
#   {'word': 'нема', 'upos': 'VERB', 'lemma': 'немати'}),
#  ({'word': 'тут', 'upos': 'ADV', 'lemma': 'тут'},
#   {'word': 'робити', 'upos': 'VERB', 'lemma': 'робити'}),
#  ({'word': 'нема', 'upos': 'VERB', 'lemma': 'немати'},
#   {'word': 'що', 'upos': 'PRON', 'lemma': 'що'},
#   {'word': 'тут', 'upos': 'ADV', 'lemma': 'тут'},
#   {'word': 'робити', 'upos': 'VERB', 'lemma': 'робити'}),
#  ({'word': "п'яний", 'upos': 'ADJ', 'lemma': 'п’яний'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'неадекватний', 'upos': 'ADJ', 'lemma': 'неадекватний'},
#   {'word': 'охоронець', 'upos': 'NOUN', 'lemma': 'охоронець'}),
#  ({'word': "п'яний", 'upos': 'ADJ', 'lemma': 'п’яний'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'неадекватний', 'upos': 'ADJ', 'lemma': 'неадекватний'}),
#  ({'word': "п'яний", 'upos': 'ADJ', 'lemma': 'п’яний'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'неадекватний', 'upos': 'ADJ', 'lemma': 'неадекватний'},
#   {'word': 'охоронець', 'upos': 'NOUN', 'lemma': 'охоронець'}),
#  ({'word': "п'яний", 'upos': 'ADJ', 'lemma': 'п’яний'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'неадекватний', 'upos': 'ADJ', 'lemma': 'неадекватний'}),
#  ({'word': 'відсутність', 'upos': 'NOUN', 'lemma': 'відсутність'},
#   {'word': 'телевізора', 'upos': 'NOUN', 'lemma': 'телевізор'}),
#  ({'word': 'відсутність', 'upos': 'NOUN', 'lemma': 'відсутність'},
#   {'word': 'телевізора', 'upos': 'NOUN', 'lemma': 'телевізор'}),
#  ({'word': 'незручне', 'upos': 'ADJ', 'lemma': 'незручний'},
#   {'word': 'розташування', 'upos': 'NOUN', 'lemma': 'розташування'}),
#  ({'word': 'розташування', 'upos': 'NOUN', 'lemma': 'розташування'},
#   {'word': 'вимикачів', 'upos': 'NOUN', 'lemma': 'вимикач'}),
#  ({'word': 'вимикачів', 'upos': 'NOUN', 'lemma': 'вимикач'},
#   {'word': 'світла', 'upos': 'NOUN', 'lemma': 'світло'}),
#  ({'word': 'занедбаний', 'upos': 'ADJ', 'lemma': 'занедбаний'},
#   {'word': 'будинок', 'upos': 'NOUN', 'lemma': 'будинок'}),
#  ({'word': 'будинок', 'upos': 'NOUN', 'lemma': 'будинок'},
#   {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#   {'word': 'промзоні', 'upos': 'NOUN', 'lemma': 'промзон'}),
#  ({'word': 'використовується', 'upos': 'VERB', 'lemma': 'використовуватися'},
#   {'word': 'для', 'upos': 'ADP', 'lemma': 'для'},
#   {'word': 'ночівлі', 'upos': 'NOUN', 'lemma': 'ночівля'}),
#  ({'word': 'ночівлі', 'upos': 'NOUN', 'lemma': 'ночівля'},
#   {'word': 'робітників', 'upos': 'NOUN', 'lemma': 'робітник'}),
#  ({'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'},
#   {'word': 'сніданку', 'upos': 'NOUN', 'lemma': 'сніданок'}),
#  ({'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'},
#   {'word': 'телевізора', 'upos': 'NOUN', 'lemma': 'телевізор'}),
#  ({'word': 'працює', 'upos': 'VERB', 'lemma': 'працювати'},
#   {'word': 'холодильник', 'upos': 'NOUN', 'lemma': 'холодильник'}),
#  ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'поступливість', 'upos': 'NOUN', 'lemma': 'поступливість'}),
#  ({'word': 'поступливість', 'upos': 'NOUN', 'lemma': 'поступливість'},
#   {'word': 'персоналу', 'upos': 'NOUN', 'lemma': 'персонал'}),
#  ({'word': 'опис', 'upos': 'NOUN', 'lemma': 'опис'},
#   {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#   {'word': 'відповідав', 'upos': 'VERB', 'lemma': 'відповідати'}),
#  ({'word': 'відповідав', 'upos': 'VERB', 'lemma': 'відповідати'},
#   {'word': 'дійсності', 'upos': 'NOUN', 'lemma': 'дійсність'}),
#  ({'word': 'телевізору', 'upos': 'ADV', 'lemma': 'телевізор'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'конюшину', 'upos': 'NOUN', 'lemma': 'конюшина'}),
#  ({'word': 'дешева', 'upos': 'ADJ', 'lemma': 'дешевий'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'брудна', 'upos': 'ADJ', 'lemma': 'брудний'}),
#  ({'word': 'постільна', 'upos': 'ADJ', 'lemma': 'постільний'},
#   {'word': 'білизна', 'upos': 'ADJ', 'lemma': 'білизний'}),
#  ({'word': 'домашньому', 'upos': 'NOUN', 'lemma': 'домашній'},
#   {'word': 'тихо', 'upos': 'ADV', 'lemma': 'тихо'}),
#  ({'word': 'тихо', 'upos': 'ADV', 'lemma': 'тихо'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#  ({'word': 'комфортно', 'upos': 'ADV', 'lemma': 'комфортно'},
#   {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#   {'word': 'парковим', 'upos': 'ADJ', 'lemma': 'парковий'}),
#  ({'word': 'тихо', 'upos': 'ADV', 'lemma': 'тихо'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#  ({'word': 'парковим', 'upos': 'ADJ', 'lemma': 'парковий'},
#   {'word': 'місцем', 'upos': 'NOUN', 'lemma': 'місце'}),
#  ({'word': 'комфортно', 'upos': 'ADV', 'lemma': 'комфортно'},
#   {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#   {'word': 'парковим', 'upos': 'ADJ', 'lemma': 'парковий'},
#   {'word': 'місцем', 'upos': 'NOUN', 'lemma': 'місце'}),
#  ({'word': 'місцем', 'upos': 'NOUN', 'lemma': 'місце'},
#   {'word': 'для', 'upos': 'ADP', 'lemma': 'для'},
#   {'word': 'автомобіля', 'upos': 'NOUN', 'lemma': 'автомобіль'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'хороша', 'upos': 'ADJ', 'lemma': 'хороший'}),
#  ({'word': 'хороша', 'upos': 'ADJ', 'lemma': 'хороший'},
#   {'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'}),
#  ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': '/', 'upos': 'PUNCT', 'lemma': '/'},
#   {'word': 'якість', 'upos': 'NOUN', 'lemma': 'якість'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'хороша', 'upos': 'ADJ', 'lemma': 'хороший'}),
#  ({'word': 'хороша', 'upos': 'ADJ', 'lemma': 'хороший'},
#   {'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'}),
#  ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#   {'word': '/', 'upos': 'PUNCT', 'lemma': '/'},
#   {'word': 'якість', 'upos': 'NOUN', 'lemma': 'якість'}),
#  ({'word': 'якість', 'upos': 'NOUN', 'lemma': 'якість'},
#   {'word': 'як', 'upos': 'SCONJ', 'lemma': 'як'},
#   {'word': 'для', 'upos': 'ADP', 'lemma': 'для'},
#   {'word': 'києва', 'upos': 'PROPN', 'lemma': 'Київ'}),
#  ({'word': 'варіант', 'upos': 'NOUN', 'lemma': 'варіант'},
#   {'word': '"', 'upos': 'PUNCT', 'lemma': '"'},
#   {'word': 'переночувати', 'upos': 'VERB', 'lemma': 'переночувати'}),
#  ({'word': 'переночувати', 'upos': 'VERB', 'lemma': 'переночувати'},
#   {'word': 'кілька', 'upos': 'DET', 'lemma': 'кілька'},
#   {'word': 'ночей', 'upos': 'NOUN', 'lemma': 'ніч'}),
#  ({'word': 'хв', 'upos': 'NOUN', 'lemma': 'хв'},
#   {'word': 'пішки', 'upos': 'ADV', 'lemma': 'пішки'}),
#  ({'word': 'стіни', 'upos': 'NOUN', 'lemma': 'стіна'},
#   {'word': 'грязьові', 'upos': 'ADJ', 'lemma': 'грязьовий'}),
#  ({'word': 'грязьові', 'upos': 'ADJ', 'lemma': 'грязьовий'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'відсутній', 'upos': 'ADJ', 'lemma': 'відсутній'}),
#  ({'word': 'відсутній', 'upos': 'ADJ', 'lemma': 'відсутній'},
#   {'word': 'телевізор', 'upos': 'NOUN', 'lemma': 'телевізор'}),
#  ({'word': 'погано', 'upos': 'ADV', 'lemma': 'погано'},
#   {'word': 'прибрано', 'upos': 'VERB', 'lemma': 'прибрати'}),
#  ({'word': 'стіни', 'upos': 'NOUN', 'lemma': 'стіна'},
#   {'word': 'грязьові', 'upos': 'ADJ', 'lemma': 'грязьовий'}),
#  ({'word': 'грязьові', 'upos': 'ADJ', 'lemma': 'грязьовий'},
#   {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#   {'word': 'відсутній', 'upos': 'ADJ', 'lemma': 'відсутній'}),
#  ({'word': 'відсутній', 'upos': 'ADJ', 'lemma': 'відсутній'},
#   {'word': 'телевізор', 'upos': 'NOUN', 'lemma': 'телевізор'}),
#  ({'word': 'погано', 'upos': 'ADV', 'lemma': 'погано'},
#   {'word': 'прибрано', 'upos': 'VERB', 'lemma': 'прибрати'}),
#  ({'word': 'другу', 'upos': 'ADJ', 'lemma': 'другий'},
#   {'word': 'смутку', 'upos': 'NOUN', 'lemma': 'смуток'}),
#  ({'word': 'смутку', 'upos': 'NOUN', 'lemma': 'смуток'},
#   {'word': 'проживання', 'upos': 'NOUN', 'lemma': 'проживання'}),
#  ({'word': 'прибирання', 'upos': 'NOUN', 'lemma': 'прибирання'},
#   {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#   {'word': 'заміна', 'upos': 'NOUN', 'lemma': 'заміна'}),
#  ({'word': 'заміна', 'upos': 'NOUN', 'lemma': 'заміна'},
#   {'word': 'рушників', 'upos': 'NOUN', 'lemma': 'рушник'}),
#  ({'word': 'великий', 'upos': 'ADJ', 'lemma': 'великий'},
#   {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'умови', 'upos': 'NOUN', 'lemma': 'умова'},
#   {'word': 'великий', 'upos': 'ADJ', 'lemma': 'великий'},
#   {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#   {'word': 'с', 'upos': 'ADP', 'lemma': 'с.'},
#   {'word': 'кондиціонером', 'upos': 'NOUN', 'lemma': 'кондиціонер'}),
#  ({'word': 'велике', 'upos': 'ADJ', 'lemma': 'великий'},
#   {'word': 'та', 'upos': 'CCONJ', 'lemma': 'та'},
#   {'word': 'комфортне', 'upos': 'ADJ', 'lemma': 'комфортний'},
#   {'word': 'ліжко', 'upos': 'NOUN', 'lemma': 'ліжко'}),
#  ({'word': 'велике', 'upos': 'ADJ', 'lemma': 'великий'},
#   {'word': 'та', 'upos': 'CCONJ', 'lemma': 'та'},
#   {'word': 'комфортне', 'upos': 'ADJ', 'lemma': 'комфортний'}),
#  ({'word': 'трійник', 'upos': 'NOUN', 'lemma': 'трійник'},
#   {'word': 'під', 'upos': 'ADP', 'lemma': 'під'},
#   {'word': 'столом', 'upos': 'NOUN', 'lemma': 'стіл'}),
#  ({'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#   {'word': 'короткому', 'upos': 'ADJ', 'lemma': 'короткий'}),
#  ({'word': 'короткому', 'upos': 'ADJ', 'lemma': 'короткий'},
#   {'word': 'шнурі', 'upos': 'NOUN', 'lemma': 'шнур'}),
#  ({'word': 'більше', 'upos': 'ADV', 'lemma': 'більше'},
#   {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'зручностей', 'upos': 'NOUN', 'lemma': 'зручність'},
#   {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'зручностей', 'upos': 'NOUN', 'lemma': 'зручність'},
#   {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#   {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#  ({'word': 'телевізора', 'upos': 'NOUN', 'lemma': 'Телевізор'},
#   {'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'}),
#  ({'word': 'звітної', 'upos': 'ADJ', 'lemma': 'звітний'},
#   {'word': 'документації', 'upos': 'NOUN', 'lemma': 'документація'}),
#  ({'word': 'відсутність', 'upos': 'NOUN', 'lemma': 'відсутність'},
#   {'word': 'звітної', 'upos': 'ADJ', 'lemma': 'звітний'},
#   {'word': 'документації', 'upos': 'NOUN', 'lemma': 'документація'}),
#  ({'word': 'звітної', 'upos': 'ADJ', 'lemma': 'звітний'},
#   {'word': 'документації', 'upos': 'NOUN', 'lemma': 'документація'}),
#  ({'word': 'відсутність', 'upos': 'NOUN', 'lemma': 'відсутність'},
#   {'word': 'звітної', 'upos': 'ADJ', 'lemma': 'звітний'},
#   {'word': 'документації', 'upos': 'NOUN', 'lemma': 'документація'}),
#  ({'word': 'заявлені', 'upos': 'ADJ', 'lemma': 'заявлений'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': 'сайті', 'upos': 'NOUN', 'lemma': 'сайт'},
#   {'word': 'відомості', 'upos': 'NOUN', 'lemma': 'відомість'}),
#  ({'word': 'заявлені', 'upos': 'ADJ', 'lemma': 'заявлений'},
#   {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#   {'word': 'сайті', 'upos': 'NOUN', 'lemma': 'сайт'}),
#  ...]

# %% [markdown]
# Extract collocations for all test hotels

# %%
def extract_collocations_for_hotels(hotels, df):
    hotel_collocations_dict = dict()

    for hotel in hotels:
        hotel_df = df.loc[df['hotel'] == example_hotel]
        hotel_revies = get_mixed_review_texts(hotel_df)
        hotel_collocations = collocation_extractor.extract_from_list_of_text(hotel_revies)
        
        hotel_collocations_dict[hotel] =  hotel_collocations
        
    return hotel_collocations_dict

# %%
# %time hotel_collocations_dict = extract_collocations_for_hotels(test_hotels, booking_test_df)
# Out:
# CPU times: user 1h 40min 43s, sys: 14 s, total: 1h 40min 57s
# Wall time: 1h 40min 59s

# %%
save_data_to_json(hotel_collocations_dict, "data/hotel-collocations-test.json")

# %% [markdown]
# ## Cluster test collocations

# %%
from clustering.cluster_collocations import ClusterCollocations
from gensim.models import KeyedVectors

# %% [markdown]
# The clustering collocation is implemented in *clustering.cluster.collocations*. First of all we convert our collocations (use only noun) into vector via word2vec, secondly we run K-means algortithm to cluster these vector.

# %%
K_CLUSTERS = len(TopicType)

# %%
embeddings_file = "./embeddings/ubercorpus.lowercased.tokenized.word2vec.300d"

# %%
word2vec = KeyedVectors.load_word2vec_format(embeddings_file)

# %%
cluster_collocations = ClusterCollocations(word2vec)

# %% [markdown]
# Let's cluster example collocations

# %%
example_hotel_clustered = cluster_collocations.cluster_collocations(example_collocations, K_CLUSTERS)

# %%
example_hotel_clustered
# Out:
# {4: {'collocations': [({'word': 'чистота', 'upos': 'NOUN', 'lemma': 'чистота'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'чистота', 'upos': 'NOUN', 'lemma': 'чистота'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'нуля', 'upos': 'NOUN', 'lemma': 'нуля'},
#     {'word': 'градусів', 'upos': 'NOUN', 'lemma': 'градус'}),
#    ({'word': 'день', 'upos': 'NOUN', 'lemma': 'день'},
#     {'word': 'два', 'upos': 'NUM', 'lemma': 'два'},
#     {'word': 'приїхати', 'upos': 'VERB', 'lemma': 'приїхати'}),
#    ({'word': 'отримав', 'upos': 'VERB', 'lemma': 'отримати'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'розмовляли', 'upos': 'VERB', 'lemma': 'розмовляти'},
#     {'word': 'по', 'upos': 'ADP', 'lemma': 'по'},
#     {'word': 'телефону', 'upos': 'NOUN', 'lemma': 'телефон'}),
#    ({'word': 'разі', 'upos': 'NOUN', 'lemma': 'раз'},
#     {'word': 'якщо', 'upos': 'SCONJ', 'lemma': 'якщо'},
#     {'word': 'нема', 'upos': 'VERB', 'lemma': 'немати'}),
#    ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#     {'word': 'цього', 'upos': 'DET', 'lemma': 'цей'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'рази', 'upos': 'NOUN', 'lemma': 'раз'},
#     {'word': 'менша', 'upos': 'ADJ', 'lemma': 'менший'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'колишніх', 'upos': 'ADJ', 'lemma': 'колишній'},
#     {'word': 'гостів', 'upos': 'NOUN', 'lemma': 'гіст'}),
#    ({'word': 'помити', 'upos': 'VERB', 'lemma': 'помити'},
#     {'word': 'після', 'upos': 'ADP', 'lemma': 'після'},
#     {'word': 'колишніх', 'upos': 'ADJ', 'lemma': 'колишній'},
#     {'word': 'гостів', 'upos': 'NOUN', 'lemma': 'гіст'}),
#    ({'word': 'душ', 'upos': 'NOUN', 'lemma': 'Душ'},
#     {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'душ', 'upos': 'NOUN', 'lemma': 'Душ'},
#     {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'чайник', 'upos': 'NOUN', 'lemma': 'чайник'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'було', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'ціну', 'upos': 'NOUN', 'lemma': 'ціна'},
#     {'word': 'за', 'upos': 'ADP', 'lemma': 'за'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'система', 'upos': 'NOUN', 'lemma': 'система'},
#     {'word': 'блокова', 'upos': 'NOUN', 'lemma': 'блоковий'}),
#    ({'word': 'місяця', 'upos': 'NOUN', 'lemma': 'місяць'},
#     {'word': 'достатньо', 'upos': 'ADV', 'lemma': 'достатньо'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'достатньо', 'upos': 'ADV', 'lemma': 'достатньо'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'покращений', 'upos': 'ADJ', 'lemma': 'покращений'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'делюкс', 'upos': 'NOUN', 'lemma': 'Делюкс'},
#     {'word': 'чи', 'upos': 'CCONJ', 'lemma': 'чи'},
#     {'word': 'покращений', 'upos': 'ADJ', 'lemma': 'покращений'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'спільний', 'upos': 'ADJ', 'lemma': 'спільний'},
#     {'word': 'для', 'upos': 'ADP', 'lemma': 'для'},
#     {'word': '2', 'upos': 'NUM', 'lemma': '2'},
#     {'word': 'номерів', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'зроблений', 'upos': 'ADJ', 'lemma': 'зроблений'}),
#    ({'word': 'цілий', 'upos': 'ADJ', 'lemma': 'цілий'},
#     {'word': 'день', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'двомісному', 'upos': 'ADJ', 'lemma': 'двомісний'},
#     {'word': 'покращеному', 'upos': 'ADJ', 'lemma': 'покращений'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'покращеному', 'upos': 'ADJ', 'lemma': 'покращений'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'ліжко', 'upos': 'NOUN', 'lemma': 'ліжко'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'покращених', 'upos': 'ADJ', 'lemma': 'покращений'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'проживали', 'upos': 'VERB', 'lemma': 'проживати'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'покращених', 'upos': 'ADJ', 'lemma': 'покращений'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'покращених', 'upos': 'ADJ', 'lemma': 'покращений'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'проживали', 'upos': 'VERB', 'lemma': 'проживати'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'покращених', 'upos': 'ADJ', 'lemma': 'покращений'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'була', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'великим', 'upos': 'ADJ', 'lemma': 'великий'},
#     {'word': 'плюсом', 'upos': 'NOUN', 'lemma': 'плюс'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'рушники', 'upos': 'NOUN', 'lemma': 'рушник'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистенький', 'upos': 'ADJ', 'lemma': 'чистенький'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистенький', 'upos': 'ADJ', 'lemma': 'чистенький'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'}),
#    ({'word': 'вартість', 'upos': 'NOUN', 'lemma': 'вартість'},
#     {'word': 'номеру', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'холодно', 'upos': 'ADV', 'lemma': 'холодно'}),
#    ({'word': 'доплата', 'upos': 'NOUN', 'lemma': 'доплатий'},
#     {'word': '50', 'upos': 'NUM', 'lemma': '50'},
#     {'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'}),
#    ({'word': 'було', 'upos': 'VERB', 'lemma': 'бути'},
#     {'word': 'холодильника', 'upos': 'NOUN', 'lemma': 'холодильник'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'також', 'upos': 'ADV', 'lemma': 'також'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'вказаний', 'upos': 'ADJ', 'lemma': 'вказаний'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'вказаний', 'upos': 'ADJ', 'lemma': 'вказаний'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'вказаний', 'upos': 'ADJ', 'lemma': 'вказаний'}),
#    ({'word': 'відпочивав', 'upos': 'VERB', 'lemma': 'відпочивати'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'був', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'невеликий', 'upos': 'ADJ', 'lemma': 'невеликий'}),
#    ({'word': 'може', 'upos': 'VERB', 'lemma': 'могти'},
#     {'word': 'бути', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'й', 'upos': 'CCONJ', 'lemma': 'й'},
#     {'word': 'плюсом', 'upos': 'NOUN', 'lemma': 'плюс'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'окремий', 'upos': 'ADJ', 'lemma': 'окремий'},
#     {'word': 'плюс', 'upos': 'NOUN', 'lemma': 'плюс'}),
#    ({'word': 'краще', 'upos': 'ADV', 'lemma': 'краще'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'краще', 'upos': 'ADV', 'lemma': 'краще'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'було', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'маленький', 'upos': 'ADJ', 'lemma': 'маленький'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'відчистити', 'upos': 'VERB', 'lemma': 'відчистити'},
#     {'word': 'дуже', 'upos': 'ADV', 'lemma': 'дуже'},
#     {'word': 'маленький', 'upos': 'ADJ', 'lemma': 'маленький'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'світло', 'upos': 'NOUN', 'lemma': 'світло'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'включалося', 'upos': 'VERB', 'lemma': 'включатися'}),
#    ({'word': 'дверей', 'upos': 'NOUN', 'lemma': 'двері'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'побачивши', 'upos': 'VERB', 'lemma': 'побачити'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'брехали', 'upos': 'VERB', 'lemma': 'брехати'},
#     {'word': 'нам', 'upos': 'PRON', 'lemma': 'ми'},
#     {'word': 'по', 'upos': 'ADP', 'lemma': 'по'},
#     {'word': 'телефону', 'upos': 'NOUN', 'lemma': 'телефон'}),
#    ({'word': 'телефону', 'upos': 'NOUN', 'lemma': 'телефон'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'що', 'upos': 'SCONJ', 'lemma': 'що'},
#     {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'йшла', 'upos': 'VERB', 'lemma': 'йти'},
#     {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#     {'word': 'шортах', 'upos': 'NOUN', 'lemma': 'шорт'}),
#    ({'word': 'вцілому', 'upos': 'ADJ', 'lemma': 'вцілий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'був', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'поганий', 'upos': 'ADJ', 'lemma': 'поганий'}),
#    ({'word': 'опис', 'upos': 'NOUN', 'lemma': 'опис'},
#     {'word': 'номеру', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'надали', 'upos': 'VERB', 'lemma': 'надати'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'надали', 'upos': 'VERB', 'lemma': 'надати'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'відповідно', 'upos': 'ADV', 'lemma': 'відповідно'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'брудно', 'upos': 'ADV', 'lemma': 'брудно'},
#     {'word': 'наказував', 'upos': 'VERB', 'lemma': 'наказувати'}),
#    ({'word': 'двомісний', 'upos': 'ADJ', 'lemma': 'двомісний'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'наказував', 'upos': 'VERB', 'lemma': 'наказувати'},
#     {'word': 'двомісний', 'upos': 'ADJ', 'lemma': 'двомісний'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'повинно', 'upos': 'ADV', 'lemma': 'повинно'},
#     {'word': 'бути', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'чистіше', 'upos': 'ADV', 'lemma': 'чистіше'}),
#    ({'word': 'ціну', 'upos': 'NOUN', 'lemma': 'ціна'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': '80-ті', 'upos': 'ADJ', 'lemma': '80-ий'},
#     {'word': 'роки', 'upos': 'NOUN', 'lemma': 'рік'}),
#    ({'word': 'жах', 'upos': 'NOUN', 'lemma': 'жах'},
#     {'word': '(', 'upos': 'PUNCT', 'lemma': '('},
#     {'word': '80-ті', 'upos': 'ADJ', 'lemma': '80-ий'},
#     {'word': 'роки', 'upos': 'NOUN', 'lemma': 'рік'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'себе', 'upos': 'PRON', 'lemma': 'себе'},
#     {'word': 'виправдовує', 'upos': 'VERB', 'lemma': 'виправдовувати'}),
#    ({'word': 'підзаконних', 'upos': 'NOUN', 'lemma': 'підзаконний'},
#     {'word': 'був', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'малий', 'upos': 'ADJ', 'lemma': 'малий'}),
#    ({'word': 'платив', 'upos': 'VERB', 'lemma': 'платити'},
#     {'word': '300', 'upos': 'NUM', 'lemma': '300'},
#     {'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'}),
#    ({'word': 'зможете', 'upos': 'VERB', 'lemma': 'змогти'},
#     {'word': 'жит', 'upos': 'NOUN', 'lemma': 'жит'}),
#    ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#     {'word': '300', 'upos': 'NUM', 'lemma': '300'},
#     {'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'}),
#    ({'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'},
#     {'word': 'але', 'upos': 'CCONJ', 'lemma': 'але'},
#     {'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'}),
#    ({'word': 'хв', 'upos': 'NOUN', 'lemma': 'хв'},
#     {'word': 'пішки', 'upos': 'ADV', 'lemma': 'пішки'}),
#    ({'word': 'великий', 'upos': 'ADJ', 'lemma': 'великий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'умови', 'upos': 'NOUN', 'lemma': 'умова'},
#     {'word': 'великий', 'upos': 'ADJ', 'lemma': 'великий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'більше', 'upos': 'ADV', 'lemma': 'більше'},
#     {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'зручностей', 'upos': 'NOUN', 'lemma': 'зручність'},
#     {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'зручностей', 'upos': 'NOUN', 'lemma': 'зручність'},
#     {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'просторий', 'upos': 'ADJ', 'lemma': 'просторий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'описі', 'upos': 'NOUN', 'lemma': 'опис'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'підібрали', 'upos': 'VERB', 'lemma': 'підібрати'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'}),
#    ({'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'},
#     {'word': 'знаходяться', 'upos': 'VERB', 'lemma': 'знаходитися'}),
#    ({'word': 'персонал', 'upos': 'NOUN', 'lemma': 'персонал'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'},
#     {'word': 'знаходяться', 'upos': 'VERB', 'lemma': 'знаходитися'}),
#    ({'word': 'персонал', 'upos': 'NOUN', 'lemma': 'персонал'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'зручний', 'upos': 'ADJ', 'lemma': 'зручний'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'комфортний', 'upos': 'ADJ', 'lemma': 'комфортний'}),
#    ({'word': 'приємний', 'upos': 'ADJ', 'lemma': 'приємний'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'символіка', 'upos': 'NOUN', 'lemma': 'символік'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'персонал', 'upos': 'NOUN', 'lemma': 'персонал'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'ціну', 'upos': 'NOUN', 'lemma': 'ціна'},
#     {'word': '-', 'upos': 'PUNCT', 'lemma': '-'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чудовий', 'upos': 'ADJ', 'lemma': 'чудовий'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чудовий', 'upos': 'ADJ', 'lemma': 'чудовий'}),
#    ({'word': 'наступного', 'upos': 'ADJ', 'lemma': 'наступний'},
#     {'word': 'дня', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': "з'їхав", 'upos': 'VERB', 'lemma': 'з’їхати'},
#     {'word': 'вже', 'upos': 'ADV', 'lemma': 'вже'},
#     {'word': 'наступного', 'upos': 'ADJ', 'lemma': 'наступний'},
#     {'word': 'дня', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'заброньований', 'upos': 'ADJ', 'lemma': 'заброньований'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'опис', 'upos': 'NOUN', 'lemma': 'опис'},
#     {'word': 'номеру', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'бронювали', 'upos': 'VERB', 'lemma': 'бронювати'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'трапились', 'upos': 'VERB', 'lemma': 'трапитися'}),
#    ({'word': 'прохолодно', 'upos': 'ADV', 'lemma': 'прохолодно'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'запах', 'upos': 'NOUN', 'lemma': 'запах'},
#     {'word': 'перегару', 'upos': 'NOUN', 'lemma': 'перегар'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'різних', 'upos': 'ADJ', 'lemma': 'різний'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'було', 'upos': 'VERB', 'lemma': 'бути'},
#     {'word': 'такого', 'upos': 'DET', 'lemma': 'такий'},
#     {'word': 'рази', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'фай', 'upos': 'VERB', 'lemma': 'фай'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'усіх', 'upos': 'DET', 'lemma': 'увесь'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'відповідає', 'upos': 'VERB', 'lemma': 'відповідати'},
#     {'word': 'своїм', 'upos': 'DET', 'lemma': 'свій'},
#     {'word': 'номером', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'приємний', 'upos': 'ADJ', 'lemma': 'приємний'},
#     {'word': 'человек', 'upos': 'NOUN', 'lemma': 'человек'}),
#    ({'word': '39;єкт', 'upos': 'ADJ', 'lemma': '39;єкт'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'відповідав', 'upos': 'VERB', 'lemma': 'відповідати'}),
#    ({'word': '60-х', 'upos': 'ADJ', 'lemma': '60-й'},
#     {'word': 'років', 'upos': 'NOUN', 'lemma': 'рік'}),
#    ({'word': 'совдепії', 'upos': 'NOUN', 'lemma': 'совдепія'},
#     {'word': '60-х', 'upos': 'ADJ', 'lemma': '60-й'},
#     {'word': 'років', 'upos': 'NOUN', 'lemma': 'рік'}),
#    ({'word': 'ночі', 'upos': 'NOUN', 'lemma': 'ніч'},
#     {'word': 'по', 'upos': 'ADP', 'lemma': 'по'},
#     {'word': '250', 'upos': 'NUM', 'lemma': '250'},
#     {'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'двомісному', 'upos': 'ADJ', 'lemma': 'двомісний'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'дістатися', 'upos': 'VERB', 'lemma': 'дістатися'},
#     {'word': 'до', 'upos': 'ADP', 'lemma': 'до'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'житло', 'upos': 'NOUN', 'lemma': 'житло'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': '250', 'upos': 'NUM', 'lemma': '250'},
#     {'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'}),
#    ({'word': 'дістатися', 'upos': 'VERB', 'lemma': 'дістатися'},
#     {'word': 'до', 'upos': 'ADP', 'lemma': 'до'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'житло', 'upos': 'NOUN', 'lemma': 'житло'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': '250', 'upos': 'NUM', 'lemma': '250'},
#     {'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'}),
#    ({'word': 'допомогли', 'upos': 'VERB', 'lemma': 'допомогти'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'квитком', 'upos': 'NOUN', 'lemma': 'квиток'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'}),
#    ({'word': 'загальний', 'upos': 'ADJ', 'lemma': 'загальний'},
#     {'word': 'для', 'upos': 'ADP', 'lemma': 'для'},
#     {'word': 'декількох', 'upos': 'DET', 'lemma': 'декілька'},
#     {'word': 'номерів', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'туалет', 'upos': 'NOUN', 'lemma': 'туалет'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'останній', 'upos': 'ADJ', 'lemma': 'останній'},
#     {'word': 'чек', 'upos': 'NOUN', 'lemma': 'чек'}),
#    ({'word': 'чек', 'upos': 'NOUN', 'lemma': 'чек'},
#     {'word': 'пробивається', 'upos': 'VERB', 'lemma': 'пробиватися'}),
#    ({'word': 'перший', 'upos': 'ADJ', 'lemma': 'перший'},
#     {'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'рік', 'upos': 'NOUN', 'lemma': 'рік'},
#     {'word': 'тому', 'upos': 'ADV', 'lemma': 'тому'}),
#    ({'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'році', 'upos': 'NOUN', 'lemma': 'рік'},
#     {'word': 'зупинитися', 'upos': 'VERB', 'lemma': 'зупинитися'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'}),
#    ({'word': 'стояв', 'upos': 'VERB', 'lemma': 'стояти'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'цьому', 'upos': 'DET', 'lemma': 'цей'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'прокурений', 'upos': 'ADJ', 'lemma': 'прокурений'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': 'обшарпаний', 'upos': 'ADJ', 'lemma': 'обшарпаний'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'стоїть', 'upos': 'VERB', 'lemma': 'стояти'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'пробурено', 'upos': 'VERB', 'lemma': 'пробурити'}),
#    ({'word': 'безпосередньо', 'upos': 'ADV', 'lemma': 'безпосередньо'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'забризкали', 'upos': 'VERB', 'lemma': 'забризкати'},
#     {'word': 'весь', 'upos': 'DET', 'lemma': 'весь'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'курять', 'upos': 'VERB', 'lemma': 'курити'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'курять', 'upos': 'VERB', 'lemma': 'курити'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'варіант', 'upos': 'NOUN', 'lemma': 'варіант'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'кілька', 'upos': 'DET', 'lemma': 'кілька'},
#     {'word': 'днів', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'коридорах', 'upos': 'NOUN', 'lemma': 'коридор'},
#     {'word': 'до', 'upos': 'ADP', 'lemma': 'до'},
#     {'word': 'номерів', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'другий', 'upos': 'ADJ', 'lemma': 'другий'},
#     {'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'відпочивав', 'upos': 'VERB', 'lemma': 'відпочивати'},
#     {'word': 'тут', 'upos': 'ADV', 'lemma': 'тут'},
#     {'word': 'другий', 'upos': 'ADJ', 'lemma': 'другий'},
#     {'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'надав', 'upos': 'VERB', 'lemma': 'надати'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'розеток', 'upos': 'NOUN', 'lemma': 'розетка'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'чисті', 'upos': 'ADJ', 'lemma': 'Чист'},
#     {'word': 'номери', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'вентилятор', 'upos': 'NOUN', 'lemma': 'вентилятор'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'прохання', 'upos': 'NOUN', 'lemma': 'прохання'},
#     {'word': 'іншої', 'upos': 'DET', 'lemma': 'інший'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'раніше', 'upos': 'ADV', 'lemma': 'раніше'},
#     {'word': 'дня', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'}),
#    ({'word': 'замінив', 'upos': 'VERB', 'lemma': 'замінити'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'далеко', 'upos': 'ADV', 'lemma': 'далеко'},
#     {'word': 'від', 'upos': 'ADP', 'lemma': 'від'},
#     {'word': 'ст', 'upos': 'NOUN', 'lemma': 'ст.'}),
#    ({'word': 'знаходиться', 'upos': 'VERB', 'lemma': 'знаходитися'},
#     {'word': 'там', 'upos': 'ADV', 'lemma': 'там'},
#     {'word': 'днем', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'міцні', 'upos': 'ADJ', 'lemma': 'міцний'},
#     {'word': '7', 'upos': 'NUM', 'lemma': '7'},
#     {'word': 'балів', 'upos': 'NOUN', 'lemma': 'бал'}),
#    ({'word': 'балів', 'upos': 'NOUN', 'lemma': 'бал'},
#     {'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'},
#     {'word': 'ставити', 'upos': 'VERB', 'lemma': 'ставити'}),
#    ({'word': 'ключ', 'upos': 'NOUN', 'lemma': 'ключ'},
#     {'word': 'від', 'upos': 'ADP', 'lemma': 'від'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'дзвінка', 'upos': 'NOUN', 'lemma': 'дзвінка'},
#     {'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'}),
#    ({'word': 'закриті', 'upos': 'ADJ', 'lemma': 'закритий'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'дзвінка', 'upos': 'NOUN', 'lemma': 'дзвінка'},
#     {'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'}),
#    ({'word': 'номерів', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'вказаних', 'upos': 'ADJ', 'lemma': 'вказаний'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'може', 'upos': 'VERB', 'lemma': 'могти'}),
#    ({'word': 'потрібний', 'upos': 'ADJ', 'lemma': 'потрібний'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'знайшли', 'upos': 'VERB', 'lemma': 'знайти'},
#     {'word': 'потрібний', 'upos': 'ADJ', 'lemma': 'потрібний'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'залишив', 'upos': 'VERB', 'lemma': 'залишити'}),
#    ({'word': 'незрозумілого', 'upos': 'ADJ', 'lemma': 'незрозуміле'},
#     {'word': 'коричневий', 'upos': 'ADJ', 'lemma': 'коричневий'},
#     {'word': 'ого', 'upos': 'NOUN', 'lemma': 'ого'}),
#    ({'word': 'коричневий', 'upos': 'ADJ', 'lemma': 'коричневий'},
#     {'word': 'ого', 'upos': 'NOUN', 'lemma': 'ого'}),
#    ({'word': 'полотен', 'upos': 'NOUN', 'lemma': 'полотено'},
#     {'word': 'незрозумілого', 'upos': 'ADJ', 'lemma': 'незрозуміле'},
#     {'word': 'коричневий', 'upos': 'ADJ', 'lemma': 'коричневий'},
#     {'word': 'ого', 'upos': 'NOUN', 'lemma': 'ого'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'було', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'сподобався', 'upos': 'VERB', 'lemma': 'сподобатися'},
#     {'word': 'сам', 'upos': 'DET', 'lemma': 'сам'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'сподобався', 'upos': 'VERB', 'lemma': 'сподобатися'},
#     {'word': 'сам', 'upos': 'DET', 'lemma': 'сам'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'вартість', 'upos': 'NOUN', 'lemma': 'вартість'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'сподобався', 'upos': 'VERB', 'lemma': 'сподобатися'},
#     {'word': 'сам', 'upos': 'DET', 'lemma': 'сам'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'сподобався', 'upos': 'VERB', 'lemma': 'сподобатися'},
#     {'word': 'сам', 'upos': 'DET', 'lemma': 'сам'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'вартість', 'upos': 'NOUN', 'lemma': 'вартість'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'},
#     {'word': '500', 'upos': 'NUM', 'lemma': '500'},
#     {'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'}),
#    ({'word': '2', 'upos': 'ADJ', 'lemma': '2'},
#     {'word': 'дня', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'вентилятор', 'upos': 'NOUN', 'lemma': 'вентилятор'},
#     {'word': 'супер', 'upos': 'NOUN', 'lemma': 'супер'}),
#    ({'word': 'супер', 'upos': 'NOUN', 'lemma': 'супер'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'дякую', 'upos': 'VERB', 'lemma': 'дякувати'}),
#    ({'word': 'задоволений', 'upos': 'ADJ', 'lemma': 'задоволений'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': 'номерами', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'звільнився', 'upos': 'VERB', 'lemma': 'звільнитися'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'холодно', 'upos': 'ADV', 'lemma': 'холодно'}),
#    ({'word': 'санвузлі', 'upos': 'NOUN', 'lemma': 'санвузлий'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'самому', 'upos': 'DET', 'lemma': 'сам'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'забронювали', 'upos': 'VERB', 'lemma': 'забронювати'},
#     {'word': '2', 'upos': 'NUM', 'lemma': '2'},
#     {'word': 'номери', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'кращий', 'upos': 'ADJ', 'lemma': 'кращий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'переселили', 'upos': 'VERB', 'lemma': 'переселити'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'кращий', 'upos': 'ADJ', 'lemma': 'кращий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'називається', 'upos': 'VERB', 'lemma': 'називатися'}),
#    ({'word': 'насправді', 'upos': 'ADV', 'lemma': 'насправді'},
#     {'word': 'найпростіший', 'upos': 'ADJ', 'lemma': 'найпростіший'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'найпростіший', 'upos': 'ADJ', 'lemma': 'найпростіший'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номери', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': '-', 'upos': 'PUNCT', 'lemma': '-'},
#     {'word': '2', 'upos': 'NUM', 'lemma': '2'},
#     {'word': 'номери', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номери', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': '-', 'upos': 'PUNCT', 'lemma': '-'},
#     {'word': '2', 'upos': 'NUM', 'lemma': '2'},
#     {'word': 'номери', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'брудний', 'upos': 'ADJ', 'lemma': 'брудний'}),
#    ({'word': 'дверцята', 'upos': 'NOUN', 'lemma': 'дверцятий'},
#     {'word': ';', 'upos': 'PUNCT', 'lemma': ';'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'брудний', 'upos': 'ADJ', 'lemma': 'брудний'}),
#    ({'word': 'приладдя', 'upos': 'NOUN', 'lemma': 'приладдя'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'здвоєний', 'upos': 'ADJ', 'lemma': 'здвоєний'}),
#    ({'word': 'ремонт', 'upos': 'NOUN', 'lemma': 'ремонт'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'звукоізоляція', 'upos': 'NOUN', 'lemma': 'звукоізоляція'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'пару', 'upos': 'NOUN', 'lemma': 'пара'},
#     {'word': 'днів', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#     {'word': 'за', 'upos': 'ADP', 'lemma': 'за'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'ніч', 'upos': 'NOUN', 'lemma': 'ніч'},
#     {'word': 'парковки', 'upos': 'NOUN', 'lemma': 'парковка'},
#     {'word': '20', 'upos': 'NUM', 'lemma': '20'},
#     {'word': 'грн', 'upos': 'NOUN', 'lemma': 'грн'}),
#    ({'word': 'розетка', 'upos': 'NOUN', 'lemma': 'розетка'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'окремими', 'upos': 'ADJ', 'lemma': 'окремий'},
#     {'word': 'номерами', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': '-', 'upos': 'PUNCT', 'lemma': '-'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'днів', 'upos': 'NOUN', 'lemma': 'день'},
#     {'word': 'зупинитися', 'upos': 'VERB', 'lemma': 'зупинитися'}),
#    ({'word': 'наступний', 'upos': 'ADJ', 'lemma': 'наступний'},
#     {'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'побачити', 'upos': 'VERB', 'lemma': 'побачити'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'наступний', 'upos': 'ADJ', 'lemma': 'наступний'},
#     {'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'чудовий', 'upos': 'ADJ', 'lemma': 'чудовий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#     {'word': 'нас', 'upos': 'PRON', 'lemma': 'ми'},
#     {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#     {'word': 'нас', 'upos': 'PRON', 'lemma': 'ми'},
#     {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'було', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'гідні', 'upos': 'ADJ', 'lemma': 'гідний'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'прилади', 'upos': 'NOUN', 'lemma': 'прилад'},
#     {'word': 'прям', 'upos': 'ADV', 'lemma': 'прямий'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'перші', 'upos': 'ADJ', 'lemma': 'перший'},
#     {'word': 'дні', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'гарні', 'upos': 'ADJ', 'lemma': 'гарний'},
#     {'word': 'номери', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'персонал', 'upos': 'NOUN', 'lemma': 'персонал'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'гарні', 'upos': 'ADJ', 'lemma': 'гарний'},
#     {'word': 'номери', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'чистий', 'upos': 'ADJ', 'lemma': 'чистий'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'жили', 'upos': 'VERB', 'lemma': 'жити'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'підійде', 'upos': 'VERB', 'lemma': 'підійти'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'кілька', 'upos': 'DET', 'lemma': 'кілька'},
#     {'word': 'днів', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'більш-менш', 'upos': 'ADV', 'lemma': 'більш-менш'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'дзвонити', 'upos': 'VERB', 'lemma': 'дзвонити'},
#     {'word': 'кожен', 'upos': 'DET', 'lemma': 'кожний'},
#     {'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'другий', 'upos': 'ADJ', 'lemma': 'другий'},
#     {'word': 'день', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'отримувати', 'upos': 'VERB', 'lemma': 'отримувати'},
#     {'word': 'чек', 'upos': 'NOUN', 'lemma': 'чек'}),
#    ({'word': 'которий', 'upos': 'NOUN', 'lemma': 'которий'},
#     {'word': 'по', 'upos': 'ADP', 'lemma': 'по'},
#     {'word': '50', 'upos': 'NUM', 'lemma': '50'},
#     {'word': 'гр', 'upos': 'NOUN', 'lemma': 'гр.'}),
#    ({'word': 'жарко', 'upos': 'ADV', 'lemma': 'Жарко'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'тривісного', 'upos': 'ADJ', 'lemma': 'тривісний'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'заброньовано', 'upos': 'VERB', 'lemma': 'заброньовано'},
#     {'word': 'тривісного', 'upos': 'ADJ', 'lemma': 'тривісний'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'поводився', 'upos': 'VERB', 'lemma': 'поводитися'},
#     {'word': 'зверхньо', 'upos': 'ADV', 'lemma': 'зверхня'},
#     {'word': 'при', 'upos': 'ADP', 'lemma': 'при'},
#     {'word': 'дзвінку', 'upos': 'NOUN', 'lemma': 'дзвінка'}),
#    ({'word': 'сусідній', 'upos': 'ADJ', 'lemma': 'сусідній'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'ходили', 'upos': 'VERB', 'lemma': 'ходити'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'сусідній', 'upos': 'ADJ', 'lemma': 'сусідній'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'був', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'підготовлений', 'upos': 'ADJ', 'lemma': 'підготовлений'}),
#    ({'word': 'ніч', 'upos': 'NOUN', 'lemma': 'ніч'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'ломилися', 'upos': 'VERB', 'lemma': 'ломитися'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'ломилися', 'upos': 'VERB', 'lemma': 'ломитися'}),
#    ({'word': 'здати', 'upos': 'VERB', 'lemma': 'здати'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'відповідав', 'upos': 'VERB', 'lemma': 'відповідати'}),
#    ({'word': 'чистота', 'upos': 'NOUN', 'lemma': 'чистота'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'сервіс', 'upos': 'NOUN', 'lemma': 'Сервіс'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'нулі', 'upos': 'NOUN', 'lemma': 'нуль'}),
#    ({'word': 'увійшовши', 'upos': 'VERB', 'lemma': 'увійти'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'цей', 'upos': 'DET', 'lemma': 'цей'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'прибирали', 'upos': 'VERB', 'lemma': 'прибирати'}),
#    ({'word': 'минулого', 'upos': 'ADJ', 'lemma': 'минулий'},
#     {'word': 'року', 'upos': 'NOUN', 'lemma': 'рік'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'чисто', 'upos': 'ADV', 'lemma': 'чисто'}),
#    ({'word': 'потрапити', 'upos': 'VERB', 'lemma': 'потрапити'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'який', 'upos': 'DET', 'lemma': 'який'},
#     {'word': 'забронювала', 'upos': 'VERB', 'lemma': 'забронювати'}),
#    ({'word': 'минулого', 'upos': 'ADJ', 'lemma': 'минулий'},
#     {'word': 'разу', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'разу', 'upos': 'NOUN', 'lemma': 'раз'},
#     {'word': 'коли', 'upos': 'ADV', 'lemma': 'коли'},
#     {'word': 'я', 'upos': 'PRON', 'lemma': 'я'},
#     {'word': 'приїжджала', 'upos': 'VERB', 'lemma': 'приїжджати'}),
#    ({'word': 'описі', 'upos': 'NOUN', 'lemma': 'опис'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'},
#     {'word': 'була', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'описі', 'upos': 'NOUN', 'lemma': 'опис'},
#     {'word': 'номера', 'upos': 'NOUN', 'lemma': 'номера'}),
#    ({'word': 'час', 'upos': 'NOUN', 'lemma': 'час'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': '1', 'upos': 'NUM', 'lemma': '1'},
#     {'word': 'день', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#     {'word': 'ел', 'upos': 'NOUN', 'lemma': 'ел.'}),
#    ({'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'стілець', 'upos': 'NOUN', 'lemma': 'стілець'},
#     {'word': 'хоча', 'upos': 'SCONJ', 'lemma': 'хоча'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'двох', 'upos': 'NUM', 'lemma': 'два'},
#     {'word': 'місцевий', 'upos': 'ADJ', 'lemma': 'місцевий'}),
#    ({'word': 'інакше', 'upos': 'ADV', 'lemma': 'інакше'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'буде', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'скасований', 'upos': 'ADJ', 'lemma': 'скасований'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'буде', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'скасований', 'upos': 'ADJ', 'lemma': 'скасований'}),
#    ({'word': 'заброньований', 'upos': 'ADJ', 'lemma': 'заброньований'},
#     {'word': 'через', 'upos': 'ADP', 'lemma': 'через'},
#     {'word': 'сайт', 'upos': 'NOUN', 'lemma': 'сайт'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'зайнятий', 'upos': 'ADJ', 'lemma': 'зайнятий'}),
#    ({'word': 'запропонували', 'upos': 'VERB', 'lemma': 'запропонувати'},
#     {'word': 'інший', 'upos': 'DET', 'lemma': 'інший'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'псувати', 'upos': 'VERB', 'lemma': 'псувати'},
#     {'word': 'нерви', 'upos': 'NOUN', 'lemma': 'нерв'},
#     {'word': 'постояльцям', 'upos': 'NOUN', 'lemma': 'постояльця'}),
#    ({'word': 'третього', 'upos': 'ADJ', 'lemma': 'третій'},
#     {'word': 'разу', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'взяли', 'upos': 'VERB', 'lemma': 'взяти'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'третього', 'upos': 'ADJ', 'lemma': 'третій'},
#     {'word': 'разу', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'напів', 'upos': 'NOUN', 'lemma': 'нап'},
#     {'word': '-', 'upos': 'PUNCT', 'lemma': '-'},
#     {'word': 'зруйноване', 'upos': 'ADJ', 'lemma': 'зруйнований'}),
#    ({'word': 'стіл', 'upos': 'NOUN', 'lemma': 'стіл'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'день', 'upos': 'NOUN', 'lemma': 'день'},
#     {'word': 'можуть', 'upos': 'VERB', 'lemma': 'могти'}),
#    ({'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'},
#     {'word': '5', 'upos': 'NUM', 'lemma': '5'},
#     {'word': 'прийти', 'upos': 'VERB', 'lemma': 'прийти'}),
#    ({'word': 'можуть', 'upos': 'VERB', 'lemma': 'могти'},
#     {'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'},
#     {'word': '5', 'upos': 'NUM', 'lemma': '5'},
#     {'word': 'прийти', 'upos': 'VERB', 'lemma': 'прийти'}),
#    ({'word': 'шкода', 'upos': 'NOUN', 'lemma': 'шкода'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'номером', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'шкода', 'upos': 'NOUN', 'lemma': 'шкода'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'номером', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'перевіряли', 'upos': 'VERB', 'lemma': 'перевіряти'},
#     {'word': 'рази', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'видали', 'upos': 'VERB', 'lemma': 'видати'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'той', 'upos': 'DET', 'lemma': 'той'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'двомісний', 'upos': 'ADJ', 'lemma': 'двомісний'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'брали', 'upos': 'VERB', 'lemma': 'брати'},
#     {'word': 'двомісний', 'upos': 'ADJ', 'lemma': 'двомісний'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'великий', 'upos': 'ADJ', 'lemma': 'великий'},
#     {'word': 'плюс', 'upos': 'NOUN', 'lemma': 'плюс'}),
#    ({'word': 'плюс', 'upos': 'NOUN', 'lemma': 'плюс'},
#     {'word': 'ще', 'upos': 'ADV', 'lemma': 'ще'}),
#    ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'маленький', 'upos': 'ADJ', 'lemma': 'маленький'}),
#    ({'word': 'насиченого', 'upos': 'ADJ', 'lemma': 'насичений'},
#     {'word': 'дня', 'upos': 'NOUN', 'lemma': 'день'}),
#    ({'word': 'двокімнатному', 'upos': 'ADJ', 'lemma': 'двокімнатний'},
#     {'word': 'номері', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'перший', 'upos': 'ADJ', 'lemma': 'перший'},
#     {'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'}),
#    ({'word': 'раз', 'upos': 'NOUN', 'lemma': 'раз'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'таким', 'upos': 'PRON', 'lemma': 'такий'},
#     {'word': 'зіткнулися', 'upos': 'VERB', 'lemma': 'зіткнутися'}),
#    ({'word': 'ключі', 'upos': 'NOUN', 'lemma': 'ключ'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'як', 'upos': 'ADV', 'lemma': 'як'},
#     {'word': 'йому', 'upos': 'PRON', 'lemma': 'він'},
#     {'word': '20', 'upos': 'NUM', 'lemma': '20'},
#     {'word': 'років', 'upos': 'NOUN', 'lemma': 'рік'}),
#    ({'word': 'ще', 'upos': 'ADV', 'lemma': 'ще'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'найкращому', 'upos': 'NOUN', 'lemma': 'найкращий'}),
#    ({'word': 'номерах', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'ведуться', 'upos': 'VERB', 'lemma': 'вестися'}),
#    ({'word': 'отримали', 'upos': 'VERB', 'lemma': 'отримати'},
#     {'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'}),
#    ({'word': 'номер', 'upos': 'NOUN', 'lemma': 'номер'},
#     {'word': 'недавно', 'upos': 'ADV', 'lemma': 'недавно'},
# ...
#     {'word': 'умовах', 'upos': 'NOUN', 'lemma': 'умова'}),
#    ({'word': 'погодитися', 'upos': 'VERB', 'lemma': 'погодитися'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'співпрацю', 'upos': 'NOUN', 'lemma': 'співпраця'}),
#    ({'word': 'співпрацю', 'upos': 'NOUN', 'lemma': 'співпраця'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'таким', 'upos': 'DET', 'lemma': 'такий'},
#     {'word': 'блощичний', 'upos': 'ADJ', 'lemma': 'блощичний'}),
#    ({'word': 'пішли', 'upos': 'VERB', 'lemma': 'піти'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'зустріч', 'upos': 'NOUN', 'lemma': 'зустріч'}),
#    ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#     {'word': 'норм', 'upos': 'NOUN', 'lemma': 'норма'}),
#    ({'word': 'прислали', 'upos': 'VERB', 'lemma': 'прислати'},
#     {'word': 'відмову', 'upos': 'NOUN', 'lemma': 'відмова'}),
#    ({'word': 'взагалі', 'upos': 'ADV', 'lemma': 'взагалі'},
#     {'word': 'була', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'проблема', 'upos': 'NOUN', 'lemma': 'проблема'}),
#    ({'word': 'проблема', 'upos': 'NOUN', 'lemma': 'проблема'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'парило', 'upos': 'VERB', 'lemma': 'парити'}),
#    ({'word': 'були', 'upos': 'VERB', 'lemma': 'бути'},
#     {'word': 'здачі', 'upos': 'NOUN', 'lemma': 'здача'}),
#    ({'word': 'шукати', 'upos': 'VERB', 'lemma': 'шукати'},
#     {'word': 'квитанцію', 'upos': 'NOUN', 'lemma': 'квитанція'}),
#    ({'word': 'день', 'upos': 'NOUN', 'lemma': 'день'},
#     {'word': 'проблема', 'upos': 'NOUN', 'lemma': 'проблема'},
#     {'word': 'вирішилася', 'upos': 'VERB', 'lemma': 'вирішитися'}),
#    ({'word': 'проблема', 'upos': 'NOUN', 'lemma': 'проблема'},
#     {'word': 'вирішилася', 'upos': 'VERB', 'lemma': 'вирішитися'}),
#    ({'word': 'чек', 'upos': 'NOUN', 'lemma': 'чек'},
#     {'word': 'за', 'upos': 'ADP', 'lemma': 'за'},
#     {'word': 'послугу', 'upos': 'NOUN', 'lemma': 'послуга'}),
#    ({'word': 'послугу', 'upos': 'NOUN', 'lemma': 'послуга'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'яку', 'upos': 'DET', 'lemma': 'який'},
#     {'word': 'сплатив', 'upos': 'VERB', 'lemma': 'сплатити'}),
#    ({'word': 'чекали', 'upos': 'VERB', 'lemma': 'чекати'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'рецепції', 'upos': 'NOUN', 'lemma': 'рецепція'}),
#    ({'word': 'чекали', 'upos': 'VERB', 'lemma': 'чекати'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'рецепції', 'upos': 'NOUN', 'lemma': 'рецепція'}),
#    ({'word': 'приваблює', 'upos': 'VERB', 'lemma': 'приваблювати'},
#     {'word': 'увагу', 'upos': 'NOUN', 'lemma': 'увага'}),
#    ({'word': 'єдиною', 'upos': 'ADJ', 'lemma': 'єдиний'},
#     {'word': 'справою', 'upos': 'NOUN', 'lemma': 'справа'}),
#    ({'word': 'справою', 'upos': 'NOUN', 'lemma': 'справа'},
#     {'word': 'якого', 'upos': 'DET', 'lemma': 'який'},
#     {'word': 'був', 'upos': 'VERB', 'lemma': 'бути'}),
#    ({'word': 'хвилин', 'upos': 'NOUN', 'lemma': 'хвилина'},
#     {'word': 'біля', 'upos': 'ADP', 'lemma': 'біля'},
#     {'word': 'рецепції', 'upos': 'NOUN', 'lemma': 'рецепція'}),
#    ({'word': 'викликає', 'upos': 'VERB', 'lemma': 'викликати'},
#     {'word': 'нерозуміння', 'upos': 'NOUN', 'lemma': 'нерозуміння'}),
#    ({'word': 'огиду', 'upos': 'NOUN', 'lemma': 'огид'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': 'розуміння', 'upos': 'NOUN', 'lemma': 'розуміння'}),
#    ({'word': 'іронічною', 'upos': 'ADJ', 'lemma': 'іронічний'},
#     {'word': 'назвою', 'upos': 'NOUN', 'lemma': 'назва'}),
#    ({'word': 'пережиток', 'upos': 'NOUN', 'lemma': 'пережиток'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'іронічною', 'upos': 'ADJ', 'lemma': 'іронічний'},
#     {'word': 'назвою', 'upos': 'NOUN', 'lemma': 'назва'}),
#    ({'word': 'допомагав', 'upos': 'VERB', 'lemma': 'Допомагати'},
#     {'word': 'у', 'upos': 'ADP', 'lemma': 'у'},
#     {'word': 'всіх', 'upos': 'DET', 'lemma': 'весь'},
#     {'word': 'дрібницях', 'upos': 'NOUN', 'lemma': 'дрібниця'}),
#    ({'word': 'залишити', 'upos': 'VERB', 'lemma': 'залишити'},
#     {'word': 'речі', 'upos': 'NOUN', 'lemma': 'річ'}),
#    ({'word': 'залишити', 'upos': 'VERB', 'lemma': 'залишити'},
#     {'word': 'речі', 'upos': 'NOUN', 'lemma': 'річ'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': 'погуляти', 'upos': 'VERB', 'lemma': 'погуляти'}),
#    ({'word': 'поняті', 'upos': 'ADJ', 'lemma': 'понятий'},
#     {'word': 'були', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'передоплатою', 'upos': 'NOUN', 'lemma': 'передоплата'}),
#    ({'word': 'випрати', 'upos': 'VERB', 'lemma': 'випрати'},
#     {'word': 'речі', 'upos': 'NOUN', 'lemma': 'річ'}),
#    ({'word': 'момент', 'upos': 'NOUN', 'lemma': 'момент'},
#     {'word': 'поломки', 'upos': 'NOUN', 'lemma': 'поломка'}),
#    ({'word': 'відсутність', 'upos': 'NOUN', 'lemma': 'відсутність'},
#     {'word': 'зв', 'upos': 'NOUN', 'lemma': 'зв.'}),
#    ({'word': 'більше', 'upos': 'ADV', 'lemma': 'більше'},
#     {'word': 'інформації', 'upos': 'NOUN', 'lemma': 'інформація'}),
#    ({'word': 'надавати', 'upos': 'VERB', 'lemma': 'надавати'},
#     {'word': 'більше', 'upos': 'ADV', 'lemma': 'більше'},
#     {'word': 'інформації', 'upos': 'NOUN', 'lemma': 'інформація'}),
#    ({'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'},
#     {'word': 'можливості', 'upos': 'NOUN', 'lemma': 'можливість'}),
#    ({'word': 'цирк', 'upos': 'NOUN', 'lemma': 'цирк'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'передоплатою', 'upos': 'NOUN', 'lemma': 'передоплата'}),
#    ({'word': 'вперше', 'upos': 'ADV', 'lemma': 'вперше'},
#     {'word': 'така', 'upos': 'DET', 'lemma': 'такий'},
#     {'word': 'безвідповідальність',
#      'upos': 'NOUN',
#      'lemma': 'безвідповідальність'}),
#    ({'word': 'зворотний', 'upos': 'ADJ', 'lemma': 'зворотний'},
#     {'word': 'зв', 'upos': 'NOUN', 'lemma': 'зв.'}),
#    ({'word': 'відповідає', 'upos': 'VERB', 'lemma': 'відповідати'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'зворотний', 'upos': 'ADJ', 'lemma': 'зворотний'},
#     {'word': 'зв', 'upos': 'NOUN', 'lemma': 'зв.'}),
#    ({'word': 'заявлена', 'upos': 'ADJ', 'lemma': 'заявлений'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'послугах', 'upos': 'NOUN', 'lemma': 'послуга'}),
#    ({'word': 'питання', 'upos': 'NOUN', 'lemma': 'питання'},
#     {'word': ':', 'upos': 'PUNCT', 'lemma': ':'},
#     {'word': 'чи', 'upos': 'PART', 'lemma': 'чи'},
#     {'word': 'можна', 'upos': 'ADV', 'lemma': 'можна'}),
#    ({'word': 'позитивну', 'upos': 'ADJ', 'lemma': 'позитивний'},
#     {'word': 'відповідь', 'upos': 'NOUN', 'lemma': 'відповідь'}),
#    ({'word': 'отримали', 'upos': 'VERB', 'lemma': 'отримати'},
#     {'word': 'позитивну', 'upos': 'ADJ', 'lemma': 'позитивний'},
#     {'word': 'відповідь', 'upos': 'NOUN', 'lemma': 'відповідь'}),
#    ({'word': 'претензій', 'upos': 'NOUN', 'lemma': 'претензія'},
#     {'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'}),
#    ({'word': 'попередні', 'upos': 'ADJ', 'lemma': 'попередній'},
#     {'word': 'домовленості', 'upos': 'NOUN', 'lemma': 'домовленість'}),
#    ({'word': 'домовленості', 'upos': 'NOUN', 'lemma': 'домовленість'},
#     {'word': 'нічого', 'upos': 'PRON', 'lemma': 'ніщо'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'значать', 'upos': 'VERB', 'lemma': 'значити'}),
#    ({'word': 'речами', 'upos': 'NOUN', 'lemma': 'річ'},
#     {'word': 'їхати', 'upos': 'VERB', 'lemma': 'їхати'}),
#    ({'word': 'спасибі', 'upos': 'NOUN', 'lemma': 'спасибі'},
#     {'word': 'персоналу', 'upos': 'NOUN', 'lemma': 'персонал'},
#     {'word': 'за', 'upos': 'ADP', 'lemma': 'за'},
#     {'word': 'чуйність', 'upos': 'NOUN', 'lemma': 'чуйність'}),
#    ({'word': 'чуйність', 'upos': 'NOUN', 'lemma': 'чуйність'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': 'допомогу', 'upos': 'NOUN', 'lemma': 'допомога'}),
#    ({'word': 'пропускна', 'upos': 'ADJ', 'lemma': 'пропускний'},
#     {'word': 'система', 'upos': 'NOUN', 'lemma': 'система'}),
#    ({'word': 'постійні', 'upos': 'ADJ', 'lemma': 'постійний'},
#     {'word': 'уточнення', 'upos': 'NOUN', 'lemma': 'уточнення'}),
#    ({'word': 'стримано', 'upos': 'ADV', 'lemma': 'стримати'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'постійні', 'upos': 'ADJ', 'lemma': 'постійний'},
#     {'word': 'уточнення', 'upos': 'NOUN', 'lemma': 'уточнення'}),
#    ({'word': 'розмова', 'upos': 'NOUN', 'lemma': 'розмова'},
#     {'word': 'тривала', 'upos': 'ADJ', 'lemma': 'тривалий'}),
#    ({'word': 'труднощі', 'upos': 'ADJ', 'lemma': 'труднощі'},
#     {'word': 'уточнення', 'upos': 'NOUN', 'lemma': 'уточнення'}),
#    ({'word': 'тягне', 'upos': 'VERB', 'lemma': 'тягнути'},
#     {'word': 'з', 'upos': 'ADP', 'lemma': 'з'},
#     {'word': 'працею', 'upos': 'NOUN', 'lemma': 'праця'}),
#    ({'word': 'виході', 'upos': 'NOUN', 'lemma': 'вихід'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'питання', 'upos': 'NOUN', 'lemma': 'питання'}),
#    ({'word': 'приємний', 'upos': 'ADJ', 'lemma': 'приємний'},
#     {'word': 'відповідь', 'upos': 'NOUN', 'lemma': 'відповідь'}),
#    ({'word': 'вимагає', 'upos': 'VERB', 'lemma': 'вимагати'},
#     {'word': 'реставрації', 'upos': 'NOUN', 'lemma': 'реставрація'}),
#    ({'word': 'ремонтні', 'upos': 'ADJ', 'lemma': 'ремонтний'},
#     {'word': 'роботи', 'upos': 'NOUN', 'lemma': 'робота'}),
#    ({'word': 'ведуться', 'upos': 'VERB', 'lemma': 'вестися'},
#     {'word': 'ремонтні', 'upos': 'ADJ', 'lemma': 'ремонтний'},
#     {'word': 'роботи', 'upos': 'NOUN', 'lemma': 'робота'}),
#    ({'word': 'автобусна', 'upos': 'ADJ', 'lemma': 'автобусний'},
#     {'word': 'зупинка', 'upos': 'NOUN', 'lemma': 'зупинка'}),
#    ({'word': 'знаходиться', 'upos': 'VERB', 'lemma': 'знаходитися'},
#     {'word': 'автобусна', 'upos': 'ADJ', 'lemma': 'автобусний'},
#     {'word': 'зупинка', 'upos': 'NOUN', 'lemma': 'зупинка'}),
#    ({'word': 'опису', 'upos': 'NOUN', 'lemma': 'опис'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'претензій', 'upos': 'NOUN', 'lemma': 'претензія'}),
#    ({'word': 'вирішити', 'upos': 'VERB', 'lemma': 'вирішити'},
#     {'word': 'цю', 'upos': 'DET', 'lemma': 'цей'},
#     {'word': 'проблему', 'upos': 'NOUN', 'lemma': 'проблема'}),
#    ({'word': 'курсі', 'upos': 'NOUN', 'lemma': 'курс'},
#     {'word': 'всіх', 'upos': 'DET', 'lemma': 'весь'},
#     {'word': 'подробиць', 'upos': 'NOUN', 'lemma': 'подробиця'}),
#    ({'word': 'прийти', 'upos': 'VERB', 'lemma': 'прийти'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'допомогу', 'upos': 'NOUN', 'lemma': 'допомога'}),
#    ({'word': 'різних', 'upos': 'ADJ', 'lemma': 'різний'},
#     {'word': 'роботах', 'upos': 'NOUN', 'lemma': 'робота'}),
#    ({'word': 'працюють', 'upos': 'VERB', 'lemma': 'працювати'},
#     {'word': 'на', 'upos': 'ADP', 'lemma': 'на'},
#     {'word': 'різних', 'upos': 'ADJ', 'lemma': 'різний'},
#     {'word': 'роботах', 'upos': 'NOUN', 'lemma': 'робота'}),
#    ({'word': 'роботах', 'upos': 'NOUN', 'lemma': 'робота'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'україні', 'upos': 'PROPN', 'lemma': 'Україна'}),
#    ({'word': 'особливих', 'upos': 'ADJ', 'lemma': 'особливий'},
#     {'word': 'проблем', 'upos': 'NOUN', 'lemma': 'проблема'}),
#    ({'word': 'речі', 'upos': 'NOUN', 'lemma': 'річ'},
#     {'word': 'складаєш', 'upos': 'VERB', 'lemma': 'складати'}),
#    ({'word': 'відповідає', 'upos': 'VERB', 'lemma': 'відповідати'},
#     {'word': 'дійсності', 'upos': 'NOUN', 'lemma': 'дійсність'}),
#    ({'word': 'питання', 'upos': 'NOUN', 'lemma': 'питання'},
#     {'word': 'більше', 'upos': 'ADV', 'lemma': 'більше'}),
#    ({'word': 'робота', 'upos': 'NOUN', 'lemma': 'робота'},
#     {'word': 'є', 'upos': 'VERB', 'lemma': 'бути'},
#     {'word': 'робота', 'upos': 'NOUN', 'lemma': 'робота'}),
#    ({'word': 'хочемо', 'upos': 'VERB', 'lemma': 'хотіти'},
#     {'word': 'спати', 'upos': 'VERB', 'lemma': 'спати'},
#     {'word': 'але', 'upos': 'CCONJ', 'lemma': 'але'},
#     {'word': 'робота', 'upos': 'NOUN', 'lemma': 'робота'}),
#    ({'word': 'сильна', 'upos': 'ADJ', 'lemma': 'сильний'},
#     {'word': 'сутність', 'upos': 'NOUN', 'lemma': 'сутність'}),
#    ({'word': 'адміністратор', 'upos': 'NOUN', 'lemma': 'адміністратор'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': 'умови', 'upos': 'NOUN', 'lemma': 'умова'}),
#    ({'word': 'першу', 'upos': 'ADJ', 'lemma': 'перший'},
#     {'word': 'чергу', 'upos': 'NOUN', 'lemma': 'черга'}),
#    ({'word': 'порадували', 'upos': 'VERB', 'lemma': 'порадувати'},
#     {'word': 'умови', 'upos': 'NOUN', 'lemma': 'умова'}),
#    ({'word': 'міста', 'upos': 'NOUN', 'lemma': 'місто'},
#     {'word': 'по', 'upos': 'ADP', 'lemma': 'по'},
#     {'word': 'суті', 'upos': 'NOUN', 'lemma': 'суть'}),
#    ({'word': 'будинку', 'upos': 'NOUN', 'lemma': 'будинок'},
#     {'word': 'кілька', 'upos': 'DET', 'lemma': 'кілька'},
#     {'word': 'організацій', 'upos': 'NOUN', 'lemma': 'організація'},
#     {'word': 'здають', 'upos': 'VERB', 'lemma': 'здавати'}),
#    ({'word': 'організацій', 'upos': 'NOUN', 'lemma': 'організація'},
#     {'word': 'здають', 'upos': 'VERB', 'lemma': 'здавати'}),
#    ({'word': 'ціна', 'upos': 'NOUN', 'lemma': 'ціна'},
#     {'word': 'і', 'upos': 'CCONJ', 'lemma': 'і'},
#     {'word': 'доброзичливість', 'upos': 'NOUN', 'lemma': 'доброзичливість'}),
#    ({'word': 'наслідками', 'upos': 'NOUN', 'lemma': 'наслідок'},
#     {'word': ',', 'upos': 'PUNCT', 'lemma': ','},
#     {'word': 'що', 'upos': 'SCONJ', 'lemma': 'що'},
#     {'word': 'випливають', 'upos': 'VERB', 'lemma': 'випливати'}),
#    ({'word': 'умови', 'upos': 'NOUN', 'lemma': 'умова'},
#     {'word': 'не', 'upos': 'PART', 'lemma': 'не'},
#     {'word': 'шикарні', 'upos': 'ADJ', 'lemma': 'шикарня'}),
#    ({'word': 'було', 'upos': 'VERB', 'lemma': 'бути'},
#     {'word': 'можливості', 'upos': 'NOUN', 'lemma': 'можливість'}),
#    ({'word': 'можливості', 'upos': 'NOUN', 'lemma': 'можливість'},
#     {'word': 'погладити', 'upos': 'VERB', 'lemma': 'погладити'}),
#    ({'word': 'ставитися', 'upos': 'VERB', 'lemma': 'ставитися'},
#     {'word': 'до', 'upos': 'ADP', 'lemma': 'до'},
#     {'word': 'реальності', 'upos': 'NOUN', 'lemma': 'реальність'}),
#    ({'word': 'мета', 'upos': 'NOUN', 'lemma': 'мета'},
#     {'word': 'була', 'upos': 'AUX', 'lemma': 'бути'},
#     {'word': 'переночувати', 'upos': 'VERB', 'lemma': 'переночувати'}),
#    ({'word': 'ремонт', 'upos': 'NOUN', 'lemma': 'ремонт'},
#     {'word': '.', 'upos': 'PUNCT', 'lemma': '.'},
#     {'word': 'послуги', 'upos': 'NOUN', 'lemma': 'послуга'}),
#    ({'word': 'поруч', 'upos': 'ADV', 'lemma': 'поруч'},
#     {'word': 'автобусна', 'upos': 'ADJ', 'lemma': 'автобусний'},
#     {'word': 'зупинка', 'upos': 'NOUN', 'lemma': 'зупинка'}),
#    ({'word': 'автобусна', 'upos': 'ADJ', 'lemma': 'автобусний'},
#     {'word': 'зупинка', 'upos': 'NOUN', 'lemma': 'зупинка'}),
#    ({'word': 'звідси', 'upos': 'ADV', 'lemma': 'звідси'},
#     {'word': 'всі', 'upos': 'DET', 'lemma': 'весь'},
#     {'word': 'наслідки', 'upos': 'NOUN', 'lemma': 'наслідок'}),
#    ({'word': 'рятує', 'upos': 'VERB', 'lemma': 'рятувати'},
#     {'word': 'ситуацію', 'upos': 'NOUN', 'lemma': 'ситуація'}),
#    ({'word': 'номери', 'upos': 'NOUN', 'lemma': 'Номери'},
#     {'word': 'в', 'upos': 'ADP', 'lemma': 'в'},
#     {'word': 'цілому', 'upos': 'NOUN', 'lemma': 'ціле'},
#     {'word': 'непогані', 'upos': 'NOUN', 'lemma': 'непоганий'}),
#    ({'word': 'цілому', 'upos': 'NOUN', 'lemma': 'ціле'},
#     {'word': 'непогані', 'upos': 'NOUN', 'lemma': 'непоганий'}),
#    ({'word': 'претензій', 'upos': 'NOUN', 'lemma': 'претензія'},
#     {'word': 'немає', 'upos': 'VERB', 'lemma': 'немати'}),
#    ({'word': 'вигідна', 'upos': 'ADJ', 'lemma': 'вигідний'},
#     {'word': 'пропозиція', 'upos': 'NOUN', 'lemma': 'пропозиція'})],
#   'centroid': ({'word': 'проблем', 'upos': 'NOUN', 'lemma': 'проблема'},
#    {'word': 'дозволив', 'upos': 'VERB', 'lemma': 'дозволити'},
#    {'word': 'залишити', 'upos': 'VERB', 'lemma': 'залишити'})}}

# %% [markdown]
# So, and now we can print **pre-summary** about example  hotel (centroid collocation for each cluster)

# %%
example_summary = []
for key in example_hotel_clustered:
    centroid = example_hotel_clustered[key]['centroid']
    words = [item['word'] for item in centroid]
    example_summary.append(' '.join(words))
example_summary
# Out:
# ['чистота в номері',
#  'загальний сам готель',
#  'матрац на ліжку',
#  'персонал не потурбувався',
#  'дозволив залишити',
#  'ванна кімната',
#  'врахувати ціну',
#  'проблем дозволив залишити']

# %% [markdown]
# Let's cluster all collocations for each hotel

# %%
hotel_clustered_dict = {hotel: cluster_collocations.cluster_collocations(hotel_collocations_dict[hotel], K_CLUSTERS) 
                        for hotel in hotel_collocations_dict}
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-28-bcaba7b350bd> in <module>
#       1 hotel_clustered_dict = {hotel: cluster_collocations.cluster_collocations(hotel_collocations_dict[hotel], K_CLUSTERS)
# ----> 2                         for hotel in hotel_collocations_dict}
#
# <ipython-input-28-bcaba7b350bd> in <dictcomp>(.0)
#       1 hotel_clustered_dict = {hotel: cluster_collocations.cluster_collocations(hotel_collocations_dict[hotel], K_CLUSTERS)
# ----> 2                         for hotel in hotel_collocations_dict}
#
# ~/DS/NLP/insights-from-user-reviews/clustering/cluster_collocations.py in cluster_collocations(self, collocations, num_cluster)
#      14         X, filtered_collocations = self.__convert_collocations_to_embedding_vectors(collocations)
#      15         kclusterer = KMeansClusterer(num_cluster, distance=nltk.cluster.util.cosine_distance, avoid_empty_clusters=True, repeats=100)
# ---> 16         y = kclusterer.cluster(X, assign_clusters=True)
#      17
#      18         top_indices = self.__find_top_n_gram_indices(X, y, kclusterer.means())
#
# /usr/local/lib/python3.7/dist-packages/nltk/cluster/util.py in cluster(self, vectors, assign_clusters, trace)
#      60
#      61         # call abstract method to cluster the vectors
# ---> 62         self.cluster_vectorspace(vectors, trace)
#      63
#      64         # assign the vectors to clusters
#
# /usr/local/lib/python3.7/dist-packages/nltk/cluster/kmeans.py in cluster_vectorspace(self, vectors, trace)
#      92             if not self._means or trial > 1:
#      93                 self._means = self._rng.sample(list(vectors), self._num_means)
# ---> 94             self._cluster_vectorspace(vectors, trace)
#      95             meanss.append(self._means)
#      96
#
# /usr/local/lib/python3.7/dist-packages/nltk/cluster/kmeans.py in _cluster_vectorspace(self, vectors, trace)
#     123                 clusters = [[] for m in range(self._num_means)]
#     124                 for vector in vectors:
# --> 125                     index = self.classify_vectorspace(vector)
#     126                     clusters[index].append(vector)
#     127
#
# /usr/local/lib/python3.7/dist-packages/nltk/cluster/kmeans.py in classify_vectorspace(self, vector)
#     149             mean = self._means[index]
#     150             dist = self._distance(vector, mean)
# --> 151             if best_distance is None or dist < best_distance:
#     152                 best_index, best_distance = index, dist
#     153         return best_index
#
# KeyboardInterrupt:

# %% [markdown]
# ### Detect hotel topic type

# %% [markdown]
# As now we have separate clusters, let's detect which topic is related to each cluster. <br>
# initially, there is simple rule-based classifier for baseline.

# %%
from clustering.cluster_topic_detector import RuleBasedTopicDetector

# %%
topic_detector = RuleBasedTopicDetector()

# %% [markdown]
# Let's detect topics for clusters of example hotel

# %%
def detect_topic_for_hotel_cluster(hotel_clustered):
    hotel_topic_clustered = dict()
    for key in hotel_clustered:
        collocations = hotel_clustered[key]['collocations']
        topic = topic_detector.detect_cluster_topic_type(collocations)

        if topic not in hotel_topic_clustered:
            hotel_topic_clustered[topic] = hotel_clustered[key]
        else:
            hotel_topic_clustered[topic]['collocations'] += collocations
            
    return hotel_topic_clustered

# %%
example_hotel_topic_clustered = detect_topic_for_hotel_cluster(example_hotel_clustered)

# %%
example_hotel_topic_clustered.keys()

# %% [markdown]
# As we can see, the number of detected topic is less that number of cluster. It is caused that some clusters has the same topic and algortihm for clustering do not work very well now.

# %% [markdown]
# Let's detect topics for clusters of each hotel

# %%
hotel_topic_clustered_dict = {
    hotel: detect_topic_for_hotel_cluster(hotel_clustered_dict[hotel])
    for hotel in hotel_clustered_dict
}

# %% [markdown]
# ### Detect sentiment of clusters

# %%
from enum import IntEnum
class SentimentType(IntEnum):
    NEGATIVE = 0, 
    NEUTRAL = 1,
    POSITIVE = 2

# %%
import itertools

# %% [markdown]
# #### Load pmi tonal dictionary for adjectives

# %% [markdown]
# As we have already had pmi dictionaries for adjectives which are acquired from postive and negative reviews, lent's use this information for detecting sentiment of cluster.

# %% [markdown]
# To see, how the dictionary was built, please use the following link: http://localhost:8888/notebooks/insights-from-user-reviews/build-sentiment-dictionary.ipynb

# %%
pos_adj_pmi_dict = load_json('data/pos-adj-pmi.json')
neg_adj_pmi_dict = load_json('data/neg-adj-pmi.json')

# %% [markdown]
# Top positive adjective lemmas

# %%
dict(itertools.islice(pos_adj_pmi_dict.items(), 10))

# %%
pos_adj_pmi_dict['привітний']

# %% [markdown]
# Top negative adjective lemmas

# %%
dict(itertools.islice(neg_adj_pmi_dict.items(), 10))

# %%
neg_adj_pmi_dict['шумний']

# %%
pmi_threshold = 0.1

# %% [markdown]
# #### Detect sentiment

# %%
def detect_sentiment_of_cluster(cluster, pos_adj_pmi_dict, neg_adj_pmi_dict, pmi_threshold):
    adjectives = []
    for cluster_item in cluster:
        adjectives += [collocation['lemma'] for collocation in cluster_item if collocation['upos'] == 'ADJ']
    
    
    pos_pmis, neg_pmis = [], []
    for adj in adjectives:
        
        if adj in pos_adj_pmi_dict:
            pmi = pos_adj_pmi_dict[adj]
            if pmi >= pmi_threshold:
                pos_pmis.append(pmi)
                
        if adj in neg_adj_pmi_dict:
            pmi = neg_adj_pmi_dict[adj]
            if pmi >= pmi_threshold:
                neg_pmis.append(pmi)
                
#     return pos_pmis, neg_pmis
    
    if len(neg_pmis) / len(pos_pmis) <= 0.75:
        return SentimentType.POSITIVE
    
    if len(pos_pmis) / len(neg_pmis) <= 0.75:
        return SentimentType.NEGATIVE    

#     pos_pmi_avg = sum(pos_pmis) / len(pos_pmis)
#     neg_pmi_avg = sum(neg_pmis) / len(meg_pmis)
    
    
    return SentimentType.NEUTRAL

# %%
def detect_sentiments_of_clusters_for_hotel(hotel_topic_clustered, pos_adj_pmi_dict, neg_adj_pmi_dict, pmi_threshold):
    for topic in hotel_topic_clustered:
        collocations = hotel_topic_clustered[topic]['collocations']
        sentiment = detect_sentiment_of_cluster(collocations, pos_adj_pmi_dict, neg_adj_pmi_dict, pmi_threshold)
        hotel_topic_clustered[topic]['sentiment'] = sentiment
        
    return hotel_topic_clustered

# %% [markdown]
# Detect sentiment for clusters of example hotel

# %%
example_hotel_topic_clustered = detect_sentiments_of_clusters_for_hotel(example_hotel_topic_clustered, pos_adj_pmi_dict, neg_adj_pmi_dict, pmi_threshold)

# %%
{print(topic, " : ", example_hotel_topic_clustered[topic]['sentiment']) for topic in example_hotel_topic_clustered}

# %% [markdown]
# ### Detect sentiment for each test hotel

# %%
for hotel in hotel_topic_clustered_dict:
    detect_sentiments_of_clusters_for_hotel(hotel_topic_clustered_dict[hotel], pos_adj_pmi_dict, neg_adj_pmi_dict, pmi_threshold)

# %% [markdown]
# ## Metric

# %%
def mark2sentiment(mark_value):
    if mark_value == -1:
        return SentimentType.NEUTRAL
    
    if mark_value > 8:
        return SentimentType.POSITIVE
    
    if mark_value > 7:
        return SentimentType.NEUTRAL
    
    return SentimentType.NEGATIVE

# %%
hotel_topic_marks_test.head()

# %% [markdown]
# As we have mark data for each topic in each hotel, let's convert this data into suitable sentiment for comparing with predicted.

# %%
hotel_topic_sentiments = dict()
for index, row in hotel_topic_marks_test.iterrows():
    hotel_topic_sentiments[row['hotel']] = {
        TopicType.CLEAN : mark2sentiment(row['hotel_clean']),
        TopicType.COMFORT : mark2sentiment(row['hotel_comfort']),
        TopicType.LOCATION : mark2sentiment(row['hotel_location']),
        TopicType.SERVICES : mark2sentiment(row['hotel_services']),
        TopicType.STAFF : mark2sentiment(row['hotel_staff']),
        TopicType.VALUE : mark2sentiment(row['hotel_value']),
        TopicType.WIFI : mark2sentiment(row['hotel_free_wifi']),
    }

# %%
hotel_topic_sentiments

# %%
y_pred, y_test = [], []
for hotel in hotel_topic_clustered_dict:
    if hotel not in hotel_topic_sentiments:
        continue
    
    for topic in hotel_topic_sentiments[hotel]:
        y_test.append(hotel_topic_sentiments[hotel][topic])
        
        if topic in hotel_topic_clustered_dict[hotel]:
            pred_sent = hotel_topic_clustered_dict[hotel][topic]['sentiment']
            y_pred.append(pred_sent)
        else:
            y_pred.append(SentimentType.NEUTRAL)
            
assert len(y_pred) == len(y_test)

# %%
from sklearn.metrics import classification_report

# %%
report = classification_report(y_pred=y_pred, y_true=y_test)
print(report)

# %% [markdown]
# ## Summary example

# %% [markdown]
# One of the main final task is to generate summary about hotel. Let's show simple baseline example

# %%
def acquire_hote_summary(hotel_info):
    summary = dict()
    for topic in hotel_info:
        sent = hotel_info[topic]['sentiment']
        words = [item['word'] for item in hotel_info[topic]['centroid']]
        phrase = ' '.join(words)
        
        if sent not in summary:
            summary[sent] = [phrase]
        else:
            summary[sent].append(phrase)
        
    return summary

# %%
hotels = list(hotel_topic_clustered_dict.keys())[:2]

# %%
hotels[0]

# %%
acquire_hote_summary(hotel_topic_clustered_dict[hotels[0]])

# %%
hotels[1]

# %%
acquire_hote_summary(hotel_topic_clustered_dict[hotels[1]])

# %% [markdown]
# ## TODO for improvements

# %% [markdown]
# 1. Implement smarter extraction of collocations. Filter collocation noise. Consider dependency tree deeply. <br>
# 2. Improve collocation clustering. In this case, we are going to use synonym dictionaries or fine-tuned existed embeddings on our domain. <br>
# 3. Annotate data for detection topic (location, staff, etc) of collocations. Train classifier for this purpose. <br>
# 4. Consider more approaches how to identify sentiment of cluster (improve existing dictionary, train classifier, etc.) <br>
# 5. Consider more approaches for summary geneartion about specific hotel.
