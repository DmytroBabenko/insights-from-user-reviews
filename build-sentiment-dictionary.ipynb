# %%
import numpy as np
import stanza

# %%
nlp_uk = stanza.Pipeline(lang="uk")
# Out:
# 2020-06-09 15:42:06 INFO: Loading these models for language: uk (Ukrainian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | iu      |
# | mwt       | iu      |
# | pos       | iu      |
# | lemma     | iu      |
# | depparse  | iu      |
# =======================
#
# 2020-06-09 15:42:06 INFO: Use device: gpu
# 2020-06-09 15:42:06 INFO: Loading: tokenize
# 2020-06-09 15:42:09 INFO: Loading: mwt
# 2020-06-09 15:42:09 INFO: Loading: pos
# 2020-06-09 15:42:10 INFO: Loading: lemma
# 2020-06-09 15:42:10 INFO: Loading: depparse
# 2020-06-09 15:42:11 INFO: Done loading processors!

# %%
import pandas as pd
import json

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
def save_data_to_json(data, file):
    with open(file, 'w') as f:
        json.dump(data, f)

# %%
def load_json(file):
    with open(file, 'r') as f:
        data = json.load(f)
        return data

# %%
def sort_dict_by_values(d, reverse=False):
    return {k: v for k, v in sorted(d.items(), key=lambda item: item[1], reverse=reverse)}

# %%
def read_all_files_in_one_df(files):
    all_df = []
    for file in files:
        df = pd.read_csv(file)
        all_df.append(df)
    return pd.concat(all_df)

# %% [markdown]
# ### Load data

# %%
booking_files = [
    '/home/dbabenko/Data-Science/NLP/Detect-emotion-sentimental/dataset/booking/booking-train.csv',
    '/home/dbabenko/Data-Science/NLP/Detect-emotion-sentimental/dataset/booking/booking-test.csv',
    '/home/dbabenko/Data-Science/NLP/Detect-emotion-sentimental/dataset/booking/booking-val.csv',
]

# %%
booking_df = read_all_files_in_one_df(booking_files)

# %%
booking_df.head()
# Out:
#                                                title  \
# 0  Лише дівчата на рецепції - три рази мені мінял...
# 1  Оформлення кімнати хороше, досить приємне, на ...
# 2  Усе відмінно, завдяки якісному сервісу ми завж...
# 3                            Ціна/якість в принципі
# 4  Приїхали з сином біля сьомої ранку, сонні та в...
#
#                                             pos_text  \
# 0  Лише дівчата на рецепції - три рази мені мінял...
# 1  Оформлення кімнати хороше, досить приємне, на ...
# 2  Усе відмінно, завдяки якісному сервісу ми завж...
# 3                             Ціна/якість в принципі
# 4  Приїхали з сином біля сьомої ранку, сонні та в...
#
#                                             neg_text  ratingValue  bestRating  \
# 0  Все. Одного досвіду вистарчило, щоб більше сюд...          4.6        10.0
# 1                                                Nan          9.2        10.0
# 2  Рекомендую людям котрі подорожують власним тра...         10.0        10.0
# 3  душова, трохи старий ремонт, але за 500 грн за...          7.5        10.0
# 4                                                Nan          8.3        10.0
#
#                hotel  rating
# 0  verhovina.uk.html       2
# 1  verhovina.uk.html       5
# 2  verhovina.uk.html       5
# 3  verhovina.uk.html       4
# 4  verhovina.uk.html       4

# %%
# !ls dataset/google-booking-association/
# Out:
# google-booking-association.json  google-booking-hotels-train.json
# google-booking-hotels-test.json

# %%
google_booking_dict_test = load_json('dataset/google-booking-association/google-booking-hotels-test.json')

# %%
booking_hotels_test = list(google_booking_dict_test.values())

# %%
booking_test_df = booking_df.loc[booking_df['hotel'].isin(booking_hotels_test)]

# %%
booking_test_df.head()
# Out:
#                                                  title  \
# 1786               Хороше розташування , приємна ціна.
# 1787                                   в цілому добре.
# 1788                                   Гарний будинок.
# 1789  Персонал взагалі не відповідає ніяким критеріям.
# 1790                                             Все\n
#
#                                                pos_text  \
# 1786                Хороше розташування , приємна ціна.
# 1787  Готель хороший, в хорошому місці,гарні номери,...
# 1788  Гарний будинок. Вид з вікна зачаровує. Затишно...
# 1789                                                Nan
# 1790                                                Все
#
#                                                neg_text  ratingValue  \
# 1786  В душі багато павуків, грибок, обідрані дивани...          5.8
# 1787  але ліжко двоспальне не передбачає зсунуті два...          7.9
# 1788           В душі грибок...Ручка в дверях Коломана.          9.2
# 1789  Персонал взагалі не відповідає ніяким критерія...          4.5
# 1790                                             Нічого         10.0
#
#       bestRating                         hotel  rating
# 1786        10.0  kiev-hotel-rock-wall.uk.html       3
# 1787        10.0  kiev-hotel-rock-wall.uk.html       4
# 1788        10.0  kiev-hotel-rock-wall.uk.html       5
# 1789        10.0  kiev-hotel-rock-wall.uk.html       2
# 1790        10.0  kiev-hotel-rock-wall.uk.html       5

# %%
len(booking_test_df)
# Out:
# 7894

# %%
booking_test_df.to_csv('dataset/booking/booking-test.csv')

# %%
booking_train_df = booking_df.loc[~booking_df['hotel'].isin(booking_hotels_test)]

# %%
len(booking_train_df)
# Out:
# 126189

# %%
booking_train_df.to_csv('dataset/booking/booking-train.csv')

# %% [markdown]
# ##  Calculate positve and negative dictionary

# %%
text_ex = booking_train_df['pos_text'].values[0]

# %%
doc = nlp_uk(text_ex)
doc.sentences[0]
# Out:
# [
#   {
#     "id": "1",
#     "text": "Лише",
#     "lemma": "лише",
#     "upos": "PART",
#     "xpos": "Q",
#     "head": 2,
#     "deprel": "discourse",
#     "misc": "start_char=0|end_char=4"
#   },
#   {
#     "id": "2",
#     "text": "дівчата",
#     "lemma": "дівчина",
#     "upos": "NOUN",
#     "xpos": "Ncfpny",
#     "feats": "Animacy=Anim|Case=Nom|Gender=Fem|Number=Plur",
#     "head": 9,
#     "deprel": "nsubj",
#     "misc": "start_char=5|end_char=12"
#   },
#   {
#     "id": "3",
#     "text": "на",
#     "lemma": "на",
#     "upos": "ADP",
#     "xpos": "Spsl",
#     "feats": "Case=Loc",
#     "head": 4,
#     "deprel": "case",
#     "misc": "start_char=13|end_char=15"
#   },
#   {
#     "id": "4",
#     "text": "рецепції",
#     "lemma": "рецепція",
#     "upos": "NOUN",
#     "xpos": "Ncfsln",
#     "feats": "Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing",
#     "head": 2,
#     "deprel": "nmod",
#     "misc": "start_char=16|end_char=24"
#   },
#   {
#     "id": "5",
#     "text": "-",
#     "lemma": "-",
#     "upos": "PUNCT",
#     "xpos": "U",
#     "feats": "PunctType=Dash",
#     "head": 9,
#     "deprel": "punct",
#     "misc": "start_char=25|end_char=26"
#   },
#   {
#     "id": "6",
#     "text": "три",
#     "lemma": "три",
#     "upos": "NUM",
#     "xpos": "Mlc-a",
#     "feats": "Case=Acc|NumType=Card",
#     "head": 7,
#     "deprel": "nummod",
#     "misc": "start_char=27|end_char=30"
#   },
#   {
#     "id": "7",
#     "text": "рази",
#     "lemma": "раз",
#     "upos": "NOUN",
#     "xpos": "Ncmpan",
#     "feats": "Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur",
#     "head": 9,
#     "deprel": "obl",
#     "misc": "start_char=31|end_char=35"
#   },
#   {
#     "id": "8",
#     "text": "мені",
#     "lemma": "я",
#     "upos": "PRON",
#     "xpos": "Pp-1-ysdn",
#     "feats": "Animacy=Anim|Case=Dat|Number=Sing|Person=1|PronType=Prs",
#     "head": 9,
#     "deprel": "iobj",
#     "misc": "start_char=36|end_char=40"
#   },
#   {
#     "id": "9",
#     "text": "міняли",
#     "lemma": "міняти",
#     "upos": "VERB",
#     "xpos": "Vmpis-p",
#     "feats": "Aspect=Imp|Mood=Ind|Number=Plur|Tense=Past|VerbForm=Fin",
#     "head": 0,
#     "deprel": "root",
#     "misc": "start_char=41|end_char=47"
#   },
#   {
#     "id": "10",
#     "text": "кімнату",
#     "lemma": "кімната",
#     "upos": "NOUN",
#     "xpos": "Ncfsan",
#     "feats": "Animacy=Inan|Case=Acc|Gender=Fem|Number=Sing",
#     "head": 9,
#     "deprel": "obj",
#     "misc": "start_char=48|end_char=55"
#   },
#   {
#     "id": "11",
#     "text": ".",
#     "lemma": ".",
#     "upos": "PUNCT",
#     "xpos": "U",
#     "head": 9,
#     "deprel": "punct",
#     "misc": "start_char=55|end_char=56"
#   }
# ]

# %%
def acquire_sentiment_pos_for_text(nlp, text, result, supporeted_pos = ['ADJ', 'ADV']):
    doc = nlp(text)
    num_words = 0
    for sent in doc.sentences:
        for token in sent.to_dict():
            if 'upos' not in token:
                continue
            pos = token['upos']
            if pos == 'PUNCT':
                continue
                
            num_words += 1
            if pos in supporeted_pos:
                lemma = token['lemma']
                if pos not in result:
                    result[pos] = dict()
                    result[pos][lemma] = 1
                else:
                    if lemma not in result[pos]:
                        result[pos][lemma] = 1
                    else:
                        result[pos][lemma] += 1      
    return num_words

# %%
def acquire_sentiment_pos(nlp, texts):
    result = dict()
    total_num_words = 0
    for text in texts:
        if len(text) == 0:
            continue
        if text == 'Nan':
            continue
            
        total_num_words += acquire_sentiment_pos_for_text(nlp, text, result)
    
    for pos in result:
        result[pos] = {k: v for k, v in sorted(result[pos].items(), key=lambda item: item[1], reverse=True)}
    
    return result, total_num_words

# %%
# %time pos_dict, total_pos_num_words = acquire_sentiment_pos(nlp_uk, booking_train_df['pos_text'].values)
# Out:
# CPU times: user 1h 54min 43s, sys: 14.5 s, total: 1h 54min 58s
# Wall time: 1h 55min 1s

# %%
total_pos_num_words
# Out:
# 2012137

# %%
save_data_to_json(pos_dict, 'dataset/booking/pos_words.json')

# %%
# %time neg_dict, total_neg_num_words = acquire_sentiment_pos(nlp_uk, booking_train_df['neg_text'].values)
# Out:
# CPU times: user 1h 35min 51s, sys: 11.4 s, total: 1h 36min 3s
# Wall time: 1h 35min 57s

# %%
total_neg_num_words
# Out:
# 2159506

# %%
save_data_to_json(neg_dict, 'dataset/booking/neg_words.json')

# %% [markdown]
# ## Calculate PMI for adjectives abd verbs in existing corpus

# %%
neg_dict
# Out:
# {'ADV': {'дуже': 20213,
#   'так': 7525,
#   'можна': 5821,
#   'трохи': 4144,
#   'ще': 3998,
#   'коли': 3976,
#   'тому': 3850,
#   'потрібно': 3652,
#   'як': 3617,
#   'вже': 3435,
#   'холодно': 2702,
#   'там': 2687,
#   'чутно': 2559,
#   'взагалі': 2558,
#   'більше': 2493,
#   'вночі': 2402,
#   'добре': 2355,
#   'погано': 2271,
#   'треба': 2239,
#   'шумно': 2201,
#   'де': 2043,
#   'досить': 1967,
#   'зовсім': 1957,
#   'неможливо': 1866,
#   'краще': 1818,
#   'далеко': 1774,
#   'теж': 1735,
#   'також': 1731,
#   'вранці': 1659,
#   'мало': 1517,
#   'поруч': 1517,
#   'особливо': 1419,
#   'постійно': 1395,
#   'зручно': 1383,
#   'можливо': 1291,
#   'потім': 1206,
#   'тут': 1196,
#   'відразу': 1179,
#   'сильно': 1154,
#   'довго': 1078,
#   'важко': 1078,
#   'ввечері': 1052,
#   'поки': 1016,
#   'прохолодно': 1009,
#   'чисто': 994,
#   'багато': 992,
#   'незручно': 979,
#   'більш': 960,
#   'варто': 932,
#   'абсолютно': 905,
#   'завжди': 901,
#   'занадто': 899,
#   'складно': 883,
#   'майже': 874,
#   'прямо': 866,
#   'раніше': 840,
#   'нормально': 837,
#   'брудний': 828,
#   'звичайно': 798,
#   'мабуть': 790,
#   'практично': 772,
#   'відмінно': 702,
#   'душно': 691,
#   'чому': 679,
#   'видно': 675,
#   'жахливо': 670,
#   'куди': 669,
#   'голосно': 662,
#   'напевно': 657,
#   'само': 636,
#   'комфортно': 622,
#   'давно': 590,
#   'неприємно': 587,
#   'необхідно': 575,
#   'жарко': 573,
#   'спочатку': 572,
#   'ніде': 572,
#   'пішки': 571,
#   'чудово': 561,
#   'туди': 560,
#   'явно': 553,
#   'іноді': 553,
#   'загалом': 540,
#   'ледве': 516,
#   'може': 516,
#   'швидко': 511,
#   'знову': 510,
#   'повністю': 503,
#   'уже': 482,
#   'критично': 479,
#   'вище': 475,
#   'надто': 472,
#   'зрозуміло': 466,
#   'приємно': 459,
#   'пізно': 458,
#   'швидше': 449,
#   'десь': 427,
#   'набагато': 417,
#   'дивно': 415,
#   'якось': 414,
#   'всюди': 414,
#   'окремо': 406,
#   'чомусь': 405,
#   'реально': 405,
#   'наприклад': 402,
#   'ніяк': 399,
#   'далі': 398,
#   'непогано': 395,
#   'часто': 389,
#   'ніколи': 381,
#   'разом': 375,
#   'відповідно': 372,
#   'менше': 365,
#   'вкрай': 355,
#   'тоді': 354,
#   'брудно': 345,
#   'рано': 339,
#   'дорого': 338,
#   'насправді': 332,
#   'зараз': 330,
#   'страшно': 307,
#   'влітку': 305,
#   'вперше': 304,
#   'навіщо': 303,
#   'настільки': 303,
#   'пізніше': 301,
#   'одно': 299,
#   'трошки': 292,
#   'точно': 291,
#   'нижче': 291,
#   'зверху': 283,
#   'сюди': 280,
#   'бажано': 280,
#   'зранку': 275,
#   'взимку': 272,
#   'злегка': 271,
#   'особисто': 260,
#   'смачно': 255,
#   'недостатньо': 254,
#   'ледь': 252,
#   'місцями': 251,
#   'цілком': 247,
#   'увечері': 246,
#   'вдень': 245,
#   'дорожче': 245,
#   'дещо': 245,
#   'важливо': 242,
#   'внизу': 242,
#   'пора': 238,
#   'незрозуміло': 238,
#   'гірше': 235,
#   'дійсно': 234,
#   'тісно': 233,
#   'начебто': 230,
#   'назад': 229,
#   'скрізь': 229,
#   'ідеально': 224,
#   'скоріше': 218,
#   'нікуди': 218,
#   'тихо': 215,
#   'зазвичай': 213,
#   'некомфортно': 212,
#   'затишно': 209,
#   'трішки': 209,
#   'легко': 204,
#   'самостійно': 204,
#   'безкоштовно': 203,
#   'близько': 202,
#   'темно': 201,
#   'дешевше': 198,
#   'поряд': 195,
#   'нереально': 194,
#   'додатково': 193,
#   'язково': 193,
#   'достатньо': 182,
#   'всередині': 181,
#   'періодично': 181,
#   'скільки': 177,
#   'проблематично': 174,
#   'приблизно': 173,
#   'інакше': 172,
#   'навпаки': 170,
#   'чесно': 167,
#   'мінус': 167,
#   'дорогувато': 165,
#   'важкувато': 163,
#   'буквально': 159,
#   'чітко': 157,
#   'точніше': 154,
#   'моторошно': 153,
#   'слід': 151,
#   'тепло': 151,
#   'тепер': 151,
#   'спокійно': 151,
#   'повільно': 149,
#   'незатишно': 149,
#   'високо': 148,
#   'фактично': 141,
#   'менш': 141,
#   'зовні': 140,
#   'навряд': 138,
#   'ду-у': 137,
#   'природно': 137,
#   'вдруге': 136,
#   'ближче': 136,
#   'огидно': 136,
#   'вниз': 133,
#   'одразу': 131,
#   'шкода': 131,
#   'пильно': 131,
#   'правда': 130,
#   'щільно': 130,
#   'слабо': 130,
#   'недалеко': 130,
#   'прям': 127,
#   'повинний': 125,
#   'значно': 124,
#   'спеціально': 124,
#   'цілодобово': 123,
#   'однозначно': 120,
#   'щодня': 119,
#   'прекрасно': 119,
#   'довше': 118,
#   'поблизу': 118,
#   'сумно': 118,
#   'доволі': 117,
#   'нажаль': 116,
#   'спекотно': 114,
#   'двічі': 114,
#   'соромно': 110,
#   'удвох': 109,
#   'терпимо': 108,
#   'звідти': 106,
#   'відверто': 106,
#   'замало': 104,
#   'найбільше': 103,
#   'правильно': 102,
#   'безпосередньо': 100,
#   'рівно': 99,
#   'колись': 97,
#   'стільки': 97,
#   'терміново': 97,
#   'вчасно': 96,
#   'навколо': 95,
#   'частково': 93,
#   'принципово': 92,
#   'плюс': 91,
#   'додому': 91,
#   'красиво': 91,
#   'неймовірно': 90,
#   'зручніше': 90,
#   'коротше': 90,
#   'звідки': 90,
#   'серйозно': 90,
#   'знизу': 89,
#   'раптом': 88,
#   'попередньо': 87,
#   'категорично': 85,
#   'акуратно': 85,
#   'схоже': 85,
#   'вірніше': 85,
#   'рідко': 84,
#   'виключно': 84,
#   'завтра': 83,
#   'надзвичайно': 82,
#   'очевидно': 82,
#   'небезпечно': 81,
#   'втім': 81,
#   'побільше': 81,
#   'сьогодні': 80,
#   'причому': 80,
#   'сиро': 79,
#   'випадково': 79,
#   'тихіше': 77,
#   'здорово': 77,
#   'круто': 77,
#   'перше': 77,
#   'прикро': 77,
#   'супер': 76,
#   'небудь': 76,
#   'насилу': 76,
#   'вельми': 75,
#   'ймовірно': 75,
#   'одночасно': 75,
#   'мовляв': 74,
#   'відносно': 72,
#   'смішно': 72,
#   'неправильно': 72,
#   'дешево': 72,
#   'якраз': 71,
#   'гучно': 70,
#   'дурнувато': 70,
#   'елементарно': 69,
#   'толком': 69,
#   'далеченько': 68,
#   'страшенно': 68,
#   'зокрема': 68,
#   'повно': 66,
#   'тіснувато': 66,
#   'цікаво': 65,
#   'поспіль': 65,
#   'навпроти': 63,
#   'завчасно': 62,
#   'скоро': 62,
#   'вгору': 62,
#   'холоднувато': 61,
#   'частіше': 61,
#   'чистіше': 61,
#   'впритул': 61,
#   'кудись': 61,
#   'дискомфортно': 61,
#   'несподівано': 61,
#   'перш': 60,
#   'тепліший': 60,
#   'найголовніше': 60,
#   'гарно': 59,
#   'принаймні': 59,
#   'вдома': 59,
#   'тимчасово': 59,
#   'збоку': 58,
#   'помітно': 58,
#   'геть': 58,
#   'нарешті': 58,
#   'звісно': 56,
#   'якісно': 56,
#   'посередині': 56,
#   'різко': 56,
#   'зсередини': 55,
#   'оперативний': 55,
#   'вічно': 54,
#   'нестерпно': 54,
#   'конкретно': 53,
#   'тупо': 53,
#   'низько': 53,
#   'дико': 53,
#   'язно': 53,
#   'свіжо': 51,
#   'суттєво': 51,
#   'ввічливо': 51,
#   'наскільки': 51,
#   'прийнятно': 51,
#   'страшнувато': 49,
#   'максимально': 49,
#   'просто': 49,
#   'нещільно': 48,
#   'відчутно': 48,
#   'ретельніше': 48,
#   'ладно': 48,
#   'ретельно': 48,
#   'платно': 48,
#   'тричі': 47,
#   'подекуди': 47,
#   'малувато': 47,
#   'неодноразово': 46,
#   'регулярно': 46,
#   'можно': 46,
#   'босоніж': 46,
#   'грубо': 46,
#   'напередодні': 46,
#   'неподалік': 45,
#   'класно': 45,
#   'противно': 45,
#   'незвично': 45,
#   'м&': 45,
#   'неудобно': 44,
#   'неприйнятно': 44,
#   'задушливо': 44,
#   'єктивно': 44,
#   'банально': 44,
#   'автоматично': 43,
#   'ужасно': 43,
#   'простіше': 43,
#   'всередину': 43,
#   'уважно': 43,
#   'щоранку': 42,
#   'порожньо': 42,
#   'непросто': 42,
#   'коротший': 42,
#   'кругом': 41,
#   'пристойно': 41,
#   'наполегливо': 41,
#   'затісно': 41,
#   'тяжко': 40,
#   'катастрофічно': 40,
#   'несмачно': 40,
#   'весело': 40,
#   'справді': 39,
#   'все-таки': 39,
#   'звідси': 39,
#   'небагато': 39,
#   'вдвох': 38,
#   'фізично': 38,
#   'телевізор': 38,
#   'ок': 37,
#   'соответственно': 37,
#   'невідомо': 36,
#   'коректно': 36,
#   'наперед': 35,
#   'інколи': 35,
#   'впринципі': 35,
#   'повторно': 35,
#   'логічно': 35,
#   'пір': 35,
#   'ясно': 35,
#   'недавно': 35,
#   'шалено': 35,
#   'приємніше': 35,
#   'забагато': 35,
#   'морально': 34,
#   'порівняно': 34,
#   'горячо': 34,
#   'наполовину': 34,
#   'душ': 34,
#   'чуйно': 34,
#   'нахабно': 33,
#   'байдуже': 33,
#   'неабияк': 33,
#   'проблемно': 33,
#   'відомо': 32,
#   'уважніше': 32,
#   'доки': 32,
#   'неякісно': 32,
#   'слизько': 32,
#   'негайно': 32,
#   'вручну': 31,
#   'волого': 31,
#   'раптово': 31,
#   'візуально': 31,
#   'строго': 31,
#   'даремно': 31,
#   'скромно': 30,
#   'зразу': 30,
#   'надалі': 30,
#   'запізно': 30,
#   'жаль': 30,
#   'активно': 30,
#   'досі': 30,
#   'цікавіше': 30,
#   'гаразд': 29,
#   'завгодно': 29,
#   'незалежно': 29,
#   'пошепки': 29,
#   'вперед': 29,
#   'по-перше': 29,
#   'безумовно': 29,
#   'заздалегідь': 29,
#   'найжахливіше': 29,
#   'смачніше': 29,
#   'похмуро': 29,
#   'миттєво': 28,
#   'ззовні': 28,
#   'легше': 28,
#   'щоразу': 28,
#   'актуально': 28,
#   'комфортніше': 28,
#   'професійно': 28,
#   'неохайно': 28,
#   'восени': 28,
#   '....': 28,
#   'неохоче': 28,
#   'спершу': 27,
#   'найгірший': 27,
#   'коротко': 27,
#   'наглухо': 27,
#   'наверх': 27,
#   'певно': 26,
#   'обов’язково': 26,
#   'опівночі': 26,
#   'аналогічно': 26,
#   'назовні': 26,
#   'щиро': 26,
#   'вчора': 26,
#   'дозатор': 26,
#   'чого': 25,
#   'суто': 25,
#   'охайно': 25,
#   'повноцінно': 25,
#   'адекватно': 25,
#   'вдало': 25,
#   'стабільно': 25,
#   'постоянно': 25,
#   'найнеприємніше': 25,
#   'слушно': 25,
#   'ширше': 25,
#   'неприятно': 24,
#   'міцно': 24,
#   'туго': 24,
#   'фена': 24,
#   'годі': 24,
#   'мовчки': 24,
#   'найбільш': 24,
#   'криво': 23,
#   'поганенько': 23,
#   'бідно': 23,
#   'сміливо': 23,
#   'виразно': 23,
#   'гідно': 23,
#   'боляче': 23,
#   'помилково': 23,
#   'допізна': 23,
#   'індивідуально': 23,
#   'незабаром': 22,
#   'яскраво': 22,
#   'вибачте': 22,
#   'переважно': 22,
#   'зліва': 22,
#   'чистенько': 22,
#   'невдало': 22,
#   'нуднувато': 22,
#   'негативно': 22,
#   'часом': 22,
#   'найкраще': 22,
#   'заново': 22,
#   'обережно': 22,
#   'шикарно': 22,
#   'запросто': 22,
#   'смертельно': 22,
#   'даже': 22,
#   'звідкись': 21,
#   'лучше': 21,
#   'недуже': 21,
#   'подалі': 21,
#   'поверхнево': 21,
#   'повз': 21,
#   'ужасное': 21,
#   'некоректно': 21,
#   'неадекватно': 21,
#   'щоночі': 21,
#   'мокро': 21,
#   'вцілому': 21,
#   'назустріч': 21,
#   'по-друге': 20,
#   'недорого': 20,
#   'вдвічі': 20,
#   'настійно': 20,
#   'довольно': 20,
#   'моментально': 20,
#   'благо': 20,
#   'марно': 20,
#   'слабенько': 20,
#   'обов': 20,
#   'безпечно': 19,
#   'врешті': 19,
#   'істотно': 19,
#   'затхле': 19,
#   'скоріш': 19,
#   'нужно': 19,
#   'остаточно': 19,
#   'нагорі': 19,
#   'нелегко': 19,
#   'обурливо': 19,
#   'звично': 19,
#   'скоренько': 19,
#   'кардинально': 18,
#   'щоправда': 18,
#   'чимало': 18,
#   'фену': 18,
#   'некритично': 18,
#   'невозможно': 18,
#   'гидко': 18,
#   'найцікавіше': 18,
#   'нерозумно': 18,
#   'чемно': 18,
#   'язливо': 18,
#   'вообще': 18,
#   'корисно': 18,
#   'надовго': 18,
#   'возможно': 17,
#   'непрофесійно': 17,
#   'сильніше': 17,
#   'успішно': 17,
#   'удобно': 17,
#   'напевне': 16,
#   'шо': 16,
#   'дослівно': 16,
#   'умовно': 16,
#   'прикольно': 16,
#   'однак': 16,
#   'благополучно': 16,
#   'ніяково': 16,
#   'поменше': 16,
#   'холодніший': 16,
#   'якомога': 16,
#   'убого': 16,
#   'недовго': 16,
#   'згідно': 16,
#   'нудно': 16,
#   'складніше': 15,
#   'вільно': 15,
#   'надворі': 15,
#   'добряче': 15,
#   'справно': 15,
#   'позитивно': 15,
#   'бездоганно': 15,
#   'втретє': 15,
#   'притому': 15,
#   'вгорі': 15,
#   'навесні': 15,
#   'посередньо': 15,
#   'нагору': 15,
#   'балкон': 15,
#   'слышно': 15,
#   'бридко': 14,
#   'жорстко': 14,
#   'доречно': 14,
#   'остальное': 14,
#   'накладно': 14,
#   'згодом': 14,
#   'мінімально': 14,
#   'непривітно': 14,
#   'неввічливо': 14,
#   'решт': 14,
#   'бюджетно': 14,
#   'дбайливо': 14,
#   'погодинно': 14,
#   'густо': 14,
#   'безглуздо': 14,
#   'найсумніше': 14,
#   'м’яко': 14,
#   'хорошо': 14,
#   'усюди': 14,
#   'дополнительно': 14,
#   'навпіл': 14,
#   'праворуч': 13,
#   'наскрізь': 13,
#   'найгірше': 13,
#   'нестабільно': 13,
#   'дальше': 13,
#   'непонятно': 13,
#   'вигідніше': 13,
#   'абияк': 13,
#   'неголосно': 13,
#   'єдино': 13,
#   'привітніше': 13,
#   'поступово': 13,
#   'наостанок': 13,
#   'щільніший': 13,
#   'чуть': 13,
#   'стандартно': 13,
#   'культурний': 13,
#   'попереду': 13,
#   'неакуратно': 13,
#   'гидливо': 13,
#   'щойно': 12,
#   'вперто': 12,
#   'завтрак': 12,
#   'наразі': 12,
#   'зрештою': 12,
#   'недоречно': 12,
#   'прохолодніше': 12,
#   'глибоко': 12,
#   'уночі': 12,
#   'середньо': 12,
#   'затишніше': 12,
#   'перебої': 12,
#   'отлично': 12,
#   'яко': 12,
#   'щовечора': 12,
#   'невчасно': 12,
#   'нерівно': 12,
#   'готово': 12,
#   'надійно': 12,
#   'мимоволі': 12,
#   'все': 12,
#   'вірно': 12,
#   'неуважно': 12,
#   'нещодавно': 12,
#   'сухо': 12,
#   'формальний': 12,
#   'недешево': 12,
#   'повсюди': 11,
#   'толку': 11,
#   'всеодно': 11,
#   'голосніше': 11,
#   'гамірно': 11,
#   'ситно': 11,
#   'веселіше': 11,
#   'назавжди': 11,
#   'задовільно': 11,
#   'доброзичливо': 11,
#   'гранично': 11,
#   'ласкаво': 11,
#   'просторіше': 11,
#   'американо': 11,
#   'однаково': 11,
#   'надмірно': 11,
#   'ловато': 11,
#   'замалі': 11,
#   'привітно': 11,
#   'дарма': 11,
#   'лінь': 11,
#   'усередині': 11,
#   'ненадовго': 11,
#   'трішечки': 11,
#   'доречі': 11,
#   'навмисно': 10,
#   'стильно': 10,
#   'твердо': 10,
#   'зимно': 10,
#   'напідпитку': 10,
#   'частенько': 10,
#   'ззаду': 10,
#   'непристойно': 10,
#   'непомітно': 10,
#   'сложно': 10,
#   'по-моєму': 10,
#   'мляво': 10,
#   'приватно': 10,
#   'навстіж': 10,
#   'спільно': 10,
#   'принизливо': 10,
#   'насамперед': 10,
#   'когда': 10,
#   'безперервно': 10,
#   'гарненько': 10,
#   'найстрашніше': 10,
#   'радісно': 9,
#   'паралельно': 9,
#   'нанівець': 9,
#   'одноразово': 9,
#   'деколи': 9,
#   'направо': 9,
#   'економно': 9,
#   'забавно': 9,
#   'функціонально': 9,
#   'несерйозно': 9,
#   'фото': 9,
#   'стерпно': 9,
#   'образливо': 9,
#   'наліво': 9,
#   'повторюся': 9,
#   'своєчасно': 9,
#   'свідомо': 9,
#   'віконця': 9,
#   'звідусіль': 9,
#   'під&': 9,
#   'недоброзичливо': 9,
#   'крутіше': 9,
#   'імовірно': 9,
#   'теоретично': 9,
#   '.....': 9,
#   'тьмяно': 9,
#   'гордовито': 9,
#   'якше': 9,
#   'разнообразные': 9,
#   'сучасно': 9,
#   'пристойніше': 9,
#   'неважливо': 9,
#   'ох': 9,
#   'найчастіше': 9,
#   'фіг': 9,
#   'достаточно': 9,
#   'романтично': 9,
#   'пришлось': 9,
#   'неясно': 9,
#   'рідше': 9,
#   'единственное': 9,
#   'знадвору': 8,
#   'доцільно': 8,
#   'принаймі': 8,
#   'навкруги': 8,
#   'гостро': 8,
#   'щонайменше': 8,
#   'маленькое': 8,
#   'компактно': 8,
#   'деінде': 8,
#   'ненадійно': 8,
#   'потроху': 8,
#   'суворо': 8,
#   'оптимально': 8,
#   'з&': 8,
#   'бесплатно': 8,
#   'залежно': 8,
#   'сердито': 8,
#   'відколи': 8,
#   'акуратніше': 8,
#   'качественно': 8,
#   'важче': 8,
#   'апетитно': 8,
#   'детально': 8,
#   'вчотирьох': 8,
#   'затратно': 8,
#   'нерівномірно': 8,
#   'оригінально': 8,
#   'бурхливо': 8,
#   'окей': 8,
#   'звечора': 8,
#   'привабливо': 8,
#   'швиденько': 8,
#   'солідно': 8,
#   'зле': 8,
#   'естетично': 8,
#   'охоче': 8,
#   'обязательно': 8,
#   'неможна': 7,
#   'нечутно': 7,
#   'ліпший': 7,
#   'будо': 7,
#   'знов': 7,
#   'отдельно': 7,
#   'неодмінно': 7,
#   'недбало': 7,
#   'москіто': 7,
#   'переді': 7,
#   'тоненько': 7,
#   'найсмішніше': 7,
#   'півроку': 7,
#   'нечемно': 7,
#   'красивіший': 7,
#   'джакузі': 7,
#   'негарно': 7,
#   'тапочок': 7,
#   'разнообразных': 7,
#   'щосили': 7,
#   'зарано': 7,
#   'ось-ось': 7,
#   'різноманітніше': 7,
#   'старше': 7,
#   'тесно': 7,
#   'порційно': 7,
#   'щогодини': 7,
#   'поверхово': 7,
#   'нігде': 7,
#   'пекельно': 7,
#   'действительно': 7,
#   'гласно': 7,
#   'задовго': 7,
#   'нескінченно': 7,
#   'радо': 7,
#   'гуло': 7,
#   'капітально': 7,
#   'т.': 7,
#   'особенно': 7,
#   'обов&': 7,
#   'глобально': 7,
#   'вкотре': 7,
#   'типово': 7,
#   'докладно': 7,
#   'штора': 7,
#   'подвійно': 7,
#   'невиправдано': 7,
#   'люб’язно': 7,
#   'востаннє': 6,
#   'вогко': 6,
#   'щей': 6,
#   'сумнівно': 6,
#   'задалеко': 6,
#   'відрами': 6,
#   'спершись': 6,
#   'ненормально': 6,
#   'старанно': 6,
#   'гладко': 6,
#   'повсюдно': 6,
#   'яскравіше': 6,
#   'ліворуч': 6,
#   'знехотя': 6,
#   'больше': 6,
#   'подушкін': 6,
#   'чутливо': 6,
#   'безцеремонно': 6,
#   'несуттєво': 6,
#   'тонко': 6,
#   'порвано': 6,
#   'здебільшого': 6,
#   'убрать': 6,
#   'зрідка': 6,
#   'підозріло': 6,
#   'штопора': 6,
#   'найприкріше': 6,
#   'мусор': 6,
#   'іще': 6,
#   'конструктивно': 6,
#   'мимо': 6,
#   'нещадно': 6,
#   'багатьом': 6,
#   'нелогічно': 6,
#   'незаконно': 6,
#   'дрібно': 6,
#   'нітрохи': 6,
#   'аскетично': 6,
#   'територіально': 6,
#   'в&': 6,
#   'по-краще': 6,
#   'короче': 6,
#   'дома': 6,
#   'совершенно': 6,
#   'латте': 6,
#   'радше': 6,
#   'одноманітно': 6,
#   'безрезультатно': 6,
#   'найімовірніше': 6,
#   'недобре': 6,
#   'серйозніше': 6,
#   'неминуче': 6,
#   'загально': 6,
#   'немного': 6,
#   '??': 6,
#   'офіційно': 6,
#   'шторка': 6,
#   'неплохо': 6,
#   'щотижня': 5,
#   'якнайшвидше': 5,
#   'водночас': 5,
#   'ужас': 5,
#   'несамовито': 5,
#   'сантехніку': 5,
#   'доступно': 5,
#   'логічніше': 5,
#   'демонстративно': 5,
#   'ефективно': 5,
#   'орієнтовно': 5,
#   'напроти': 5,
#   'заввишки': 5,
#   'незначно': 5,
#   'невірно': 5,
#   'свіжіше': 5,
#   'здалеку': 5,
#   'конечно': 5,
#   'отрицательно': 5,
#   'ненароком': 5,
#   'грубувато': 5,
#   'правильніше': 5,
#   'вигідно': 5,
#   'скромніше': 5,
#   'мрачно': 5,
#   'подорожче': 5,
#   'найменше': 5,
#   'безперешкодно': 5,
#   'послужливо': 5,
#   'герметично': 5,
#   'рівномірно': 5,
#   'тщательно': 5,
#   'мирно': 5,
#   'нечасто': 5,
#   'різноманітно': 5,
#   'емоційно': 5,
#   'несвіже': 5,
#   'гарантовано': 5,
#   'вперве': 5,
#   'безбожно': 5,
#   'гостинно': 5,
#   'по-третє': 5,
#   'хаотично': 5,
#   'важливіше': 5,
#   'п&': 5,
#   'рясно': 5,
#   'нешанобливо': 5,
#   'намертво': 5,
#   'старомодно': 5,
#   '!!!!': 5,
#   'наврядчи': 5,
#   'агресивно': 5,
#   'незадовільно': 5,
#   'довкола': 5,
#   'завбачливо': 5,
#   'примусово': 5,
#   'предварительно': 5,
#   'систематично': 5,
#   'найперше': 5,
#   'гордо': 5,
#   'зависоко': 5,
#   'сутужно': 5,
#   'шторк': 5,
#   'білий': 5,
#   'презентабельно': 5,
#   'безнадійно': 5,
#   'недружелюбно': 5,
#   'відповідально': 5,
#   'законно': 5,
#   'невиразно': 5,
#   'душевно': 5,
#   'оглушливо': 5,
#   'продемонстрировать': 5,
#   'давненько': 5,
#   'наживо': 5,
#   'інтенсивно': 5,
#   'взнаки': 5,
#   'хотя': 5,
#   'потому': 5,
#   'замечательно': 5,
#   'грунтовно': 5,
#   'общем': 5,
#   'технічно': 5,
#   'гуркоче': 5,
#   'обіцяно': 5,
#   'достойно': 4,
#   'ввечорі': 4,
#   'удома': 4,
#   'вліво': 4,
#   'апріорі': 4,
#   'несколько': 4,
#   'печально': 4,
#   'ранувато': 4,
#   'щоденно': 4,
#   'видимо': 4,
#   'честно': 4,
#   'зухвало': 4,
#   'плавно': 4,
#   'симпатично': 4,
#   'традиційно': 4,
#   ...},
#  'ADJ': {'маленький': 5217,
#   'поганий': 4369,
#   'ванній': 4153,
#   'душовий': 3241,
#   'старий': 2896,
#   'брудний': 2824,
#   'відсутній': 2783,
#   'гарячий': 2775,
#   'перший': 2747,
#   'жахливий': 2456,
#   'великий': 2377,
#   'сусідній': 2229,
#   'другий': 1867,
#   'ресепшений': 1802,
#   'холодний': 1611,
#   'єдиний': 1572,
#   'постільний': 1493,
#   'загальний': 1357,
#   'незручний': 1342,
#   'хороший': 1336,
#   'неприємний': 1255,
#   'тонкий': 1242,
#   'слабкий': 1241,
#   'зручний': 1201,
#   'чистий': 1176,
#   'ванний': 1124,
#   'кращий': 1118,
#   'невеликий': 1050,
#   'розташований': 1040,
#   'повинний': 1010,
#   'зламаний': 1005,
#   'окремий': 938,
#   'одноразовий': 909,
#   'новий': 909,
#   'високий': 904,
#   'теплий': 896,
#   'відкритий': 880,
#   'туалетний': 877,
#   'додатковий': 866,
#   'повний': 846,
#   'закритий': 842,
#   'нормальний': 791,
#   'потрібний': 786,
#   'гучний': 767,
#   'двоспальний': 743,
#   'наступний': 727,
#   'білизний': 699,
#   'платний': 661,
#   'звичайний': 636,
#   'сильний': 626,
#   'привітний': 615,
#   'смачний': 612,
#   'вхідний': 606,
#   'останній': 599,
#   'забитий': 597,
#   'приємний': 594,
#   'включений': 592,
#   'попередній': 591,
#   'готовий': 589,
#   'різний': 586,
#   'дивний': 583,
#   'свіжий': 580,
#   'двомісний': 573,
#   'цілий': 566,
#   'заявлений': 559,
#   'дешевий': 547,
#   'величезний': 547,
#   'радянський': 544,
#   'зубний': 534,
#   'третій': 533,
#   'низький': 530,
#   'ранній': 524,
#   'поламаний': 508,
#   'шведський': 496,
#   'завищений': 494,
#   'галасливий': 491,
#   'вузький': 488,
#   '8': 486,
#   'огидний': 483,
#   'вільний': 479,
#   '3': 474,
#   '4': 469,
#   'втомлений': 465,
#   'житловий': 463,
#   'відмінний': 459,
#   'безкоштовний': 445,
#   'нічний': 444,
#   'чистотий': 436,
#   'даний': 436,
#   'дорогий': 423,
#   'стандартний': 421,
#   'гарний': 420,
#   'постійний': 417,
#   'питний': 415,
#   'спальний': 415,
#   'убогий': 415,
#   'душова': 410,
#   'чорний': 400,
#   '5': 392,
#   'косметичний': 392,
#   'внутрішній': 389,
#   'тісний': 382,
#   'прокурений': 378,
#   '9': 377,
#   'верхній': 372,
#   'довгий': 369,
#   'порожній': 367,
#   'комфортний': 361,
#   'схожий': 356,
#   'ванна': 352,
#   '7': 351,
#   'минулий': 348,
#   'білий': 347,
#   'жорсткий': 337,
#   '14': 334,
#   'яний': 331,
#   'скромний': 329,
#   'темний': 326,
#   'присутній': 322,
#   'слабенький': 320,
#   'робочий': 318,
#   'більший': 318,
#   'малий': 316,
#   'скрипучий': 316,
#   'зайнятий': 315,
#   'прибраний': 308,
#   '6': 305,
#   '12': 303,
#   'міні': 300,
#   '23': 299,
#   'важкий': 299,
#   'чужий': 295,
#   'громадський': 293,
#   'дитячий': 292,
#   'вказаний': 282,
#   'основний': 280,
#   'рідкий': 280,
#   'сірий': 275,
#   'дрібний': 274,
#   'мокрий': 271,
#   'москітний': 271,
#   'однодольний': 268,
#   'місцевий': 267,
#   'покращений': 265,
#   'крутий': 264,
#   '10': 264,
#   'милий': 263,
#   'український': 259,
#   'одномісний': 259,
#   'короткий': 258,
#   'чудовий': 250,
#   'найближчий': 247,
#   'особистий': 246,
#   'простий': 244,
#   'власний': 239,
#   'затишний': 239,
#   'зношений': 237,
#   'незрозумілий': 235,
#   'заправний': 233,
#   'тихий': 232,
#   'негативний': 229,
#   'середній': 228,
#   'готельний': 224,
#   '11': 224,
#   'приватний': 223,
#   'пізний': 222,
#   'повільний': 220,
#   'страшний': 220,
#   'особливий': 219,
#   'обмежений': 218,
#   'центральний': 217,
#   'прекрасний': 215,
#   '1': 214,
#   'вихідний': 214,
#   'туристичний': 210,
#   'головний': 207,
#   'красивий': 207,
#   'зроблений': 204,
#   'несмачний': 203,
#   'зайвий': 203,
#   'розбитий': 200,
#   'зовнішній': 198,
#   'певний': 196,
#   'килимовий': 195,
#   'непривітний': 193,
#   'ввічливий': 192,
#   'мізерний': 190,
#   'найдешевший': 189,
#   'елементарний': 185,
#   'задоволений': 185,
#   'добрий': 182,
#   'ремонтний': 182,
#   'пошарпаний': 181,
#   'одноманітний': 180,
#   'мінімальний': 179,
#   'необхідний': 179,
#   'ідеальний': 178,
#   'спільний': 178,
#   'жовтий': 178,
#   'пластиковий': 177,
#   'молодий': 177,
#   'картонний': 176,
#   'старенький': 176,
#   'несправний': 175,
#   'проїжджий': 174,
#   'скляний': 172,
#   'пральний': 172,
#   'літній': 170,
#   'бюджетний': 169,
#   'застарілий': 168,
#   '2': 167,
#   'найкращий': 167,
#   'підвальний': 167,
#   'якісний': 166,
#   'відповідний': 166,
#   'іржавий': 165,
#   'залізничний': 165,
#   'непоганий': 164,
#   'важливий': 163,
#   'убитий': 162,
#   'подавлений': 159,
#   'мобільний': 158,
#   'четвертий': 157,
#   'сміттєвий': 156,
#   'непрацюючий': 155,
#   'будівельний': 155,
#   'вологий': 154,
#   'розрахований': 154,
#   'російський': 153,
#   'пізній': 153,
#   'зазначений': 153,
#   'цокольний': 153,
#   'грубий': 151,
#   'доступний': 151,
#   'зіпсований': 151,
#   'подібний': 151,
#   'твердий': 151,
#   'роздільний': 150,
#   'чайний': 149,
#   'уважний': 148,
#   'повноцінний': 147,
#   'чутній': 147,
#   'сучасний': 146,
#   'позитивний': 145,
#   'легкий': 145,
#   'кухонний': 144,
#   'змушений': 143,
#   'можливий': 143,
#   'працюючий': 143,
#   'обіцяний': 143,
#   'сигаретний': 142,
#   'обшарпаний': 142,
#   'тьмяний': 141,
#   'мансардний': 141,
#   '21': 140,
#   'кімнатний': 139,
#   'заброньований': 139,
#   'недостатній': 139,
#   'сімейний': 139,
#   'хамський': 138,
#   'реальний': 135,
#   'порваний': 135,
#   'голодний': 135,
#   'незадоволений': 135,
#   'цілодобовий': 135,
#   'вищий': 134,
#   '22': 134,
#   'крихітний': 134,
#   'міський': 134,
#   'сан.': 130,
#   'сумнівний': 130,
#   'похмурий': 130,
#   'жвавий': 129,
#   'дорослий': 129,
#   'електричний': 126,
#   'встановлений': 126,
#   'тривалий': 126,
#   'чуйний': 125,
#   'посередній': 124,
#   'сходовий': 124,
#   '20': 124,
#   'прохолодний': 123,
#   'банківський': 123,
#   'сухий': 123,
#   'впевнений': 123,
#   'розчинний': 122,
#   'душевний': 121,
#   'сторонній': 121,
#   'стійкий': 121,
#   'передбачений': 120,
#   'закріплений': 118,
#   'смердючий': 118,
#   'різноманітний': 118,
#   'жіночий': 118,
#   'оплачений': 117,
#   'совковий': 117,
#   'винний': 116,
#   'язаний': 116,
#   'сумний': 116,
#   'європейський': 116,
#   'крижаний': 116,
#   'замовлений': 115,
#   'гігієнічний': 114,
#   'здивований': 114,
#   'електронний': 113,
#   'наданий': 113,
#   'телефонний': 112,
#   'столовий': 111,
#   'розчарований': 110,
#   'замалий': 110,
#   'мізерній': 110,
#   'використаний': 109,
#   'шумний': 109,
#   'пристойний': 108,
#   'черговий': 107,
#   'найгірший': 107,
#   'обдертий': 106,
#   'ятий': 106,
#   'рваний': 104,
#   'денний': 104,
#   'малесенький': 103,
#   'швидкий': 103,
#   'вечірній': 103,
#   'найбільший': 102,
#   'миючий': 102,
#   'належний': 101,
#   'суцільний': 101,
#   'зелений': 101,
#   'далекий': 100,
#   'просторий': 100,
#   'менший': 100,
#   'однаковий': 100,
#   'смажений': 99,
#   'жирний': 98,
#   'мікрохвильовий': 97,
#   '30': 97,
#   'доброзичливий': 97,
#   'цікавий': 97,
#   'моторошний': 97,
#   'трамвайний': 97,
#   'запропонований': 96,
#   'адекватний': 95,
#   '16': 94,
#   'зачинений': 94,
#   'незначний': 94,
#   'скриптовий': 93,
#   'прямий': 92,
#   'специфічний': 92,
#   'щільний': 91,
#   'москвітіний': 91,
#   'неякісний': 90,
#   'вайлуватий': 90,
#   'слизький': 89,
#   'балконний': 89,
#   'вуличний': 88,
#   'розміщений': 88,
#   'обслуговуючий': 88,
#   '18': 88,
#   '1-ий': 88,
#   'ранковий': 87,
#   'технічний': 87,
#   'пробурений': 87,
#   'настільний': 87,
#   'діловий': 87,
#   'сонячний': 86,
#   'одностайний': 86,
#   'зливний': 86,
#   'широкий': 86,
#   'неприбраний': 85,
#   '13': 85,
#   'яскравий': 84,
#   'шикарний': 84,
#   'гумовий': 84,
#   '19': 84,
#   'прозорий': 84,
#   'зимовий': 83,
#   'колишній': 83,
#   'пакувальний': 82,
#   'душий': 82,
#   'банний': 82,
#   'налаштований': 82,
#   'задній': 81,
#   'варений': 81,
#   'індивідуальний': 81,
#   'ясний': 81,
#   'червоний': 80,
#   'п.': 80,
#   'англійський': 79,
#   'зсунутий': 79,
#   'напівпідвальний': 79,
#   'мильний': 79,
#   'паркувальний': 79,
#   '15': 78,
#   'живий': 77,
#   'обладнаний': 77,
#   '3-ий': 76,
#   'невеличкий': 76,
#   '4-ий': 76,
#   'синтетичний': 76,
#   'нульовий': 76,
#   'подвійний': 76,
#   'тимчасовий': 75,
#   'найменший': 75,
#   'заселений': 75,
#   'задушливий': 75,
#   'проїжджаючий': 75,
#   'одеський': 75,
#   'щоденний': 74,
#   'кабельний': 74,
#   'підготовлений': 74,
#   'складний': 74,
#   'паперовий': 74,
#   'домашній': 74,
#   'призначений': 74,
#   'підвищений': 73,
#   'явний': 73,
#   'несвіжий': 73,
#   'доглянутий': 73,
#   'випраний': 73,
#   'провалений': 72,
#   'продуманий': 72,
#   'пожежний': 71,
#   'вбиральний': 71,
#   'літний': 71,
#   'ціновий': 71,
#   'перероблений': 71,
#   'помітний': 70,
#   'залізний': 70,
#   'критичний': 70,
#   'зрушений': 70,
#   'зірковий': 69,
#   'розкладний': 69,
#   'неймовірний': 69,
#   '2-ий': 69,
#   'серйозний': 69,
#   'тютюновий': 68,
#   'плоский': 68,
#   'каналізаційний': 67,
#   'покритий': 67,
#   'спокійний': 66,
#   'достатній': 66,
#   'річний': 66,
#   'номерний': 66,
#   'нижній': 66,
#   'конкретний': 65,
#   '2-й': 65,
#   'різкий': 65,
#   'спеціальний': 65,
#   'глухий': 64,
#   'коричневий': 64,
#   'дерибасівський': 64,
#   'неробочий': 63,
#   'бідний': 63,
#   '4-й': 63,
#   'застелений': 63,
#   'прохідний': 63,
#   'небезпечний': 62,
#   'пішохідний': 62,
#   'металевий': 62,
#   'т.': 62,
#   'відключений': 62,
#   'санний': 62,
#   'занедбаний': 61,
#   'голий': 61,
#   'активний': 61,
#   'прийнятний': 61,
#   'чоловічий': 61,
#   '24': 61,
#   'справний': 61,
#   '17': 61,
#   'відірваний': 60,
#   'зрозумілий': 60,
#   'тоненький': 60,
#   '3-й': 60,
#   'вимкнений': 60,
#   'м’який': 59,
#   'кредитний': 59,
#   'вдалий': 59,
#   'званий': 59,
#   'дикий': 59,
#   'іноземний': 58,
#   'вбитий': 58,
#   'твердь': 58,
#   'тримісний': 58,
#   'планувальний': 58,
#   'вимитий': 57,
#   'промисловий': 57,
#   'прикріплений': 57,
#   'заклеєний': 57,
#   'глибокий': 57,
#   'хороше': 57,
#   'панорамний': 57,
#   'абсолютний': 56,
#   'супутниковий': 56,
#   'штучний': 56,
#   'гідний': 56,
#   'віддалений': 55,
#   'гостьовий': 55,
#   'газовий': 55,
#   'чистіший': 54,
#   'справжній': 54,
#   'знятий': 54,
#   'веселий': 54,
#   'найдорожчий': 54,
#   'шановний': 54,
#   'нестерпний': 54,
#   'транспортний': 53,
#   'неадекватний': 53,
#   'складений': 53,
#   'істотний': 53,
#   'історичний': 53,
#   'чесний': 52,
#   'континентальний': 52,
#   'протилежний': 52,
#   'гострий': 52,
#   'курячий': 52,
#   'піший': 52,
#   'суміщений': 52,
#   '00': 52,
#   'пиловий': 52,
#   'розбавлений': 52,
#   'побитий': 51,
#   'класний': 51,
#   'недорогий': 51,
#   'гірший': 51,
#   'значний': 51,
#   'солодкий': 51,
#   'точний': 51,
#   'міжкімнатний': 51,
#   'пружинний': 51,
#   'аналогічний': 51,
#   'сирий': 51,
#   'м': 51,
#   'наявний': 50,
#   'сумовитий': 50,
#   'відчинений': 50,
#   'розхитаний': 50,
#   'двокімнатний': 50,
#   'одинарний': 50,
#   'байдужий': 49,
#   'крайній': 49,
#   'некурящий': 49,
#   'некомфортний': 49,
#   'товстий': 48,
#   'слабий': 48,
#   'близький': 48,
#   'продуктовий': 48,
#   'голосний': 48,
#   'класичний': 48,
#   'неможливий': 48,
#   'відпочиваючий': 48,
#   'пустий': 47,
#   'світлий': 47,
#   'майбутній': 47,
#   'грізний': 47,
#   'невдалий': 47,
#   'відомий': 46,
#   'ситний': 46,
#   'нестабільний': 46,
#   'розпізнавальний': 46,
#   'вентиляційний': 46,
#   'кутовий': 46,
#   'дірявий': 46,
#   'чутний': 46,
#   'неправильний': 46,
#   'разовий': 46,
#   'натуральний': 46,
#   'старовинний': 46,
#   'спекотний': 45,
#   'асортимент': 45,
#   'підключений': 45,
#   'банальний': 45,
#   'збитий': 45,
#   'кавовий': 45,
#   'здоровий': 45,
#   'віконний': 45,
#   'футбольний': 45,
#   'санітарний': 44,
#   'ресторанний': 44,
#   'повторний': 44,
#   'спортивний': 44,
#   'сусідський': 44,
#   'суттєвий': 44,
#   'зворотний': 44,
#   'різноманітніший': 44,
#   'доп.': 44,
#   'організований': 44,
#   'парадний': 44,
#   'компетентний': 43,
#   'незадовільний': 43,
#   'правильний': 43,
#   'забруднений': 43,
#   'жаркий': 43,
#   'заправлений': 43,
#   'найжахливіший': 43,
#   'прилеглий': 43,
#   'гостинний': 43,
#   'магнітний': 42,
#   'затертий': 42,
#   'професійний': 42,
#   'базовий': 42,
#   'типовий': 42,
#   'заповнений': 42,
#   'проведений': 42,
#   'компактний': 42,
#   'львівський': 42,
#   'стабільний': 42,
#   'побутовий': 41,
#   'письмовий': 41,
#   'простенький': 41,
#   'впертий': 41,
#   'заблокований': 41,
#   'мініатюрний': 41,
#   'дешевший': 41,
#   'запорошений': 41,
#   'стаціонарний': 41,
#   '5-ий': 41,
#   'язковий': 41,
#   'незрозуміле': 41,
#   'пляжний': 41,
#   'пошкоджений': 40,
#   'барний': 40,
#   'п’яний': 40,
#   'ретельний': 40,
#   'дверний': 40,
#   'київський': 40,
#   'виставлений': 40,
#   'знайомий': 40,
#   'романтичний': 40,
#   'потрісканий': 40,
#   'затхлий': 40,
#   'природний': 40,
#   'поліпшений': 40,
#   'попівський': 40,
#   'торговий': 40,
#   'привабливий': 40,
#   'залитий': 40,
#   'видний': 40,
#   'залишений': 40,
#   'кольоровий': 40,
#   'вихідні': 40,
#   'службовий': 39,
#   'безсонний': 39,
#   'одягнений': 39,
#   'вирваний': 39,
#   'вчорашній': 39,
#   'крихітній': 39,
#   'вівсяний': 39,
#   'необхідне': 39,
#   'приручений': 39,
#   'гвинтовий': 39,
#   'людський': 38,
#   'чіткий': 38,
#   'найголовніший': 38,
#   'виправний': 38,
#   'придатний': 38,
#   'горячий': 38,
#   'вбудований': 38,
#   'поставлений': 38,
#   'крихітна': 38,
#   'древний': 38,
#   'квадратний': 38,
#   'аварійний': 38,
#   'лівий': 38,
#   'антиконкурентний': 38,
#   'телевізійний': 38,
#   'вирішений': 38,
#   'керуючий': 38,
#   'відчутний': 38,
#   'багатоповерховий': 37,
#   'дорожчий': 37,
#   'описаний': 37,
#   'помічений': 37,
#   'розділений': 37,
#   'опалювальний': 37,
#   'засмічений': 37,
#   'суміжний': 37,
#   'сонний': 37,
#   'максимальний': 37,
#   'частий': 37,
#   'потужний': 37,
#   'правий': 37,
#   'кислий': 37,
#   'акуратний': 36,
#   'невідомий': 36,
#   'виконаний': 36,
#   'зависокий': 36,
#   'нижчий': 36,
#   'бажаний': 36,
#   'примітивний': 36,
#   'вай': 36,
#   'расположений': 36,
#   'виявлений': 36,
#   ';яний': 36,
#   'поверховий': 36,
#   'кільцевий': 35,
#   'кінцевий': 35,
#   'битий': 35,
#   'жалюгідний': 35,
#   'перекошений': 35,
#   'офісний': 35,
#   'непрофесійний': 35,
#   'неуважний': 35,
#   'дерев’яний': 35,
#   'шостий': 35,
#   'освітлений': 35,
#   'підземний': 35,
#   'покладений': 35,
#   'поточний': 35,
#   'запасний': 35,
#   'перерахований': 35,
#   'безглуздий': 35,
#   'комплексний': 35,
#   'молочний': 35,
#   'єктивний': 35,
#   'новорічний': 35,
#   'музичний': 34,
#   'заплутаний': 34,
#   'захований': 34,
#   'чутливий': 34,
#   'китайський': 34,
#   'оформлений': 34,
#   'супер': 34,
#   'централізований': 34,
#   'спа.': 34,
#   'божевільний': 34,
#   'нереальний': 34,
#   'звичний': 34,
#   'журнальний': 33,
#   'обраний': 33,
#   'неохайний': 33,
#   'окружний': 33,
#   'холодильний': 33,
#   'мертвий': 33,
#   'скоріше': 33,
#   'гнітючий': 33,
#   'пластмасовий': 33,
#   'розвалений': 33,
#   'бідненький': 33,
#   'забутий': 33,
#   'цінний': 33,
#   'броньований': 32,
#   'банкетний': 32,
#   'заляпаний': 32,
#   'мінеральний': 32,
#   'білосніжний': 32,
#   'укомплектований': 32,
#   'переповнений': 32,
#   'мінусни': 32,
#   'передоплатий': 32,
#   'фітнес': 32,
#   'неприйнятний': 32,
#   'обірваний': 32,
#   'найпростіший': 32,
#   'невисокий': 32,
#   'капітальний': 32,
#   'потертий': 32,
#   'святковий': 32,
#   'охайний': 31,
#   'задовільний': 31,
#   'фактичний': 31,
#   'змінний': 31,
#   'мікроскопічний': 31,
#   'тренажерний': 31,
#   'підтверджений': 31,
#   'студентський': 31,
#   'рудий': 31,
#   'подальший': 31,
#   '39;ятий': 31,
#   '6-ий': 31,
#   'духовий': 31,
#   'навчений': 31,
#   'підлоговий': 31,
#   'написаний': 31,
#   'примусовий': 31,
#   'розкішний': 30,
#   'безготівковий': 30,
#   'представлений': 30,
#   'ручний': 30,
#   'давній': 30,
#   'маленькай': 30,
#   'круглий': 30,
#   'сіруватий': 30,
#   'побудований': 30,
#   'старший': 30,
#   'некомпетентний': 30,
#   'декоративний': 30,
#   'засмучений': 30,
#   'вітальний': 30,
#   'пропонований': 30,
#   'французький': 30,
#   'рудуватий': 30,
#   'поношений': 29,
#   'точніше': 29,
#   'платіжний': 29,
#   'грозний': 29,
#   'приємне': 29,
#   'настінний': 29,
#   'впечатлений': 29,
#   'бетонний': 29,
#   'х': 29,
#   'недоступний': 29,
#   'допотопний': 29,
#   'местоположений': 29,
#   'сплячий': 29,
#   'ортопедичний': 29,
#   'заварний': 29,
#   'поданий': 29,
#   'усміхнений': 29,
#   '08': 29,
#   'перекритий': 29,
#   'непродуманий': 28,
#   'похилий': 28,
#   'вушний': 28,
#   'проживаючий': 28,
#   'безпечний': 28,
#   'висунутий': 28,
#   'гіркий': 28,
#   'скошений': 28,
#   'чийсь': 28,
#   'орієнтований': 28,
#   'розумний': 28,
#   'подряпаний': 28,
#   'синій': 28,
#   'проблемний': 28,
#   'офіційний': 28,
#   'відвертий': 28,
#   'найприємніший': 28,
#   'небудь': 28,
#   'сидячий': 28,
#   'їстівний': 27,
#   'кривий': 27,
#   'вартий': 27,
#   'персональний': 27,
#   'ел.': 27,
#   'багатоквартирний': 27,
#   'гнучкий': 27,
#   'новіший': 27,
#   'ізольований': 27,
#   'пристосований': 27,
#   'добовий': 27,
#   'кволий': 27,
#   'поєднаний': 27,
#   'застійний': 27,
#   'відносний': 27,
#   'розламаний': 27,
#   'непомітний': 27,
#   'кодовий': 27,
#   'нахабний': 26,
#   'найголовніше': 26,
#   'обережній': 26,
#   'крайний': 26,
#   'генеральний': 26,
#   '09': 26,
#   'вклеєний': 26,
#   'липкий': 26,
#   'попереджений': 26,
#   'позначений': 26,
#   'симпатичний': 26,
#   'автоматичний': 26,
#   'терміновий': 26,
#   'очень': 26,
#   'обумовлений': 26,
#   'набитий': 26,
#   'доречний': 26,
#   'босий': 25,
#   'прописаний': 25,
#   'викладений': 25,
#   'розкладений': 25,
#   'смішний': 25,
#   'нарізаний': 25,
#   'прострочений': 25,
#   'замкнений': 25,
#   'овочевий': 25,
#   'комунальний': 25,
#   'забезпечений': 25,
#   'улюблений': 25,
#   '..': 25,
#   'бутильований': 25,
#   'гарантований': 25,
#   'некоректний': 25,
#   '5-й': 25,
#   'недоглянутий': 25,
#   'цілковитий': 25,
#   'актуальний': 25,
#   'д.': 25,
#   'морський': 25,
#   'чималий': 25,
#   'безпосередній': 25,
#   'шампанський': 25,
#   'єднаний': 25,
#   'кахельний': 24,
#   'дешевше': 24,
#   'двоканальний': 24,
#   'поганенький': 24,
#   'корисний': 24,
#   'самий': 24,
#   'фізичний': 24,
#   'розігрітий': 24,
#   'завантажений': 24,
#   '2018': 24,
#   'досвідчений': 24,
#   'контрастний': 24,
#   'заяложений': 24,
#   'вообщий': 24,
#   'затісний': 24,
#   'підозрілий': 24,
#   'пропілений': 24,
#   'оперний': 24,
#   'державний': 23,
#   'незнайомий': 23,
#   'оголений': 23,
#   'обслуживаний': 23,
#   'весільний': 23,
#   'третя': 23,
#   'малюсінький': 23,
#   'настояний': 23,
#   'непривабливий': 23,
#   'облуплений': 23,
#   'пильний': 23,
#   'готівковий': 23,
#   'плохий': 23,
#   'котячий': 23,
#   'сьомий': 23,
#   'неправдивий': 23,
#   'хиткий': 23,
#   '90-й': 23,
#   'характерний': 23,
#   'пузатий': 23,
#   'виправданий': 23,
#   'ватний': 23,
#   'пекельний': 23,
#   'мальовничий': 23,
#   'інтенсивний': 23,
#   'найкраще': 23,
#   'платній': 23,
#   'знімний': 23,
#   'критий': 23,
#   'вибагливий': 23,
#   'дворівневий': 23,
#   '2019': 22,
#   'приклеєний': 22,
#   'му': 22,
#   'надійний': 22,
#   'відрегульований': 22,
#   'тепліший': 22,
#   'ужалений': 22,
#   'практичний': 22,
#   'вдячний': 22,
#   'герметичний': 22,
#   'парковий': 22,
#   'недоречний': 22,
#   'відповідальний': 22,
#   'рівний': 22,
#   'касовий': 22,
#   'гідромасажий': 22,
#   'зацікавлений': 22,
#   'економний': 22,
#   'коректний': 22,
#   'найвищий': 22,
#   '....': 22,
#   'кошмарний': 22,
#   'замінений': 22,
#   'найзручніший': 22,
#   'звуковий': 22,
#   'прикритий': 22,
#   'відремонтований': 22,
#   '1-й': 22,
#   'приготований': 22,
#   'зарядний': 22,
#   'розкиданий': 21,
#   'тверезий': 21,
#   'вузенький': 21,
#   'показаний': 21,
#   'хворий': 21,
#   '01': 21,
#   'багатий': 21,
#   'поселений': 21,
#   'оснащений': 21,
#   'стриманий': 21,
#   'масляний': 21,
#   'злий': 21,
#   'матовий': 21,
#   'вантажний': 21,
#   'знайдений': 21,
#   'розважальний': 21,
#   'огороджений': 21,
#   'двоповерховий': 21,
#   'дубовий': 21,
#   'популярний': 21,
#   'міжнародний': 21,
#   'газневий': 21,
#   'бічний': 21,
#   'заставний': 21,
#   'тупий': 21,
#   'видимий': 21,
#   'моторошній': 21,
#   '39;яний': 21,
#   'приготовлений': 21,
#   'невибагливий': 21,
#   ...}}

# %%
len(set(pos_dict['ADJ'].keys()).union(set(neg_dict['ADJ'].keys())))
# Out:
# 9266

# %%
def calc_sentiment_score(pos_dict, neg_dict, total_pos, total_neg, word):
    freq_pos_w = pos_dict[word] if word in pos_dict else 0.1
    freq_neg_w = neg_dict[word] if word in neg_dict else 0.1
    
    sentiment_score = np.log2((freq_pos_w * total_neg) / (freq_neg_w * total_pos))
    return sentiment_score

# %%
calc_sentiment_score(pos_dict['ADJ'], neg_dict['ADJ'], total_pos_num_words, total_neg_num_words, 'привітний')
# Out:
# 4.70307015851435

# %% [markdown]
# #### Calc sentiment score for adjective

# %%
all_adjectives = set(pos_dict['ADJ'].keys()).union(set(neg_dict['ADJ'].keys()))

# %%
adjective_scores = dict()
for adj in all_adjectives:
    score = calc_sentiment_score(pos_dict['ADJ'], neg_dict['ADJ'], total_pos_num_words, total_neg_num_words, adj)
    adjective_scores[adj] = score
    
adjective_scores = sort_dict_by_values(adjective_scores, reverse=True)

# %%
adjective_scores['брудний']
# Out:
# -4.466733822007981

# %%
adjective_scores['чистий']
# Out:
# 3.8180864768644764

# %%
save_data_to_json(adjective_scores, 'data/adj-sent-scores.json')

# %% [markdown]
# #### Calc sentiment score for adverbs

# %%
all_adverbs = set(pos_dict['ADV'].keys()).union(set(neg_dict['ADV'].keys()))

# %%
adverbs_scores = dict()
for adv in all_adverbs:
    score = calc_sentiment_score(pos_dict['ADV'], neg_dict['ADV'], total_pos_num_words, total_neg_num_words, adv)
    adverbs_scores[adv] = score
    
adverbs_scores = sort_dict_by_values(adverbs_scores, reverse=True)

# %%
adverbs_scores['стильно']
# Out:
# 5.083825441244996

# %%
adverbs_scores['дорого']
# Out:
# -0.11403130541864527

# %%
save_data_to_json(adverbs_scores, 'data/adv-sent-scores.json')
